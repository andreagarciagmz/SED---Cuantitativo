# %%
# !pip install pandas
# !pip install openpyxl
# !pip install requests
# !pip install beautifulsoup4
# !pip install newspaper3k
# !pip install selenium
# !pip install openai
# !pip install serpapi
# !pip install GoogleNews
# !pip install googlesearch-python
# !pip install google-search-results
# !pip install concurrent.futures
# !pip install lxml
# !pip install numpy
# !pip install json
# !pip install "httpx[http2]"
# !pip install "lxml[html_clean]"
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.12/dist-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2025.10.5)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (4.13.5)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (4.15.0)
# Collecting newspaper3k
#   Downloading newspaper3k-0.2.8-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.12/dist-packages (from newspaper3k) (4.13.5)
# Requirement already satisfied: Pillow>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from newspaper3k) (11.3.0)
# Requirement already satisfied: PyYAML>=3.11 in /usr/local/lib/python3.12/dist-packages (from newspaper3k) (6.0.3)
# Collecting cssselect>=0.9.2 (from newspaper3k)
#   Downloading cssselect-1.3.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: lxml>=3.6.0 in /usr/local/lib/python3.12/dist-packages (from newspaper3k) (5.4.0)
# Requirement already satisfied: nltk>=3.2.1 in /usr/local/lib/python3.12/dist-packages (from newspaper3k) (3.9.1)
# Requirement already satisfied: requests>=2.10.0 in /usr/local/lib/python3.12/dist-packages (from newspaper3k) (2.32.4)
# Collecting feedparser>=5.2.1 (from newspaper3k)
#   Downloading feedparser-6.0.12-py3-none-any.whl.metadata (2.7 kB)
# Collecting tldextract>=2.0.1 (from newspaper3k)
#   Downloading tldextract-5.3.0-py3-none-any.whl.metadata (11 kB)
# Collecting feedfinder2>=0.0.4 (from newspaper3k)
#   Downloading feedfinder2-0.0.4.tar.gz (3.3 kB)
#   Preparing metadata (setup.py) ... done
# Collecting jieba3k>=0.35.1 (from newspaper3k)
#   Downloading jieba3k-0.35.1.zip (7.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 44.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.12/dist-packages (from newspaper3k) (2.9.0.post0)
# Collecting tinysegmenter==0.3 (from newspaper3k)
#   Downloading tinysegmenter-0.3.tar.gz (16 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.4.1->newspaper3k) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.4.1->newspaper3k) (4.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from feedfinder2>=0.0.4->newspaper3k) (1.17.0)
# Collecting sgmllib3k (from feedparser>=5.2.1->newspaper3k)
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk>=3.2.1->newspaper3k) (8.3.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk>=3.2.1->newspaper3k) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk>=3.2.1->newspaper3k) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk>=3.2.1->newspaper3k) (4.67.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.10.0->newspaper3k) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.10.0->newspaper3k) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.10.0->newspaper3k) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.10.0->newspaper3k) (2025.10.5)
# Collecting requests-file>=1.4 (from tldextract>=2.0.1->newspaper3k)
#   Downloading requests_file-3.0.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: filelock>=3.0.8 in /usr/local/lib/python3.12/dist-packages (from tldextract>=2.0.1->newspaper3k) (3.20.0)
# Downloading newspaper3k-0.2.8-py3-none-any.whl (211 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.1/211.1 kB 16.1 MB/s eta 0:00:00
# Downloading cssselect-1.3.0-py3-none-any.whl (18 kB)
# Downloading feedparser-6.0.12-py3-none-any.whl (81 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.5/81.5 kB 5.8 MB/s eta 0:00:00
# Downloading tldextract-5.3.0-py3-none-any.whl (107 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.4/107.4 kB 7.9 MB/s eta 0:00:00
# Downloading requests_file-3.0.1-py2.py3-none-any.whl (4.5 kB)
# Building wheels for collected packages: tinysegmenter, feedfinder2, jieba3k, sgmllib3k
#   Building wheel for tinysegmenter (setup.py) ... done
#   Created wheel for tinysegmenter: filename=tinysegmenter-0.3-py3-none-any.whl size=13540 sha256=a7f7fa7cdb84ec1caa8c69d0425faef387bf7e265aa53ed91c451c6f001ead5f
#   Stored in directory: /root/.cache/pip/wheels/a5/91/9f/00d66475960891a64867914273fcaf78df6cb04d905b104a2a
#   Building wheel for feedfinder2 (setup.py) ... done
#   Created wheel for feedfinder2: filename=feedfinder2-0.0.4-py3-none-any.whl size=3341 sha256=9aa42201b13fdf8d0732cd8b14ddcaedb9324b61097ab249c3e08ba7486af0f4
#   Stored in directory: /root/.cache/pip/wheels/9f/9f/fb/364871d7426d3cdd4d293dcf7e53d97f160c508b2ccf00cc79
#   Building wheel for jieba3k (setup.py) ... done
#   Created wheel for jieba3k: filename=jieba3k-0.35.1-py3-none-any.whl size=7398380 sha256=26052ee6c69afbba2ba21c2b723a2260c7f2943defdc12732fa595a033e5f7da
#   Stored in directory: /root/.cache/pip/wheels/26/72/f7/fff392a8d4ea988dea4ccf9788599d09462a7f5e51e04f8a92
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6046 sha256=7d63b922a720ffcc21949f1f86310b35ab57fe1f7820fac5854dbfe218c3a988
#   Stored in directory: /root/.cache/pip/wheels/03/f5/1a/23761066dac1d0e8e683e5fdb27e12de53209d05a4a37e6246
# Successfully built tinysegmenter feedfinder2 jieba3k sgmllib3k
# Installing collected packages: tinysegmenter, sgmllib3k, jieba3k, feedparser, cssselect, requests-file, feedfinder2, tldextract, newspaper3k
# Successfully installed cssselect-1.3.0 feedfinder2-0.0.4 feedparser-6.0.12 jieba3k-0.35.1 newspaper3k-0.2.8 requests-file-3.0.1 sgmllib3k-1.0.0 tinysegmenter-0.3 tldextract-5.3.0
# Collecting selenium
#   Downloading selenium-4.38.0-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: urllib3<3.0,>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from urllib3[socks]<3.0,>=2.5.0->selenium) (2.5.0)
# Collecting trio<1.0,>=0.31.0 (from selenium)
#   Downloading trio-0.32.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting trio-websocket<1.0,>=0.12.2 (from selenium)
#   Downloading trio_websocket-0.12.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: certifi>=2025.10.5 in /usr/local/lib/python3.12/dist-packages (from selenium) (2025.10.5)
# Requirement already satisfied: typing_extensions<5.0,>=4.15.0 in /usr/local/lib/python3.12/dist-packages (from selenium) (4.15.0)
# Requirement already satisfied: websocket-client<2.0,>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from selenium) (1.9.0)
# Requirement already satisfied: attrs>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from trio<1.0,>=0.31.0->selenium) (25.4.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.12/dist-packages (from trio<1.0,>=0.31.0->selenium) (2.4.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from trio<1.0,>=0.31.0->selenium) (3.11)
# Collecting outcome (from trio<1.0,>=0.31.0->selenium)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: sniffio>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from trio<1.0,>=0.31.0->selenium) (1.3.1)
# Collecting wsproto>=0.14 (from trio-websocket<1.0,>=0.12.2->selenium)
#   Downloading wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from urllib3[socks]<3.0,>=2.5.0->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from wsproto>=0.14->trio-websocket<1.0,>=0.12.2->selenium) (0.16.0)
# Downloading selenium-4.38.0-py3-none-any.whl (9.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 63.7 MB/s eta 0:00:00
# Downloading trio-0.32.0-py3-none-any.whl (512 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 512.0/512.0 kB 32.8 MB/s eta 0:00:00
# Downloading trio_websocket-0.12.2-py3-none-any.whl (21 kB)
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Installing collected packages: wsproto, outcome, trio, trio-websocket, selenium
# Successfully installed outcome-1.3.0.post0 selenium-4.38.0 trio-0.32.0 trio-websocket-0.12.2 wsproto-1.2.0
# Requirement already satisfied: openai in /usr/local/lib/python3.12/dist-packages (1.109.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from openai) (0.11.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from openai) (2.11.10)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.12/dist-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Collecting serpapi
#   Downloading serpapi-0.1.5-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from serpapi) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->serpapi) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->serpapi) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->serpapi) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->serpapi) (2025.10.5)
# Downloading serpapi-0.1.5-py2.py3-none-any.whl (10 kB)
# Installing collected packages: serpapi
# Successfully installed serpapi-0.1.5
# Collecting GoogleNews
#   Downloading GoogleNews-1.6.15-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from GoogleNews) (4.13.5)
# Collecting dateparser (from GoogleNews)
#   Downloading dateparser-1.2.2-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (from GoogleNews) (2.9.0.post0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->GoogleNews) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->GoogleNews) (4.15.0)
# Requirement already satisfied: pytz>=2024.2 in /usr/local/lib/python3.12/dist-packages (from dateparser->GoogleNews) (2025.2)
# Requirement already satisfied: regex>=2024.9.11 in /usr/local/lib/python3.12/dist-packages (from dateparser->GoogleNews) (2024.11.6)
# Requirement already satisfied: tzlocal>=0.2 in /usr/local/lib/python3.12/dist-packages (from dateparser->GoogleNews) (5.3.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil->GoogleNews) (1.17.0)
# Downloading GoogleNews-1.6.15-py3-none-any.whl (8.8 kB)
# Downloading dateparser-1.2.2-py3-none-any.whl (315 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 315.5/315.5 kB 7.3 MB/s eta 0:00:00
# Installing collected packages: dateparser, GoogleNews
# Successfully installed GoogleNews-1.6.15 dateparser-1.2.2
# Collecting googlesearch-python
#   Downloading googlesearch_python-1.3.0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: beautifulsoup4>=4.9 in /usr/local/lib/python3.12/dist-packages (from googlesearch-python) (4.13.5)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.12/dist-packages (from googlesearch-python) (2.32.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.9->googlesearch-python) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.9->googlesearch-python) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.20->googlesearch-python) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.20->googlesearch-python) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.20->googlesearch-python) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.20->googlesearch-python) (2025.10.5)
# Downloading googlesearch_python-1.3.0-py3-none-any.whl (5.6 kB)
# Installing collected packages: googlesearch-python
# Successfully installed googlesearch-python-1.3.0
# Collecting google-search-results
#   Downloading google_search_results-2.4.2.tar.gz (18 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from google-search-results) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->google-search-results) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->google-search-results) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->google-search-results) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->google-search-results) (2025.10.5)
# Building wheels for collected packages: google-search-results
#   Building wheel for google-search-results (setup.py) ... done
#   Created wheel for google-search-results: filename=google_search_results-2.4.2-py3-none-any.whl size=32010 sha256=03b8403d2ec8fe4d350a6a95356846b54933fd564a3ba7fc6ff66b3c5844b1eb
#   Stored in directory: /root/.cache/pip/wheels/0c/47/f5/89b7e770ab2996baf8c910e7353d6391e373075a0ac213519e
# Successfully built google-search-results
# Installing collected packages: google-search-results
# Successfully installed google-search-results-2.4.2
# ERROR: Could not find a version that satisfies the requirement concurrent.futures (from versions: none)
# ERROR: No matching distribution found for concurrent.futures
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (5.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# ERROR: Could not find a version that satisfies the requirement json (from versions: none)
# ERROR: No matching distribution found for json
# Requirement already satisfied: httpx[http2] in /usr/local/lib/python3.12/dist-packages (0.28.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx[http2]) (4.11.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx[http2]) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx[http2]) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx[http2]) (3.11)
# Requirement already satisfied: h2<5,>=3 in /usr/local/lib/python3.12/dist-packages (from httpx[http2]) (4.3.0)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx[http2]) (0.16.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in /usr/local/lib/python3.12/dist-packages (from h2<5,>=3->httpx[http2]) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /usr/local/lib/python3.12/dist-packages (from h2<5,>=3->httpx[http2]) (4.1.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx[http2]) (1.3.1)
# Requirement already satisfied: typing_extensions>=4.5 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx[http2]) (4.15.0)
# Requirement already satisfied: lxml[html_clean] in /usr/local/lib/python3.12/dist-packages (5.4.0)
# Collecting lxml_html_clean (from lxml[html_clean])
#   Downloading lxml_html_clean-0.4.3-py3-none-any.whl.metadata (2.3 kB)
# Downloading lxml_html_clean-0.4.3-py3-none-any.whl (14 kB)
# Installing collected packages: lxml_html_clean
# Successfully installed lxml_html_clean-0.4.3

# %%
import re
from dateutil import parser
from tabulate import tabulate
import pandas as pd
import requests
from bs4 import BeautifulSoup
from urllib.parse import quote_plus
import time
import random
from datetime import datetime
from GoogleNews import GoogleNews
from serpapi import GoogleSearch
import pandas as pd
from openai import OpenAI
import json

# %%
# ================================================================
# Keys
# ================================================================

SerpAPI_tkn1= "72ce14c7c062bc7f84a14cdaad42d0773fe66be22644e6addfa422cce5d12417"
OPENAI_API_KEY = "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"
SESSION = requests.Session()
SESSION.headers.update({'User-Agent': 'Mozilla/5.0 (compatible; EduNews/3.1)'})
SESSION_TIMEOUT = 15
client = OpenAI(api_key=OPENAI_API_KEY)

# %%
# ================================================================
# EXTENDIDO
# ================================================================
HEADERS = {'User-Agent': 'Mozilla/5.0'}
TIMEOUT = 10
MAX_RESULTS = 300
YEAR = "2019"

def link_valido(url):
    try:
        r = requests.head(url, timeout=5, allow_redirects=True)
        return r.status_code == 200
    except:
        return False


# ================================================================
#  SCRAPING DE FUENTES ESPECÍFICAS
# ================================================================
def buscar_noticias_generales(nombre_fuente, url_base, termino_busqueda, max_resultados=150):
    """Scrapea noticias desde sitios como El Tiempo, ADE o FECODE."""
    print(f"\n🔍 Buscando en {nombre_fuente}: {termino_busqueda}")
    datos = []
    termino_codificado = quote_plus(termino_busqueda)
    url_busqueda = f"{url_base}{termino_codificado}"

    headers = {'User-Agent': 'Mozilla/5.0'}

    try:
        response = requests.get(url_busqueda, headers=headers, timeout=20)
        response.raise_for_status()
        soup = BeautifulSoup(response.content, 'html.parser')

        articulos = soup.find_all('article', limit=max_resultados)
        print(f"Encontrados {len(articulos)} artículos en {nombre_fuente}")

        for art in articulos:
            titulo = (art.find('h2') or art.find('h3'))
            enlace = art.find('a', href=True)

            if not titulo or not enlace:
                continue

            link = enlace['href']
            if not link.startswith('http'):
                link = f"{url_base.rstrip('/')}/{link.lstrip('/')}"

            if not link_valido(link):
                continue

            descripcion = art.find('p').get_text(strip=True) if art.find('p') else ''
            fecha_elem = art.find('time')
            fecha = fecha_elem.get_text(strip=True) if fecha_elem else 'No especificada'

            datos.append({
                'fuente': nombre_fuente,
                'titulo': titulo.get_text(strip=True),
                'descripcion': descripcion,
                'fecha_publicacion': fecha,
                'url': link,
                'periodo_busqueda': termino_busqueda,
                'fecha_extraccion': datetime.now().strftime('%Y-%m-%d %H:%M:%S')
            })

    except Exception as e:
        print(f"❌ Error en {nombre_fuente}: {e}")

    time.sleep(random.uniform(1.5, 3.5))
    return datos


# ================================================================
#  GOOGLE NEWS
# ================================================================
def buscar_con_googlenews():
    googlenews = GoogleNews(lang='es', encode='utf-8')
    googlenews.set_time_range('01/01/2019', '01/01/2020')
    resultados = []

    queries = [
        'paro docente Colombia 2019', 'paro maestros Bogotá 2019', 'FECODE paro 2019',
        'huelga de profesores Colombia 2019', 'protestas docentes educación 2019',
        'ADE Bogotá paro 2019', 'magisterio colombiano paro 2019',
        'ministerio educación paro maestros 2019', 'paro educativo nacional Colombia 2019',
        'suspensión de clases por paro docente 2019'
    ]

    for q in queries:
        googlenews.search(q)
        time.sleep(random.uniform(2, 4))
        res = googlenews.result()
        for r in res:
            resultados.append({
                'fuente': r.get('media', 'GoogleNews'),
                'titulo': r.get('title'),
                'descripcion': r.get('desc', ''),
                'url': r.get('link', ''),
                'fecha_publicacion': r.get('date', ''),
                'periodo_busqueda': q,
                'fecha_extraccion': datetime.now().strftime("%Y-%m-%d %H:%M:%S")
            })
    print(f"✅ GoogleNews: {len(resultados)} resultados")
    return resultados


# ================================================================
#  SERPAPI
# ================================================================
def buscar_con_serpapi(api_key):
    print("\n🔍 Buscando con SerpAPI...")
    resultados = []
    queries = [
        '(paro docente OR paro maestros OR huelga profesores OR FECODE OR ADE) Colombia 2019',
        '(paro educativo OR suspensión clases) Bogotá 2019',
        '(FECODE protesta OR paro) Colombia 2019',
        '(magisterio colombiano OR sindicato maestros) paro 2019',
    ]

    for query in queries:
        params = {
            "engine": "google",
            "q": f"{query} after:2019-01-01 before:2020-01-01",
            "api_key": api_key,
            "num": 190
        }
        try:
            search = GoogleSearch(params)
            results = search.get_dict()
            items = results.get("organic_results", [])
            for item in items:
                resultados.append({
                    'fuente': 'Google (SerpAPI)',
                    'titulo': item.get('title'),
                    'descripcion': item.get('snippet', ''),
                    'url': item.get('link'),
                    'fecha_publicacion': '',
                    'periodo_busqueda': query,
                    'fecha_extraccion': datetime.now().strftime("%Y-%m-%d %H:%M:%S")
                })
        except Exception as e:
            print(f"❌ Error en SerpAPI: {e}")
            time.sleep(random.uniform(1, 2))
    print(f" SerpAPI: {len(resultados)} resultados")
    return resultados

# ================================================================
#  EJECUCIÓN PRINCIPAL
# ================================================================

if __name__ == "__main__":
    print("="*60)
    print(" INICIANDO SCRAPER + ANÁLISIS IA")
    print("="*60)

    resultados_totales = []

    # 1) Fuentes oficiales primero
    print("\n FASE 1: Recopilando noticias...")

    fuentes = {
        "El Tiempo": "https://www.eltiempo.com/buscar/",
        "El Espectador": "https://www.elespectador.com/buscador/",
        "FECODE": "https://fecode.edu.co/?s=",
        "ADE Bogotá": "https://adebogota.org/index.php/buscar?q=",
        "SED": "https://www.educacionbogota.edu.co/noticias?field_noticia_descripcion_value=",
        "Bogota.gov": "https://bogota.gov.co/tag/ingreso-minimo-garantizado?search_api_fulltext=",
        "Caracol" : "https://www.noticiascaracol.com/busqueda?q=",
        "Valora Analitik" : "https://www.valoraanalitik.com/?s=",
        "Portafolio": "https://www.portafolio.co/buscar?q=",
    }
    terminos = [
        "paro docentes", "paro maestros", "suspensión de clases 2016",
        "cese de actividades escolares 2016", "FECODE 2016", "huelga de profesores",
        "protesta docente 2016"
    ]
    for fuente, url_base in fuentes.items():
        for termino in terminos:
            resultados_totales.extend(
                buscar_noticias_generales(fuente, url_base, termino)
            )
            time.sleep(random.uniform(2, 4))

   # 2) GoogleNews y SerpAPI
    resultados_totales.extend(buscar_con_googlenews())
    resultados_totales.extend(buscar_con_serpapi(SerpAPI_tkn1))

    df = pd.DataFrame(resultados_totales).drop_duplicates(subset="url")
    df.to_csv("noticias_paros_docentes_2019_SUPER.csv", index=False, encoding="utf-8-sig")

    print(f"\n✅ Total de noticias recopiladas: {len(resultados_totales)}")
# Out:
# ============================================================
#  INICIANDO SCRAPER + ANÁLISIS IA
# ============================================================
#
#  FASE 1: Recopilando noticias...
#
# 🔍 Buscando en El Tiempo: paro docentes
# Encontrados 20 artículos en El Tiempo
#
# 🔍 Buscando en El Tiempo: paro maestros
# Encontrados 20 artículos en El Tiempo
#
# 🔍 Buscando en El Tiempo: suspensión de clases 2016
# Encontrados 20 artículos en El Tiempo
#
# 🔍 Buscando en El Tiempo: cese de actividades escolares 2016
# Encontrados 20 artículos en El Tiempo
#
# 🔍 Buscando en El Tiempo: FECODE 2016
# Encontrados 20 artículos en El Tiempo
#
# 🔍 Buscando en El Tiempo: huelga de profesores
# Encontrados 20 artículos en El Tiempo
#
# 🔍 Buscando en El Tiempo: protesta docente 2016
# Encontrados 20 artículos en El Tiempo
#
# 🔍 Buscando en El Espectador: paro docentes
# Encontrados 0 artículos en El Espectador
#
# 🔍 Buscando en El Espectador: paro maestros
# Encontrados 0 artículos en El Espectador
#
# 🔍 Buscando en El Espectador: suspensión de clases 2016
# Encontrados 0 artículos en El Espectador
#
# 🔍 Buscando en El Espectador: cese de actividades escolares 2016
# Encontrados 0 artículos en El Espectador
#
# 🔍 Buscando en El Espectador: FECODE 2016
# Encontrados 0 artículos en El Espectador
#
# 🔍 Buscando en El Espectador: huelga de profesores
# Encontrados 0 artículos en El Espectador
#
# 🔍 Buscando en El Espectador: protesta docente 2016
# Encontrados 0 artículos en El Espectador
#
# 🔍 Buscando en FECODE: paro docentes
# Encontrados 4 artículos en FECODE
#
# 🔍 Buscando en FECODE: paro maestros
# Encontrados 2 artículos en FECODE
#
# 🔍 Buscando en FECODE: suspensión de clases 2016
# Encontrados 0 artículos en FECODE
#
# 🔍 Buscando en FECODE: cese de actividades escolares 2016
# Encontrados 0 artículos en FECODE
#
# 🔍 Buscando en FECODE: FECODE 2016
# Encontrados 1 artículos en FECODE
#
# 🔍 Buscando en FECODE: huelga de profesores
# Encontrados 0 artículos en FECODE
#
# 🔍 Buscando en FECODE: protesta docente 2016
# Encontrados 0 artículos en FECODE
#
# 🔍 Buscando en ADE Bogotá: paro docentes
# Encontrados 0 artículos en ADE Bogotá
#
# 🔍 Buscando en ADE Bogotá: paro maestros
# Encontrados 0 artículos en ADE Bogotá
#
# 🔍 Buscando en ADE Bogotá: suspensión de clases 2016
# Encontrados 0 artículos en ADE Bogotá
#
# 🔍 Buscando en ADE Bogotá: cese de actividades escolares 2016
# Encontrados 0 artículos en ADE Bogotá
#
# 🔍 Buscando en ADE Bogotá: FECODE 2016
# Encontrados 0 artículos en ADE Bogotá
#
# 🔍 Buscando en ADE Bogotá: huelga de profesores
# Encontrados 0 artículos en ADE Bogotá
#
# 🔍 Buscando en ADE Bogotá: protesta docente 2016
# Encontrados 0 artículos en ADE Bogotá
#
# 🔍 Buscando en SED: paro docentes
# Encontrados 0 artículos en SED
#
# 🔍 Buscando en SED: paro maestros
# Encontrados 0 artículos en SED
#
# 🔍 Buscando en SED: suspensión de clases 2016
# Encontrados 0 artículos en SED
#
# 🔍 Buscando en SED: cese de actividades escolares 2016
# Encontrados 0 artículos en SED
#
# 🔍 Buscando en SED: FECODE 2016
# Encontrados 0 artículos en SED
#
# 🔍 Buscando en SED: huelga de profesores
# Encontrados 0 artículos en SED
#
# 🔍 Buscando en SED: protesta docente 2016
# Encontrados 0 artículos en SED
#
# 🔍 Buscando en Bogota.gov: paro docentes
# Encontrados 0 artículos en Bogota.gov
#
# 🔍 Buscando en Bogota.gov: paro maestros
# Encontrados 0 artículos en Bogota.gov
#
# 🔍 Buscando en Bogota.gov: suspensión de clases 2016
# Encontrados 0 artículos en Bogota.gov
#
# 🔍 Buscando en Bogota.gov: cese de actividades escolares 2016
# Encontrados 0 artículos en Bogota.gov
#
# 🔍 Buscando en Bogota.gov: FECODE 2016
# Encontrados 0 artículos en Bogota.gov
#
# 🔍 Buscando en Bogota.gov: huelga de profesores
# Encontrados 0 artículos en Bogota.gov
#
# 🔍 Buscando en Bogota.gov: protesta docente 2016
# Encontrados 0 artículos en Bogota.gov
#
# 🔍 Buscando en Caracol: paro docentes
# Encontrados 0 artículos en Caracol
#
# 🔍 Buscando en Caracol: paro maestros
# Encontrados 0 artículos en Caracol
#
# 🔍 Buscando en Caracol: suspensión de clases 2016
# Encontrados 0 artículos en Caracol
#
# 🔍 Buscando en Caracol: cese de actividades escolares 2016
# Encontrados 0 artículos en Caracol
#
# 🔍 Buscando en Caracol: FECODE 2016
# Encontrados 0 artículos en Caracol
#
# 🔍 Buscando en Caracol: huelga de profesores
# Encontrados 0 artículos en Caracol
#
# 🔍 Buscando en Caracol: protesta docente 2016
# Encontrados 0 artículos en Caracol
#
# 🔍 Buscando en Valora Analitik: paro docentes
# Encontrados 8 artículos en Valora Analitik
#
# 🔍 Buscando en Valora Analitik: paro maestros
# Encontrados 8 artículos en Valora Analitik
#
# 🔍 Buscando en Valora Analitik: suspensión de clases 2016
# Encontrados 0 artículos en Valora Analitik
#
# 🔍 Buscando en Valora Analitik: cese de actividades escolares 2016
# Encontrados 0 artículos en Valora Analitik
#
# 🔍 Buscando en Valora Analitik: FECODE 2016
# Encontrados 4 artículos en Valora Analitik
#
# 🔍 Buscando en Valora Analitik: huelga de profesores
# Encontrados 5 artículos en Valora Analitik
#
# 🔍 Buscando en Valora Analitik: protesta docente 2016
# Encontrados 0 artículos en Valora Analitik
#
# 🔍 Buscando en Portafolio: paro docentes
# Encontrados 20 artículos en Portafolio
#
# 🔍 Buscando en Portafolio: paro maestros
# Encontrados 20 artículos en Portafolio
#
# 🔍 Buscando en Portafolio: suspensión de clases 2016
# Encontrados 20 artículos en Portafolio
#
# 🔍 Buscando en Portafolio: cese de actividades escolares 2016
# Encontrados 20 artículos en Portafolio
#
# 🔍 Buscando en Portafolio: FECODE 2016
# Encontrados 20 artículos en Portafolio
#
# 🔍 Buscando en Portafolio: huelga de profesores
# Encontrados 20 artículos en Portafolio
#
# 🔍 Buscando en Portafolio: protesta docente 2016
# Encontrados 20 artículos en Portafolio
# ✅ GoogleNews: 550 resultados
#
# 🔍 Buscando con SerpAPI...
#  SerpAPI: 40 resultados
#
# ✅ Total de noticias recopiladas: 762

# %%
# ================================================================
# ANÁLISIS CON IA
# ================================================================

def obtener_texto_completo(url):

    try:
        r = requests.get(url, timeout=15)
        r.raise_for_status()
        soup = BeautifulSoup(r.text, "html.parser")

        # Elimina elementos que no son contenido principal
        for s in soup(["script", "style", "noscript", "header", "footer", "aside", "form"]):
            s.extract()

        texto = " ".join(soup.stripped_strings)
        return texto[:8000]  # Máximo 8000 caracteres
    except Exception as e:
        return f"Error al obtener contenido: {e}"


def analizar_con_ia(titulo, descripcion, url):
    """
    🤖 EXPLICACIÓN (LA MÁS IMPORTANTE):
    Esta función envía la noticia a GPT-4 para que la analice siguiendo criterios estrictos.

    PROCESO:
    1. Intenta descargar el contenido completo de la URL
    2. Si falla, usa solo título + descripción, indicame si pudiste o no acceder al URL
    3. Construye un prompt detallado con instrucciones para la IA
    4. Envía el prompt a OpenAI (modelo gpt-4o-mini)
    5. Recibe respuesta en formato JSON
    6. Parsea el JSON y devuelve un diccionario con las características

    CARACTERÍSTICAS QUE ANALIZA:
    - es_paro_docente: ¿Hubo suspensión de clases?
    - organizaciones_sindicales: ¿Qué sindicatos u organizaciones políticas participaron?
    - duracion_dias: ¿Cuántos días duró?
    - ubicacion_bogota: ¿Ocurrió en Bogotá?
    - ubicacion_Colombia: ¿Abarcó todo el territorio Nacional=
    - costo_mencionado: ¿Se habla de costos económicos?
    - fecha_paro: ¿cuál es la fecha exacta del paro (día, mes, año)?
    """
    print(f"  🤖 Analizando: {titulo[:60]}...")

    contenido_completo = obtener_texto_completo(url) if url else ""

    if "Error" in contenido_completo or not contenido_completo:
        texto_analizar = f"Título: {titulo}\nDescripción: {descripcion}"
    else:
        texto_analizar = contenido_completo

    # ============================================
    #  PROMPT IA
    # ============================================
    prompt = f"""
Analiza la siguiente noticia en español sobre educación, sindicatos o protestas de docentes.

CRITERIOS ESTRICTOS:
- Un **paro docente verdadero** solo existe si hubo suspensión de clases programadas.
- Si fue marcha, manifestación o concentración SIN suspensión de clases, NO es paro.
- Debes explicar tu razonamiento.

Devuelve un JSON con estas claves:

- "es_paro_docente": true/false → true solo si hubo suspensión de clases
- "justificacion_paro": texto breve (2-4 líneas) explicando por qué es o no un paro
- "organizaciones_sindicales": lista de sindicatos mencionados u organizaciones políticas o partidos políticos (ej: ["FECODE", "ADE"]), o []
- "hay_suspension_clases": true/false → si se suspendieron clases
- "duracion_dias": número de días estimados, o null
- "razones_paro": resumen de las demandas principales
- "ubicacion_bogota": true/false → si ocurre en Bogotá/Cundinamarca
- "ubicacion_Colombia": true/false → si el paro abarca el territorio Nacional
- "costo_mencionado": monto económico si se menciona, o null
- "resumen": breve resumen (máx. 3 líneas)
- "fecha_paro": fecha exacta o estimada del paro (en formato ISO: YYYY-MM-DD).
   Si no se menciona explícitamente, intenta inferirla a partir del texto:
   por ejemplo, si dice "este jueves" o "la semana pasada",
   dedúcela usando la fecha de publicación o el contexto temporal.
   Si no se puede deducir con precisión, deja null.
- "tipo_movilizacion": ¿cuál es el tipo de movilización, paro docente con las caracteristicas que ya vimos, paro de otro gremio, demostración, plantón, toma, marcha pacífica, etc?
- "ubicacion": además del país y ciudad, podemos identificar localidades? barrios? calles? edificios? colegios específicos o barrios?
Devuelve SOLO el JSON válido, sin texto extra.
- "fuente_oficial": ¿es una fuente oficial de algún sindicato o es media, si es media cual, si es sindicato, cual?

Texto a analizar:
{texto_analizar}
"""

    try:
        # ============================================
        #  API DE OPENAI
        # ============================================

        response = client.chat.completions.create(
            model="gpt-4o-mini",
            temperature=0.1,
            messages=[{"role": "user", "content": prompt}],
        )

        # Extrae el texto de la respuesta
        respuesta_texto = response.choices[0].message.content.strip()

        # ============================================
        # PARSEO DEL JSON
        # ============================================
        # La IA devuelve un JSON como string, lo convertimos a diccionario
        try:
            # Intenta parsear directamente
            analisis = json.loads(respuesta_texto)
        except json.JSONDecodeError:
            # Si falla, busca el JSON dentro de bloques de código ```json```
            if "```json" in respuesta_texto:
                inicio = respuesta_texto.find("```json") + 7
                fin = respuesta_texto.find("```", inicio)
                json_str = respuesta_texto[inicio:fin].strip()
                analisis = json.loads(json_str)
            else:
                # Si todo falla, devuelve valores por defecto
                print("    ⚠️ No se pudo parsear el JSON")
                analisis = {
                    'es_paro_docente': False,
                    'justificacion_paro': 'Error al analizar',
                    'organizaciones_sindicales': [],
                    'hay_suspension_clases': False,
                    'duracion_dias': None,
                    'razones_paro': '',
                    'ubicacion_bogota': False,
                    'ubicacion_Colombia': False,
                    'costo_mencionado': None,
                    'resumen': '',
                    'fecha_paro': None,
                    'tipo_movilizacion': '',
                    'ubicacion': '',
                    'fuente_oficial': ''
                }

        return analisis

    except Exception as e:
        print(f"    ❌ Error en análisis IA: {e}")
        if "insufficient_quota" in str(e):
            print("    Please check your OpenAI API plan and billing details.")
        return {
            'es_paro_docente': False,
            'justificacion_paro': f'Error: {str(e)}',
            'organizaciones_sindicales': [],
            'hay_suspension_clases': False,
            'duracion_dias': None,
            'razones_paro': '',
            'ubicacion_bogota': False,
            'ubicacion_Colombia': False,
            'costo_mencionado': None,
            'resumen': '',
            'fecha_paro': None,
            'tipo_movilizacion': '',
            'ubicacion': '',
            'fuente_oficial': ''
        }


# ================================================================
# 🧹 FASE 1.5: LIMPIEZA Y ELIMINACIÓN DE DUPLICADOS
# ================================================================
print("\n🧹 Eliminando duplicados...")

df = pd.DataFrame(resultados_totales)

df['url_norm'] = df['url'].astype(str).str.strip().str.lower()
df = df.drop_duplicates(subset=['url_norm'], keep='first')

print(f"✅ Total tras eliminar duplicados: {len(df)} noticias únicas\n")

# ================================================================
# FASE 2: ANÁLISIS CON IA
# ================================================================
print("\n🤖 FASE 2: Analizando con IA...")

resultados_finales = []
for i, noticia in enumerate(df.to_dict('records'), 1):
    print(f"\n[{i}/{len(df)}] Analizando: {noticia['titulo'][:80]}")

    analisis = analizar_con_ia(
        noticia['titulo'],
        noticia.get('descripcion', ''),
        noticia.get('url', '')
    )

    noticia.update(analisis)
    resultados_finales.append(noticia)

    # Espera 2 segundos entre llamadas para no saturar la API
    time.sleep(2)

# ================================================================
# FASE 3: GUARDAR RESULTADOS EN CSV
# ================================================================
print("\n💾 FASE 3: Guardando resultados...")

df_final = pd.DataFrame(resultados_finales)

# Reordena columnas para legibilidad
columnas_importantes = [
    'titulo', 'fuente', 'fecha_publicacion', 'url',
    'es_paro_docente', 'hay_suspension_clases', 'ubicacion_bogota',
    'ubicacion_Colombia', 'duracion_dias', 'organizaciones_sindicales',
    'razones_paro', 'costo_mencionado', 'justificacion_paro', 'resumen',
    'fecha_paro', 'tipo_movilizacion', 'ubicacion',
    'descripcion', 'periodo_busqueda', 'fecha_extraccion', 'fuente_oficial'
]

columnas_finales = [col for col in columnas_importantes if col in df_final.columns]
df_final = df_final[columnas_finales]

# Guarda CSV final
nombre_archivo = "noticias_paros_docentes_2016_ANALIZADO.csv"
df_final.to_csv(nombre_archivo, index=False, encoding="utf-8-sig")

print(f"✅ Archivo guardado: {nombre_archivo}")
print(f"📊 Total de noticias analizadas: {len(df_final)}")

# ================================================================
# 🧹 FASE 2.5: UNIFICAR FORMATO DE FECHAS Y FILTRAR EVENTOS
# ================================================================
print("\n📅 Normalizando formato de fechas y filtrando eventos relevantes...")

def parse_fecha(fecha):
    if pd.isna(fecha) or str(fecha).strip() == "":
        return None
    for fmt in ("%Y-%m-%d", "%d/%m/%Y", "%d-%m-%Y", "%B %d, %Y", "%d %b %Y"):
        try:
            return pd.to_datetime(fecha, format=fmt, errors='coerce')
        except Exception:
            continue
    return pd.to_datetime(fecha, errors='coerce')

df_final['fecha_paro'] = df_final['fecha_paro'].apply(parse_fecha)
df_final['fecha_paro'] = df_final['fecha_paro'].dt.strftime('%Y-%m-%d')

df_filtrado = df_final[
    ((df_final['es_paro_docente'] == True) | (df_final['hay_suspension_clases'] == True))
    & ((df_final['ubicacion_bogota'] == True) | (df_final['ubicacion_Colombia'] == True))
].copy()

print(f"✅ Total de eventos filtrados (Colombia/Bogotá): {len(df_filtrado)}")

nombre_archivo_filtrado = "web_noticias_paros_docentes_2019.csv"
df_filtrado.to_csv(nombre_archivo_filtrado, index=False, encoding="utf-8-sig")
print(f"📁 Archivo filtrado guardado: {nombre_archivo_filtrado}")

# ================================================================
# ESTADÍSTICAS FINALES
# ================================================================
print("\n" + "="*60)
print("📈 ESTADÍSTICAS DEL ANÁLISIS")
print("="*60)

paros_verdaderos = df_final[df_final['es_paro_docente'] == True]
print(f"🔴 Paros verdaderos (con suspensión de clases): {len(paros_verdaderos)}")

en_bogota = df_final[df_final['ubicacion_bogota'] == True]
print(f"📍 Eventos en Bogotá: {len(en_bogota)}")

con_duracion = df_final[df_final['duracion_dias'].notna()]
if len(con_duracion) > 0:
   print(f"⏱️ Duración promedio: {con_duracion['duracion_dias'].mean():.1f} días")

print("\n🎉 ¡Análisis completado!")
# Out:
# 🧹 Eliminando duplicados...
# ✅ Total tras eliminar duplicados: 290 noticias únicas
#
#
# 🤖 FASE 2: Analizando con IA...
#
# [1/290] Analizando: Circulares 2023
#   🤖 Analizando: Circulares 2023...
#
# [2/290] Analizando: Documentos 2025
#   🤖 Analizando: Documentos 2025...
#
# [3/290] Analizando: Circulares 2025
#   🤖 Analizando: Circulares 2025...
#
# [4/290] Analizando: Inicio
#   🤖 Analizando: Inicio...
#
# [5/290] Analizando: Tablas Salariales
#   🤖 Analizando: Tablas Salariales...
#
# [6/290] Analizando: Fecode convoca a paro nacional de 24 horas el próximo 30 de octubre
#   🤖 Analizando: Fecode convoca a paro nacional de 24 horas el próximo 30 de ...
#
# [7/290] Analizando: Gobierno invierte cerca de $130.000 millones en nuevo sistema de salud laboral p
#   🤖 Analizando: Gobierno invierte cerca de $130.000 millones en nuevo sistem...
#
# [8/290] Analizando: Alianza entre Banco de Bogotá y Unicef ha recaudado más de $33.000 millones para
#   🤖 Analizando: Alianza entre Banco de Bogotá y Unicef ha recaudado más de $...
#
# [9/290] Analizando: Trabajadores del sector educación protestarán en Bogotá: denuncian promesas incu
#   🤖 Analizando: Trabajadores del sector educación protestarán en Bogotá: den...
#
# [10/290] Analizando: Los puntos clave de la ley que rediseñará el mapa de competencias entre Nación y
#   🤖 Analizando: Los puntos clave de la ley que rediseñará el mapa de compete...
#
# [11/290] Analizando: Con exposición fotográfica, Aris Mining destaca la riqueza de Marmato, en Caldas
#   🤖 Analizando: Con exposición fotográfica, Aris Mining destaca la riqueza d...
#
# [12/290] Analizando: G8+ de Medellín presenta resultados de investigaciones en Antioquia
#   🤖 Analizando: G8+ de Medellín presenta resultados de investigaciones en An...
#
# [13/290] Analizando: Adjudican a Enlaza 6 proyectos de obras por impuestos de Colombia en 2023
#   🤖 Analizando: Adjudican a Enlaza 6 proyectos de obras por impuestos de Col...
#
# [14/290] Analizando: ¿Cuántos paros de maestros ha habido en 2023 y cómo impactan a la educación en C
#   🤖 Analizando: ¿Cuántos paros de maestros ha habido en 2023 y cómo impactan...
#
# [15/290] Analizando: Paro nacional de maestros este 30 de agosto: ¿Por qué marchan 24 horas?
#   🤖 Analizando: Paro nacional de maestros este 30 de agosto: ¿Por qué marcha...
#
# [16/290] Analizando: ¿Paro de maestros? Fecode anuncia movilizaciones para este 30 de agosto
#   🤖 Analizando: ¿Paro de maestros? Fecode anuncia movilizaciones para este 3...
#
# [17/290] Analizando: Reforma por decreto: Gobierno lanza nuevo modelo de salud y enfrenta reparos del
#   🤖 Analizando: Reforma por decreto: Gobierno lanza nuevo modelo de salud y ...
#
# [18/290] Analizando: ABC del paro que realizará Fecode en Bogotá contra el gobierno Petro
#   🤖 Analizando: ABC del paro que realizará Fecode en Bogotá contra el gobier...
#
# [19/290] Analizando: Marcha de maestros continuó este 29 de marzo, vea el balance de movilidad en Bog
#   🤖 Analizando: Marcha de maestros continuó este 29 de marzo, vea el balance...
#
# [20/290] Analizando: Así está la movilidad en Bogotá con marchas de maestros y de rappitenderos
#   🤖 Analizando: Así está la movilidad en Bogotá con marchas de maestros y de...
#
# [21/290] Analizando: 30 ministros han pasado por el gabinete ministerial de Petro en dos años de Gobi
#   🤖 Analizando: 30 ministros han pasado por el gabinete ministerial de Petro...
#
# [22/290] Analizando: El nuevo proyecto de ley que tramitará el Gobierno Petro y dejará en pausa la re
#   🤖 Analizando: El nuevo proyecto de ley que tramitará el Gobierno Petro y d...
#
# [23/290] Analizando: Continúan marchas en Bogotá este 31 de agosto: estas son las afectaciones viales
#   🤖 Analizando: Continúan marchas en Bogotá este 31 de agosto: estas son las...
#
# [24/290] Analizando: Huelgas contra reformas de Emmanuel Macron en Francia provocan caos en transport
#   🤖 Analizando: Huelgas contra reformas de Emmanuel Macron en Francia provoc...
#
# [25/290] Analizando: Se cae reforma a la educación del gobierno Petro en el Congreso por falta de tie
#   🤖 Analizando: Se cae reforma a la educación del gobierno Petro en el Congr...
#
# [26/290] Analizando: Reforma a la educación: ¿Tambalea otra de las iniciativas del gobierno Petro?
#   🤖 Analizando: Reforma a la educación: ¿Tambalea otra de las iniciativas de...
#
# [27/290] Analizando: Prima de fin de año: esto es lo que recibiría en diciembre si gana un salario mí
#   🤖 Analizando: Prima de fin de año: esto es lo que recibiría en diciembre s...
#
# [28/290] Analizando: Gobierno de EE. UU. será accionista de 'startup' que se enfoca en transformar ti
#   🤖 Analizando: Gobierno de EE. UU. será accionista de 'startup' que se enfo...
#
# [29/290] Analizando: Nasa lanzará misión a Marte con instrumentos diseñados por una universidad de Fl
#   🤖 Analizando: Nasa lanzará misión a Marte con instrumentos diseñados por u...
#
# [30/290] Analizando: Proyecto de nuevo régimen aduanero aumentaría la incertidumbre para los empresar
#   🤖 Analizando: Proyecto de nuevo régimen aduanero aumentaría la incertidumb...
#
# [31/290] Analizando: La empresa Nvidia sube en Wall Street pese al veto de Trump a sus ventas en Chin
#   🤖 Analizando: La empresa Nvidia sube en Wall Street pese al veto de Trump ...
#
# [32/290] Analizando: Anótelo: cómo evitar el fraude al transferir por medio de un código QR
#   🤖 Analizando: Anótelo: cómo evitar el fraude al transferir por medio de un...
#
# [33/290] Analizando: Con reforma laboral, puede pedir gratis atención psicológica a su ARL: cómo hace
#   🤖 Analizando: Con reforma laboral, puede pedir gratis atención psicológica...
#
# [34/290] Analizando: La inversión extranjera directa en minas y canteras cayó 31%, el primer semestre
#   🤖 Analizando: La inversión extranjera directa en minas y canteras cayó 31%...
#
# [35/290] Analizando: CCS hizo un llamado a las empresas a incluir a toda su cadena de valor en la ges
#   🤖 Analizando: CCS hizo un llamado a las empresas a incluir a toda su caden...
#
# [36/290] Analizando: El Monedero: inflación de alimentos vs. su bolsillo, en el caso del arroz o el h
#   🤖 Analizando: El Monedero: inflación de alimentos vs. su bolsillo, en el c...
#
# [37/290] Analizando: Womenize Latam llega al Caribe para impulsar el liderazgo femenino en tecnología
#   🤖 Analizando: Womenize Latam llega al Caribe para impulsar el liderazgo fe...
#
# [38/290] Analizando: Club El Nogal revisará despidos de forma individual, tras mesas con Mintrabajo
#   🤖 Analizando: Club El Nogal revisará despidos de forma individual, tras me...
#
# [39/290] Analizando: Huracán Melissa deja sus primeros estragos, tras su llegada a Jamaica
#   🤖 Analizando: Huracán Melissa deja sus primeros estragos, tras su llegada ...
#
# [40/290] Analizando: Fundación Terpel impacta en la educación de niños en poblaciones en zonas rurale
#   🤖 Analizando: Fundación Terpel impacta en la educación de niños en poblaci...
#
# [41/290] Analizando: ¿Buscando trabajo con estudios básicos? Hay feria de empleo en Bogotá
#   🤖 Analizando: ¿Buscando trabajo con estudios básicos? Hay feria de empleo ...
#
# [42/290] Analizando: Enfriamiento líquido se consolida como la tecnología clave para los centros de d
#   🤖 Analizando: Enfriamiento líquido se consolida como la tecnología clave p...
#
# [43/290] Analizando: Violencia escolar en América Latina y el Caribe: un desafío urgente
#   🤖 Analizando: Violencia escolar en América Latina y el Caribe: un desafío ...
#
# [44/290] Analizando: El costo oculto de la política: cómo la financiación electoral afecta los impues
#   🤖 Analizando: El costo oculto de la política: cómo la financiación elector...
#
# [45/290] Analizando: Dónde hay más informalidad en el mundo y cómo está Colombia
#   🤖 Analizando: Dónde hay más informalidad en el mundo y cómo está Colombia...
#
# [46/290] Analizando: Empresas aseguran que los roles de trabajadores son transformados gracias a la I
#   🤖 Analizando: Empresas aseguran que los roles de trabajadores son transfor...
#
# [47/290] Analizando: Shakira hace historia... otra vez: 'Billboard' reconoce a la artista por su gira
#   🤖 Analizando: Shakira hace historia... otra vez: 'Billboard' reconoce a la...
#
# [48/290] Analizando: Costos de la energía, entre los principales desafíos para la operación de Nestlé
#   🤖 Analizando: Costos de la energía, entre los principales desafíos para la...
#
# [49/290] Analizando: Las oficinas vuelven a llenarse en Bogotá: cae la vacancia y se disparan nuevame
#   🤖 Analizando: Las oficinas vuelven a llenarse en Bogotá: cae la vacancia y...
#
# [50/290] Analizando: ‘El sector vivienda necesita una alianza real entre gobierno, cajas y banca para
#   🤖 Analizando: ‘El sector vivienda necesita una alianza real entre gobierno...
#
# [51/290] Analizando: De superar varias crisis a abrir su tercer restaurante en EE. UU.: el éxito de J
#   🤖 Analizando: De superar varias crisis a abrir su tercer restaurante en EE...
#
# [52/290] Analizando: ‘Uno de cada diez vehículos que han ingresado al parque automotor en Bogotá es 1
#   🤖 Analizando: ‘Uno de cada diez vehículos que han ingresado al parque auto...
#
# [53/290] Analizando: Fabricato: pioneros en circularidad textil en Colombia
#   🤖 Analizando: Fabricato: pioneros en circularidad textil en Colombia...
#
# [54/290] Analizando: Abelardo de la Espriella lanza su candidatura a las elecciones presidenciales de
#   🤖 Analizando: Abelardo de la Espriella lanza su candidatura a las eleccion...
#
# [55/290] Analizando: Cinco claves para entender el debate sobre por qué ya no está de moda tener novi
#   🤖 Analizando: Cinco claves para entender el debate sobre por qué ya no est...
#
# [56/290] Analizando: El robot araña que imprime casas con tierra y busca llevar su tecnología hasta l
#   🤖 Analizando: El robot araña que imprime casas con tierra y busca llevar s...
#
# [57/290] Analizando: ‘El país está prácticamente quebrado y las finanzas públicas están muy mal admin
#   🤖 Analizando: ‘El país está prácticamente quebrado y las finanzas públicas...
#
# [58/290] Analizando: Las inconsistencias técnicas en los planes de comercialidad del campo Sirius, de
#   🤖 Analizando: Las inconsistencias técnicas en los planes de comercialidad ...
#
# [59/290] Analizando: 'Muchas empresas aún están debatiendo entre el potencial de la tecnología y los
#   🤖 Analizando: 'Muchas empresas aún están debatiendo entre el potencial de ...
#
# [60/290] Analizando: 'Un paciente en Colombia se puede demorar más de dos o tres años en acceder a pr
#   🤖 Analizando: 'Un paciente en Colombia se puede demorar más de dos o tres ...
#
# [61/290] Analizando: Inversión climática: agua y saneamiento
#   🤖 Analizando: Inversión climática: agua y saneamiento...
#
# [62/290] Analizando: Arte faraónico: Egipto muestra su tesoro ancestral con la apertura de su Gran Mu
#   🤖 Analizando: Arte faraónico: Egipto muestra su tesoro ancestral con la ap...
#
# [63/290] Analizando: El centro comercial Andino, en Bogotá, anuncia inversión de $50.000 millones par
#   🤖 Analizando: El centro comercial Andino, en Bogotá, anuncia inversión de ...
#
# [64/290] Analizando: Scania Finance Colombia espera cerrar el año con una cartera superior a los $800
#   🤖 Analizando: Scania Finance Colombia espera cerrar el año con una cartera...
#
# [65/290] Analizando: ‘Este año estuvo dos veces por apagarse Bogotá’: ISA Intercolombia
#   🤖 Analizando: ‘Este año estuvo dos veces por apagarse Bogotá’: ISA Interco...
#
# [66/290] Analizando: ¿La campaña de Estados Unidos en el Caribe está 'arruinando' su relación con Col
#   🤖 Analizando: ¿La campaña de Estados Unidos en el Caribe está 'arruinando'...
#
# [67/290] Analizando: Nueva fase de desescalamiento de la guerra comercial entre China y Estados Unido
#   🤖 Analizando: Nueva fase de desescalamiento de la guerra comercial entre C...
#
# [68/290] Analizando: Contraloría alerta déficit en PAE y advierte riesgo para 1,6 millones de estudia
#   🤖 Analizando: Contraloría alerta déficit en PAE y advierte riesgo para 1,6...
#
# [69/290] Analizando: ‘La vivienda social no puede quedar en el olvido’: Grupo Amarilo
#   🤖 Analizando: ‘La vivienda social no puede quedar en el olvido’: Grupo Ama...
#
# [70/290] Analizando: 'Vendemos la mitad de viviendas y desistimientos se duplicaron en gobierno Petro
#   🤖 Analizando: 'Vendemos la mitad de viviendas y desistimientos se duplicar...
#
# [71/290] Analizando: 'Graves riesgos': los incumplimientos de Andrés Carne de Res que llevaron a su c
#   🤖 Analizando: 'Graves riesgos': los incumplimientos de Andrés Carne de Res...
#
# [72/290] Analizando: Polémica por artículo del Presupuesto 2026 que permitiría mover fondos pensional
#   🤖 Analizando: Polémica por artículo del Presupuesto 2026 que permitiría mo...
#
# [73/290] Analizando: Propiedad horizontal y convivencia: así funciona la ley del ruido en el país
#   🤖 Analizando: Propiedad horizontal y convivencia: así funciona la ley del ...
#
# [74/290] Analizando: SIC ordena el cierre inmediato de la empresa de criptos World en Colombia
#   🤖 Analizando: SIC ordena el cierre inmediato de la empresa de criptos Worl...
#
# [75/290] Analizando: Cambios en el gasto del Presupuesto 2026 despiertan dudas en el Congreso
#   🤖 Analizando: Cambios en el gasto del Presupuesto 2026 despiertan dudas en...
#
# [76/290] Analizando: México aprueba Ley Aduanera para combatir la evasión fiscal: ¿de qué trata?
#   🤖 Analizando: México aprueba Ley Aduanera para combatir la evasión fiscal:...
#
# [77/290] Analizando: Controles al gasto, veedurías institucionales y transparencia electoral en el pa
#   🤖 Analizando: Controles al gasto, veedurías institucionales y transparenci...
#
# [78/290] Analizando: Fitch advierte que romper la regla fiscal pasará factura a las calificaciones
#   🤖 Analizando: Fitch advierte que romper la regla fiscal pasará factura a l...
#
# [79/290] Analizando: Los puntos claves para entender el proyecto de ley minera que propone el gobiern
#   🤖 Analizando: Los puntos claves para entender el proyecto de ley minera qu...
#
# [80/290] Analizando: Llega a Colombia el sello Age Friendly para incentivar el empleo senior
#   🤖 Analizando: Llega a Colombia el sello Age Friendly para incentivar el em...
#
# [81/290] Analizando: Colombia canceló la línea de crédito flexible con el FMI
#   🤖 Analizando: Colombia canceló la línea de crédito flexible con el FMI...
#
# [82/290] Analizando: Presupuesto 2026: inician los debates con el fantasma de la 'dictadura fiscal' r
#   🤖 Analizando: Presupuesto 2026: inician los debates con el fantasma de la ...
#
# [83/290] Analizando: Pulso en Ecuador por propuesta de una constituyente: qué está ocurriendo
#   🤖 Analizando: Pulso en Ecuador por propuesta de una constituyente: qué est...
#
# [84/290] Analizando: Datos de Petro sobre educación revelan más alteraciones estadísticas que mejoras
#   🤖 Analizando: Datos de Petro sobre educación revelan más alteraciones esta...
#
# [85/290] Analizando: Colombia se acerca a un apagón: ¿cómo dar el ‘timonazo’ energético?
#   🤖 Analizando: Colombia se acerca a un apagón: ¿cómo dar el ‘timonazo’ ener...
#
# [86/290] Analizando: Análisis: ¿el mundo debe ser más pragmático para la lucha contra el cambio climá
#   🤖 Analizando: Análisis: ¿el mundo debe ser más pragmático para la lucha co...
#
# [87/290] Analizando: Trampas del crecimiento de la productividad en Colombia: reto para las regiones
#   🤖 Analizando: Trampas del crecimiento de la productividad en Colombia: ret...
#
# [88/290] Analizando: Colombia estaría en camino a su quinto año por fuera del rango meta en inflación
#   🤖 Analizando: Colombia estaría en camino a su quinto año por fuera del ran...
#
# [89/290] Analizando: ¿Cuándo salen a vacaciones los colegios e inicia la semana de receso de octubre?
#   🤖 Analizando: ¿Cuándo salen a vacaciones los colegios e inicia la semana d...
#
# [90/290] Analizando: La distorsión de precios y la baja demanda ahogan a las siderúrgicas
#   🤖 Analizando: La distorsión de precios y la baja demanda ahogan a las side...
#
# [91/290] Analizando: Análisis: Colombia avanza lento en la misión de reducir de la pobreza monetaria
#   🤖 Analizando: Análisis: Colombia avanza lento en la misión de reducir de l...
#
# [92/290] Analizando: Ganadería y caña, sectores que más sufren falta de seguridad
#   🤖 Analizando: Ganadería y caña, sectores que más sufren falta de seguridad...
#
# [93/290] Analizando: Radiografía de la educación privada en Colombia: cómo van las finanzas de los co
#   🤖 Analizando: Radiografía de la educación privada en Colombia: cómo van la...
#
# [94/290] Analizando: Y el carbón sigue ahí… Datos que muestran que consumo mundial del mineral va en
#   🤖 Analizando: Y el carbón sigue ahí… Datos que muestran que consumo mundia...
#
# [95/290] Analizando: El tiempo que se pasa en rutas escolares subiría a 190 minutos en 2030
#   🤖 Analizando: El tiempo que se pasa en rutas escolares subiría a 190 minut...
#
# [96/290] Analizando: Análisis: los cambios profundos que viene experimentando Colombia en los últimos
#   🤖 Analizando: Análisis: los cambios profundos que viene experimentando Col...
#
# [97/290] Analizando: Lo que pasó y lo que quedó por fuera de la reforma laboral en su segundo debate
#   🤖 Analizando: Lo que pasó y lo que quedó por fuera de la reforma laboral e...
#
# [98/290] Analizando: Financiación de la biodiversidad en Colombia requiere de más recursos
#   🤖 Analizando: Financiación de la biodiversidad en Colombia requiere de más...
#
# [99/290] Analizando: Promigás busca entrar en la masificación de energía solar
#   🤖 Analizando: Promigás busca entrar en la masificación de energía solar...
#
# [100/290] Analizando: El país que busca prohibir el uso de celulares en los colegios: así es la inicia
#   🤖 Analizando: El país que busca prohibir el uso de celulares en los colegi...
#
# [101/290] Analizando: Cómo es vivir con un trastorno psicopático y no sentir empatía por los demás
#   🤖 Analizando: Cómo es vivir con un trastorno psicopático y no sentir empat...
#
# [102/290] Analizando: ‘De problema a solución’: cómo el desplome de la natalidad puede elevar la educa
#   🤖 Analizando: ‘De problema a solución’: cómo el desplome de la natalidad p...
#
# [103/290] Analizando: Cómo un adolescente se volvió el prisionero más joven por traición en Rusia
#   🤖 Analizando: Cómo un adolescente se volvió el prisionero más joven por tr...
#
# [104/290] Analizando: La Creg convocó subasta de reconfiguración de energía en firme ante alertas de d
#   🤖 Analizando: La Creg convocó subasta de reconfiguración de energía en fir...
#
# [105/290] Analizando: En el diseño de los envases y empaques influye más la psicología del consumidor
#   🤖 Analizando: En el diseño de los envases y empaques influye más la psicol...
#
# [106/290] Analizando: Colombia presenta primer balance nacional sobre niñez migrante
#   🤖 Analizando: Colombia presenta primer balance nacional sobre niñez migran...
#
# [107/290] Analizando: Inspeccionan la sede de Colombia Humana por indagación a la campaña de Petro
#   🤖 Analizando: Inspeccionan la sede de Colombia Humana por indagación a la ...
#
# [108/290] Analizando: Pacientes con enfermedades raras alertan por demoras en diagnóstico y acceso
#   🤖 Analizando: Pacientes con enfermedades raras alertan por demoras en diag...
#
# [109/290] Analizando: Inflación y déficit le seguirán pasando factura a la política monetaria
#   🤖 Analizando: Inflación y déficit le seguirán pasando factura a la polític...
#
# [110/290] Analizando: Anuncio de asamblea constituyente no distrae a los empresarios
#   🤖 Analizando: Anuncio de asamblea constituyente no distrae a los empresari...
#
# [111/290] Analizando: Insonorizar las casas, un negocio que crece por los conciertos
#   🤖 Analizando: Insonorizar las casas, un negocio que crece por los conciert...
#
# [112/290] Analizando: Tasa de interés real: las decisiones que ha tomado el Banco de la República con
#   🤖 Analizando: Tasa de interés real: las decisiones que ha tomado el Banco ...
#
# [113/290] Analizando: Reacciones a propuesta de declarar inexequible la reforma pensional
#   🤖 Analizando: Reacciones a propuesta de declarar inexequible la reforma pe...
#
# [114/290] Analizando: Choque por cifras de mortalidad de las enfermedades huérfanas
#   🤖 Analizando: Choque por cifras de mortalidad de las enfermedades huérfana...
#
# [115/290] Analizando: El pueblo en Colombia que es tranquilo, pero guarda un laberinto de túneles bajo
#   🤖 Analizando: El pueblo en Colombia que es tranquilo, pero guarda un laber...
#
# [116/290] Analizando: Fecoer cuestiona las cifras de inversión al sistema entregadas por el Minsalud
#   🤖 Analizando: Fecoer cuestiona las cifras de inversión al sistema entregad...
#
# [117/290] Analizando: Internacionalizarse o rezagarse: así evoluciona la formación superior de colombi
#   🤖 Analizando: Internacionalizarse o rezagarse: así evoluciona la formación...
#
# [118/290] Analizando: 'Alza de aranceles a carros de Brasil afecta al país': Aconauto
#   🤖 Analizando: 'Alza de aranceles a carros de Brasil afecta al país': Acona...
#
# [119/290] Analizando: La ropa inteligente gana terreno: cómo funciona, qué marcas hay y qué ofrecen
#   🤖 Analizando: La ropa inteligente gana terreno: cómo funciona, qué marcas ...
#
# [120/290] Analizando: Millonario republicano critica agenda comercial de Trump: 'Perdemos todos'
#   🤖 Analizando: Millonario republicano critica agenda comercial de Trump: 'P...
#
# [121/290] Analizando: Futuro del sistema de salud en suspenso mientras se agrava la crisis de paciente
#   🤖 Analizando: Futuro del sistema de salud en suspenso mientras se agrava l...
#
# [122/290] Analizando: Cronología: hechos que han ahondado la crisis en la relación entre Colombia y EE
#   🤖 Analizando: Cronología: hechos que han ahondado la crisis en la relación...
#
# [123/290] Analizando: Así es la flota que los narcos están usando para sacar cocaína de Colombia por e
#   🤖 Analizando: Así es la flota que los narcos están usando para sacar cocaí...
#
# [124/290] Analizando: Eafit celebra los Premios Inspiradores 2025: reconocimiento al liderazgo que tra
#   🤖 Analizando: Eafit celebra los Premios Inspiradores 2025: reconocimiento ...
#
# [125/290] Analizando: La arquitectura: el motor del crecimiento ordenado de las ciudades
#   🤖 Analizando: La arquitectura: el motor del crecimiento ordenado de las ci...
#
# [126/290] Analizando: Famosa psiquiatra y autora Marián Rojas estará en Colombia: cuándo es la cita y
#   🤖 Analizando: Famosa psiquiatra y autora Marián Rojas estará en Colombia: ...
#
# [127/290] Analizando: Inteligencia artificial amenaza el multimillonario negocio de agentes de futboli
#   🤖 Analizando: Inteligencia artificial amenaza el multimillonario negocio d...
#
# [128/290] Analizando: Bloqueo comercial de EE. UU. no sería la razón de la crisis en Cuba, dicen exper
#   🤖 Analizando: Bloqueo comercial de EE. UU. no sería la razón de la crisis ...
#
# [129/290] Analizando: Así es como puede jugar al Mega Millions desde Colombia y ganar premios millonar
#   🤖 Analizando: Así es como puede jugar al Mega Millions desde Colombia y ga...
#
# [130/290] Analizando: Ni Estados Unidos ni Europa: Colombia se parece más a China en esto inesperado
#   🤖 Analizando: Ni Estados Unidos ni Europa: Colombia se parece más a China ...
#
# [131/290] Analizando: En qué ciudad de Colombia es más probable que se vuelva rico en 2026, según la I
#   🤖 Analizando: En qué ciudad de Colombia es más probable que se vuelva rico...
#
# [132/290] Analizando: Cafés de Colombia Expo 2025: una nueva edición llega a Bogotá
#   🤖 Analizando: Cafés de Colombia Expo 2025: una nueva edición llega a Bogot...
#
# [133/290] Analizando: De no creer: el pueblo colombiano donde las casas están pintadas con símbolos se
#   🤖 Analizando: De no creer: el pueblo colombiano donde las casas están pint...
#
# [134/290] Analizando: La profesión que podría hacerle famoso y casi nadie estudia en Colombia, según l
#   🤖 Analizando: La profesión que podría hacerle famoso y casi nadie estudia ...
#
# [135/290] Analizando: Impuesto al consumo: ABC para que entienda cómo funciona este cobro
#   🤖 Analizando: Impuesto al consumo: ABC para que entienda cómo funciona est...
#
# [136/290] Analizando: Javier Cuéllar regresa al FNG como presidente encargado
#   🤖 Analizando: Javier Cuéllar regresa al FNG como presidente encargado...
#
# [137/290] Analizando: Se les hizo el 'milagro': los Brayans en Colombia podrán tener deliciosa oferta
#   🤖 Analizando: Se les hizo el 'milagro': los Brayans en Colombia podrán ten...
#
# [138/290] Analizando: Mercado laboral: el nuevo empleo que dispara los sueldos en la era digital
#   🤖 Analizando: Mercado laboral: el nuevo empleo que dispara los sueldos en ...
#
# [139/290] Analizando: Los recursos de la naturaleza: oportunidades rentables y ambientalmente responsa
#   🤖 Analizando: Los recursos de la naturaleza: oportunidades rentables y amb...
#
# [140/290] Analizando: Educación y empleo juvenil en Colombia: cifras revelan brechas frente a la Ocde
#   🤖 Analizando: Educación y empleo juvenil en Colombia: cifras revelan brech...
#
# [141/290] Analizando: Psicólogo explicó cuáles son las profesiones con mayor presencia de rasgos psico
#   🤖 Analizando: Psicólogo explicó cuáles son las profesiones con mayor prese...
#
# [142/290] Analizando: La historia de Carlos Slim, el magnate que construyó un imperio empresarial
#   🤖 Analizando: La historia de Carlos Slim, el magnate que construyó un impe...
#
# [143/290] Analizando: ‘Las energías renovables apenas alcanzan para cubrir la crisis’: Siemens
#   🤖 Analizando: ‘Las energías renovables apenas alcanzan para cubrir la cris...
#
# [144/290] Analizando: Más de 60 países firman tratado de la ONU contra la ciberdelincuencia, pese a cr
#   🤖 Analizando: Más de 60 países firman tratado de la ONU contra la ciberdel...
#
# [145/290] Analizando: Se agita el debate pensional tras recusación a magistrado que propone tumbar la
#   🤖 Analizando: Se agita el debate pensional tras recusación a magistrado qu...
#
# [146/290] Analizando: Proyecto de decreto sobre portabilidad financiera: esto es lo que usted podría h
#   🤖 Analizando: Proyecto de decreto sobre portabilidad financiera: esto es l...
#
# [147/290] Analizando: Segunda semana del cierre del gobierno en EE. UU.: ¿ya hay acuerdo a la vista?
#   🤖 Analizando: Segunda semana del cierre del gobierno en EE. UU.: ¿ya hay a...
#
# [148/290] Analizando: Cuáles son las carreras que muy pocos eligen estudiar en Colombia, según la IA
#   🤖 Analizando: Cuáles son las carreras que muy pocos eligen estudiar en Col...
#
# [149/290] Analizando: Licencia de paternidad en Colombia podría ser de hasta tres meses
#   🤖 Analizando: Licencia de paternidad en Colombia podría ser de hasta tres ...
#
# [150/290] Analizando: Crece controversia entre Fomag y Así Vamos en Salud por informe sobre régimen es
#   🤖 Analizando: Crece controversia entre Fomag y Así Vamos en Salud por info...
#
# [151/290] Analizando: Déficit del Fomag en 2025 prende alertas sobre sostenibilidad en salud del magis
#   🤖 Analizando: Déficit del Fomag en 2025 prende alertas sobre sostenibilida...
#
# [152/290] Analizando: Precandidatos presidenciales presentan propuestas en materia económica y de segu
#   🤖 Analizando: Precandidatos presidenciales presentan propuestas en materia...
#
# [153/290] Analizando: Los goles con los que Colombia venció a Bolivia 3-0 y clasificó al Mundial 2026
#   🤖 Analizando: Los goles con los que Colombia venció a Bolivia 3-0 y clasif...
#
# [154/290] Analizando: 'Colombia es un motor de crecimiento para la compañía en Latinoamérica': Pandora
#   🤖 Analizando: 'Colombia es un motor de crecimiento para la compañía en Lat...
#
# [155/290] Analizando: ‘El tiempo me dio la razón’
#   🤖 Analizando: ‘El tiempo me dio la razón’...
#
# [156/290] Analizando: Vigencias futuras serían otro camino erróneo para financiar la consulta popular
#   🤖 Analizando: Vigencias futuras serían otro camino erróneo para financiar ...
#
# [157/290] Analizando: Congresistas le piden a Petro concretar la situación del Presupuesto para el 202
#   🤖 Analizando: Congresistas le piden a Petro concretar la situación del Pre...
#
# [158/290] Analizando: Festival Estéreo Pícnic volverá a ser de tres días: fechas y todo lo que se sabe
#   🤖 Analizando: Festival Estéreo Pícnic volverá a ser de tres días: fechas y...
#
# [159/290] Analizando: Así le fue al Ministerio de Ambiente a un año de terminar el gobierno Petro
#   🤖 Analizando: Así le fue al Ministerio de Ambiente a un año de terminar el...
#
# [160/290] Analizando: Plan Nacional de Desarrollo de Petro avanza pero no articula
#   🤖 Analizando: Plan Nacional de Desarrollo de Petro avanza pero no articula...
#
# [161/290] Analizando: Centrales obreras harán paro nacional en 2019
#   🤖 Analizando: Centrales obreras harán paro nacional en 2019...
#
# [162/290] Analizando: Paro de docentes de Eje Cafetero durará 72 horas: marchas en Pereira, Armenia y
#   🤖 Analizando: Paro de docentes de Eje Cafetero durará 72 horas: marchas en...
#
# [163/290] Analizando: Paro Nacional 28 y 29 de mayo en Colombia: quiénes marcharán, ciudades clave y ú
#   🤖 Analizando: Paro Nacional 28 y 29 de mayo en Colombia: quiénes marcharán...
#
# [164/290] Analizando: Paro nacional del 28 y 29 de mayo podría ser un “pulso político” de cara a las e
#   🤖 Analizando: Paro nacional del 28 y 29 de mayo podría ser un “pulso polít...
#
# [165/290] Analizando: El Dato de La Verdad Panamá para hoy sábado 19 de abril de 2025
#   🤖 Analizando: El Dato de La Verdad Panamá para hoy sábado 19 de abril de 2...
#
# [166/290] Analizando: Cambia el calendario escolar | SUSPENDEN las CLASES hasta el 21 de marzo para pr
#   🤖 Analizando: Cambia el calendario escolar | SUSPENDEN las CLASES hasta el...
#
# [167/290] Analizando: El primer gran paro de 2025 en Colombia ya tiene fecha: Los manifestantes asegur
#   🤖 Analizando: El primer gran paro de 2025 en Colombia ya tiene fecha: Los ...
#
# [168/290] Analizando: Marchas hoy 21 de noviembre en Bogotá y Colombia: serán por conmemoración de est
#   🤖 Analizando: Marchas hoy 21 de noviembre en Bogotá y Colombia: serán por ...
#
# [169/290] Analizando: En conmemoración del estallido social, centrales obreras convocaron marchas este
#   🤖 Analizando: En conmemoración del estallido social, centrales obreras con...
#
# [170/290] Analizando: Marchas de Fecode el 21 de noviembre: puntos clave de las manifestaciones en Col
#   🤖 Analizando: Marchas de Fecode el 21 de noviembre: puntos clave de las ma...
#
# [171/290] Analizando: Paro de docentes de Eje Cafetero durará 72 horas: marchas en Pereira, Armenia y
#   🤖 Analizando: Paro de docentes de Eje Cafetero durará 72 horas: marchas en...
#
# [172/290] Analizando: El grave deterioro del servicio de salud para los miembros del magisterio ha dej
#   🤖 Analizando: El grave deterioro del servicio de salud para los miembros d...
#
# [173/290] Analizando: Paro Nacional: ¿Habrá clases en colegios públicos de Bogotá el 28 y 29 de mayo?
#   🤖 Analizando: Paro Nacional: ¿Habrá clases en colegios públicos de Bogotá ...
#
# [174/290] Analizando: Arranca un nuevo paro nacional en Colombia a favor de la consulta popular de Pet
#   🤖 Analizando: Arranca un nuevo paro nacional en Colombia a favor de la con...
#
# [175/290] Analizando: Paro nacional del 28 y 29 de mayo podría ser un “pulso político” de cara a las e
#   🤖 Analizando: Paro nacional del 28 y 29 de mayo podría ser un “pulso polít...
#
# [176/290] Analizando: Docentes protestan en Bogotá por mejores condiciones laborales y de salud | City
#   🤖 Analizando: Docentes protestan en Bogotá por mejores condiciones laboral...
#
# [177/290] Analizando: La salud se consolida como la principal preocupación de los colombianos y desbor
#   🤖 Analizando: La salud se consolida como la principal preocupación de los ...
#
# [178/290] Analizando: El primer gran paro de 2025 en Colombia ya tiene fecha: Los manifestantes asegur
#   🤖 Analizando: El primer gran paro de 2025 en Colombia ya tiene fecha: Los ...
#
# [179/290] Analizando: En conmemoración del estallido social, centrales obreras convocaron marchas este
#   🤖 Analizando: En conmemoración del estallido social, centrales obreras con...
#
# [180/290] Analizando: Marchas 21 noviembre 2024: puntos de encuentro y horarios
#   🤖 Analizando: Marchas 21 noviembre 2024: puntos de encuentro y horarios...
#
# [181/290] Analizando: “Paro nacional de 24 horas el 30 de octubre: el magisterio exige salud digna y f
#   🤖 Analizando: “Paro nacional de 24 horas el 30 de octubre: el magisterio e...
#
# [182/290] Analizando: Paro Nacional 28 y 29 de mayo en Colombia: quiénes marcharán, ciudades clave y ú
#   🤖 Analizando: Paro Nacional 28 y 29 de mayo en Colombia: quiénes marcharán...
#
# [183/290] Analizando: Puntos de encuentro en todo el país para las movilizaciones del 21 de noviembre
#   🤖 Analizando: Puntos de encuentro en todo el país para las movilizaciones ...
#
# [184/290] Analizando: En conmemoración del estallido social, centrales obreras convocaron marchas este
#   🤖 Analizando: En conmemoración del estallido social, centrales obreras con...
#
# [185/290] Analizando: Marchas 21 noviembre 2024: puntos de encuentro y horarios
#   🤖 Analizando: Marchas 21 noviembre 2024: puntos de encuentro y horarios...
#
# [186/290] Analizando: Nueva manifestación en Colombia por el 'estallido social' del 21 de noviembre: p
#   🤖 Analizando: Nueva manifestación en Colombia por el 'estallido social' de...
#
# [187/290] Analizando: La CUT apoyará el paro nacional convocado por Fecode el 12 de junio
#   🤖 Analizando: La CUT apoyará el paro nacional convocado por Fecode el 12 d...
#
# [188/290] Analizando: FECODE convoca paro nacional el 12 de Junio contra la ley estatutaria de educaci
#   🤖 Analizando: FECODE convoca paro nacional el 12 de Junio contra la ley es...
#
# [189/290] Analizando: Se están metiendo a los conjuntos: se cumplen tres años de esa noche
#   🤖 Analizando: Se están metiendo a los conjuntos: se cumplen tres años de e...
#
# [190/290] Analizando: ¿Cuáles serán las rutas del Paro Nacional de este 19 de noviembre en Colombia?
#   🤖 Analizando: ¿Cuáles serán las rutas del Paro Nacional de este 19 de novi...
#
# [191/290] Analizando: Trabajadores del Garrahan y docentes de la UBA marcharon a Plaza de Mayo contra
#   🤖 Analizando: Trabajadores del Garrahan y docentes de la UBA marcharon a P...
#
# [192/290] Analizando: Economía - Huelga de maestros en México: ¿qué exigen y cuál es la respuesta del
#   🤖 Analizando: Economía - Huelga de maestros en México: ¿qué exigen y cuál ...
#
# [193/290] Analizando: Paro nacional del 28 y 29 de mayo podría ser un “pulso político” de cara a las e
#   🤖 Analizando: Paro nacional del 28 y 29 de mayo podría ser un “pulso polít...
#
# [194/290] Analizando: Los maestros mantienen el paro pese a la retirada de la reforma del ISSSTE: “No
#   🤖 Analizando: Los maestros mantienen el paro pese a la retirada de la refo...
#
# [195/290] Analizando: Se suspenden clases en escuelas de Educación Básica estos días de marzo y ésta e
#   🤖 Analizando: Se suspenden clases en escuelas de Educación Básica estos dí...
#
# [196/290] Analizando: El primer gran paro de 2025 en Colombia ya tiene fecha: Los manifestantes asegur
#   🤖 Analizando: El primer gran paro de 2025 en Colombia ya tiene fecha: Los ...
#
# [197/290] Analizando: En conmemoración del estallido social, centrales obreras convocaron marchas este
#   🤖 Analizando: En conmemoración del estallido social, centrales obreras con...
#
# [198/290] Analizando: Por paro estudiantil, suspendieron contratos a más de 1.000 docentes en la Unive
#   🤖 Analizando: Por paro estudiantil, suspendieron contratos a más de 1.000 ...
#
# [199/290] Analizando: Despedidos por vacaciones: miles de empleados de la educación se van al paro en
#   🤖 Analizando: Despedidos por vacaciones: miles de empleados de la educació...
#
# [200/290] Analizando: 154 días de paros de profesores desde 2010 y contando: una lápida al desarrollo
#   🤖 Analizando: 154 días de paros de profesores desde 2010 y contando: una l...
#
# [201/290] Analizando: SNTE Sección 19 exige detener linchamientos públicos contra docentes en Morelos
#   🤖 Analizando: SNTE Sección 19 exige detener linchamientos públicos contra ...
#
# [202/290] Analizando: Paro de docentes de Eje Cafetero durará 72 horas: marchas en Pereira, Armenia y
#   🤖 Analizando: Paro de docentes de Eje Cafetero durará 72 horas: marchas en...
#
# [203/290] Analizando: Docentes anuncian paro nacional para el 18 y 19 de agosto
#   🤖 Analizando: Docentes anuncian paro nacional para el 18 y 19 de agosto...
#
# [204/290] Analizando: Oaxaca: se cumplen 19 años del desalojo de los profesores, aseguran la represión
#   🤖 Analizando: Oaxaca: se cumplen 19 años del desalojo de los profesores, a...
#
# [205/290] Analizando: Régimen de excepción laboral: ¿qué es y por qué la CNTE exige su eliminación?
#   🤖 Analizando: Régimen de excepción laboral: ¿qué es y por qué la CNTE exig...
#
# [206/290] Analizando: Protesta de la CNTE en Mérida hoy: sin respuesta favorable a sus demandas
#   🤖 Analizando: Protesta de la CNTE en Mérida hoy: sin respuesta favorable a...
#
# [207/290] Analizando: Protestas de maestros colapsan calles en los estados este 30 de mayo; derogación
#   🤖 Analizando: Protestas de maestros colapsan calles en los estados este 30...
#
# [208/290] Analizando: ¿Qué piden los maestros de la CNTE para quitar los bloqueos?
#   🤖 Analizando: ¿Qué piden los maestros de la CNTE para quitar los bloqueos?...
#
# [209/290] Analizando: Manifestaciones de la CNTE en la CDMX: ¿Cuánto piden de aumento salarial los mae
#   🤖 Analizando: Manifestaciones de la CNTE en la CDMX: ¿Cuánto piden de aume...
#
# [210/290] Analizando: CNTE, en paro: las protestas de los maestros se extienden por 10 estados
#   🤖 Analizando: CNTE, en paro: las protestas de los maestros se extienden po...
#
# [211/290] Analizando: Paro de taxistas en Bogotá: Manifestaciones bloquearon vías principales y TransM
#   🤖 Analizando: Paro de taxistas en Bogotá: Manifestaciones bloquearon vías ...
#
# [212/290] Analizando: Movilidad 19 de agosto: habilitan paso en Portal de las Américas
#   🤖 Analizando: Movilidad 19 de agosto: habilitan paso en Portal de las Amér...
#
# [213/290] Analizando: Paro de bicitaxistas generó caos en Bogotá: amenazan con quemar buses y llantas
#   🤖 Analizando: Paro de bicitaxistas generó caos en Bogotá: amenazan con que...
#
# [214/290] Analizando: Violenta protesta de bicitaxistas tiene bloqueada la movilidad en Bogotá: estos
#   🤖 Analizando: Violenta protesta de bicitaxistas tiene bloqueada la movilid...
#
# [215/290] Analizando: Los jóvenes del Paro Nacional de 2021 se quejan del Gobierno de Petro: “Si nos q
#   🤖 Analizando: Los jóvenes del Paro Nacional de 2021 se quejan del Gobierno...
#
# [216/290] Analizando: Epa Colombia ya pagó parte de la indemnización por destruir una estación de Tran
#   🤖 Analizando: Epa Colombia ya pagó parte de la indemnización por destruir ...
#
# [217/290] Analizando: Epa Colombia logró acuerdo económico para reparar los daños que ocasionó a Trans
#   🤖 Analizando: Epa Colombia logró acuerdo económico para reparar los daños ...
#
# [218/290] Analizando: Epa Colombia ya pagó parte de indemnización por daños a TransMilenio durante par
#   🤖 Analizando: Epa Colombia ya pagó parte de indemnización por daños a Tran...
#
# [219/290] Analizando: Personería de Bogotá pidió que el paro nacional no se asemeje a las protestas de
#   🤖 Analizando: Personería de Bogotá pidió que el paro nacional no se asemej...
#
# [220/290] Analizando: Epa Colombia respondió a multimillonario pago exigido por vandalizar estación de
#   🤖 Analizando: Epa Colombia respondió a multimillonario pago exigido por va...
#
# [221/290] Analizando: Centrales obreras harán paro nacional en 2019
#   🤖 Analizando: Centrales obreras harán paro nacional en 2019...
#
# [222/290] Analizando: Paro de docentes de Eje Cafetero durará 72 horas: marchas en Pereira, Armenia y
#   🤖 Analizando: Paro de docentes de Eje Cafetero durará 72 horas: marchas en...
#
# [223/290] Analizando: Así va el paro hoy en Medellín: últimas noticias de marchas en directo, vías cer
#   🤖 Analizando: Así va el paro hoy en Medellín: últimas noticias de marchas ...
#
# [224/290] Analizando: Arranca un nuevo paro nacional en Colombia a favor de la consulta popular de Pet
#   🤖 Analizando: Arranca un nuevo paro nacional en Colombia a favor de la con...
#
# [225/290] Analizando: Paro nacional de la CNTE sigue en pie para el 19 de marzo; estas son las vialida
#   🤖 Analizando: Paro nacional de la CNTE sigue en pie para el 19 de marzo; e...
#
# [226/290] Analizando: El primer gran paro de 2025 en Colombia ya tiene fecha: Los manifestantes asegur
#   🤖 Analizando: El primer gran paro de 2025 en Colombia ya tiene fecha: Los ...
#
# [227/290] Analizando: Marcha hacia la Plaza de Bolívar conmemora cinco años del paro nacional
#   🤖 Analizando: Marcha hacia la Plaza de Bolívar conmemora cinco años del pa...
#
# [228/290] Analizando: Marchas hoy 21 de noviembre en Bogotá y Colombia: serán por conmemoración de est
#   🤖 Analizando: Marchas hoy 21 de noviembre en Bogotá y Colombia: serán por ...
#
# [229/290] Analizando: Marchas de Fecode el 21 de noviembre: puntos clave de las manifestaciones en Col
#   🤖 Analizando: Marchas de Fecode el 21 de noviembre: puntos clave de las ma...
#
# [230/290] Analizando: Nueva manifestación en Colombia por el 'estallido social' del 21 de noviembre: p
#   🤖 Analizando: Nueva manifestación en Colombia por el 'estallido social' de...
#
# [231/290] Analizando: Pagos MPPE esto se sabe HOY, 19 de octubre: bonos del Ministerio de Educación y
#   🤖 Analizando: Pagos MPPE esto se sabe HOY, 19 de octubre: bonos del Minist...
#
# [232/290] Analizando: Docentes convocan paro nacional y denuncian abandono del MEC
#   🤖 Analizando: Docentes convocan paro nacional y denuncian abandono del MEC...
#
# [233/290] Analizando: Docentes anuncian paro nacional para el 18 y 19 de agosto
#   🤖 Analizando: Docentes anuncian paro nacional para el 18 y 19 de agosto...
#
# [234/290] Analizando: 50 días sin clases: cronología y cifras del paro del STEG que ha afectado a 340
#   🤖 Analizando: 50 días sin clases: cronología y cifras del paro del STEG qu...
#
# [235/290] Analizando: Joviel Acevedo exige nuevas condiciones para levantar campamento y terminar el p
#   🤖 Analizando: Joviel Acevedo exige nuevas condiciones para levantar campam...
#
# [236/290] Analizando: Gremios docentes se reúnen con el Meduca y el sector empresarial
#   🤖 Analizando: Gremios docentes se reúnen con el Meduca y el sector empresa...
#
# [237/290] Analizando: Huelga del STEG deja 34 días sin clases: no hay calendario que alcance para repo
#   🤖 Analizando: Huelga del STEG deja 34 días sin clases: no hay calendario q...
#
# [238/290] Analizando: Estudiantes en Panamá mejoran en lectura y matemáticas, pese al paro docentes
#   🤖 Analizando: Estudiantes en Panamá mejoran en lectura y matemáticas, pese...
#
# [239/290] Analizando: Mineduc se pronuncia ante anuncio de Asamblea Permanente de parte de STEG
#   🤖 Analizando: Mineduc se pronuncia ante anuncio de Asamblea Permanente de ...
#
# [240/290] Analizando: Primer paro de un gremio docente "grande" contra el gobierno de Axel Kicillof en
#   🤖 Analizando: Primer paro de un gremio docente "grande" contra el gobierno...
#
# [241/290] Analizando: “Montarse en la montaña rusa”: movilización estudiantil en el paro nacional colo
#   🤖 Analizando: “Montarse en la montaña rusa”: movilización estudiantil en e...
#
# [242/290] Analizando: Del vandalismo a disculpas públicas y videos pedagógicos: así reparará ‘Epa Colo
#   🤖 Analizando: Del vandalismo a disculpas públicas y videos pedagógicos: as...
#
# [243/290] Analizando: Paro de docentes de Eje Cafetero durará 72 horas: marchas en Pereira, Armenia y
#   🤖 Analizando: Paro de docentes de Eje Cafetero durará 72 horas: marchas en...
#
# [244/290] Analizando: Cambia el calendario escolar | SUSPENDEN las CLASES hasta el 21 de marzo para pr
#   🤖 Analizando: Cambia el calendario escolar | SUSPENDEN las CLASES hasta el...
#
# [245/290] Analizando: Se suspenden clases en escuelas de Educación Básica estos días de marzo y ésta e
#   🤖 Analizando: Se suspenden clases en escuelas de Educación Básica estos dí...
#
# [246/290] Analizando: Paro nacional de la CNTE sigue en pie para el 19 de marzo; estas son las vialida
#   🤖 Analizando: Paro nacional de la CNTE sigue en pie para el 19 de marzo; e...
#
# [247/290] Analizando: El primer gran paro de 2025 en Colombia ya tiene fecha: Los manifestantes asegur
#   🤖 Analizando: El primer gran paro de 2025 en Colombia ya tiene fecha: Los ...
#
# [248/290] Analizando: El 21 de noviembre de 2019: Paro Nacional y Resistencia Popular
#   🤖 Analizando: El 21 de noviembre de 2019: Paro Nacional y Resistencia Popu...
#
# [249/290] Analizando: Marchas de Fecode el 21 de noviembre: puntos clave de las manifestaciones en Col
#   🤖 Analizando: Marchas de Fecode el 21 de noviembre: puntos clave de las ma...
#
# [250/290] Analizando: Estos son los puntos de las movilizaciones en conmemoración por las protestas de
#   🤖 Analizando: Estos son los puntos de las movilizaciones en conmemoración ...
#
# [251/290] Analizando: Paro de docentes universitarios por la Ley de financiamiento
#   🤖 Analizando: Paro de docentes universitarios por la Ley de financiamiento...
#
# [252/290] Analizando: ¿Habrá clases este viernes 19 de septiembre? La SEP responde
#   🤖 Analizando: ¿Habrá clases este viernes 19 de septiembre? La SEP responde...
#
# [253/290] Analizando: Paro de docentes de Eje Cafetero durará 72 horas: marchas en Pereira, Armenia y
#   🤖 Analizando: Paro de docentes de Eje Cafetero durará 72 horas: marchas en...
#
# [254/290] Analizando: 50 días sin clases: cronología y cifras del paro del STEG que ha afectado a 340
#   🤖 Analizando: 50 días sin clases: cronología y cifras del paro del STEG qu...
#
# [255/290] Analizando: Sindicato de Joviel Acevedo depone medidas y vuelve a las aulas luego de 79 días
#   🤖 Analizando: Sindicato de Joviel Acevedo depone medidas y vuelve a las au...
#
# [256/290] Analizando: Caravanas del STEG complicarán el tránsito en Guatemala este lunes 21; clases si
#   🤖 Analizando: Caravanas del STEG complicarán el tránsito en Guatemala este...
#
# [257/290] Analizando: Joviel Acevedo exige nuevas condiciones para levantar campamento y terminar el p
#   🤖 Analizando: Joviel Acevedo exige nuevas condiciones para levantar campam...
#
# [258/290] Analizando: Dirigencia del STEG se aparta de llamados a paro, pero las aulas siguen vacías
#   🤖 Analizando: Dirigencia del STEG se aparta de llamados a paro, pero las a...
#
# [259/290] Analizando: Huelga del STEG deja 34 días sin clases: no hay calendario que alcance para repo
#   🤖 Analizando: Huelga del STEG deja 34 días sin clases: no hay calendario q...
#
# [260/290] Analizando: Reportan la muerte de un estudiante dentro de la Universidad de Ingeniería y Tec
#   🤖 Analizando: Reportan la muerte de un estudiante dentro de la Universidad...
#
# [261/290] Analizando: Colombia: convocan a profesores públicos a paro nacional
#   🤖 Analizando: Colombia: convocan a profesores públicos a paro nacional...
#
# [262/290] Analizando: Anuncian nuevo paro nacional de maestros
#   🤖 Analizando: Anuncian nuevo paro nacional de maestros...
#
# [263/290] Analizando: 3 factores inéditos que hicieron del 21 de noviembre un ...
#   🤖 Analizando: 3 factores inéditos que hicieron del 21 de noviembre un ......
#
# [264/290] Analizando: Con histórico 'cacerolazo' concluyó el paro nacional contra ...
#   🤖 Analizando: Con histórico 'cacerolazo' concluyó el paro nacional contra ...
#
# [265/290] Analizando: Los líderes de las protestas elevan la presión con un ...
#   🤖 Analizando: Los líderes de las protestas elevan la presión con un ......
#
# [266/290] Analizando: Protestas en Colombia de 2019-2020
#   🤖 Analizando: Protestas en Colombia de 2019-2020...
#
# [267/290] Analizando: Colombia: paro nacional y movilizaciones en todo el país ...
#   🤖 Analizando: Colombia: paro nacional y movilizaciones en todo el país ......
#
# [268/290] Analizando: fecode
#   🤖 Analizando: fecode...
#
# [269/290] Analizando: Habrá paro de maestros el próximo 26 de julio
#   🤖 Analizando: Habrá paro de maestros el próximo 26 de julio...
#
# [270/290] Analizando: En vivo las movilizaciones del paro de maestros convocado ...
#   🤖 Analizando: En vivo las movilizaciones del paro de maestros convocado .....
#
# [271/290] Analizando: Se suspenden clases en instituciones educativas por paro ...
#   🤖 Analizando: Se suspenden clases en instituciones educativas por paro ......
#
# [272/290] Analizando: Colombia: más protestas en vísperas de segundo paro ...
#   🤖 Analizando: Colombia: más protestas en vísperas de segundo paro ......
#
# [273/290] Analizando: Colombia encara séptimo día de protestas con tibia ...
#   🤖 Analizando: Colombia encara séptimo día de protestas con tibia ......
#
# [274/290] Analizando: Suspenden clases en la Universidad Pedagógica por ...
#   🤖 Analizando: Suspenden clases en la Universidad Pedagógica por ......
#
# [275/290] Analizando: Historia, Dignidad y Paro Nacional en Colombia
#   🤖 Analizando: Historia, Dignidad y Paro Nacional en Colombia...
#
# [276/290] Analizando: Las protestas llegan a Colombia: grandes marchas contra ...
#   🤖 Analizando: Las protestas llegan a Colombia: grandes marchas contra ......
#
# [277/290] Analizando: Con 'cacerolazos', cierra jornada caótica de paro nacional
#   🤖 Analizando: Con 'cacerolazos', cierra jornada caótica de paro nacional...
#
# [278/290] Analizando: La marcha no pone en riesgo los acuerdos con el Gobierno
#   🤖 Analizando: La marcha no pone en riesgo los acuerdos con el Gobierno...
#
# [279/290] Analizando: Colombia encara séptimo día de protestas con tibia ...
#   🤖 Analizando: Colombia encara séptimo día de protestas con tibia ......
#
# [280/290] Analizando: PARO 21N. Colombia: paro nacional y movilizaciones este ...
#   🤖 Analizando: PARO 21N. Colombia: paro nacional y movilizaciones este ......
#
# [281/290] Analizando: fecode
#   🤖 Analizando: fecode...
#
# [282/290] Analizando: millones se movilizan en jornada de Paro Nacional
#   🤖 Analizando: millones se movilizan en jornada de Paro Nacional...
#
# [283/290] Analizando: Los paros de FECODE: ¿algún día encontraremos la ...
#   🤖 Analizando: Los paros de FECODE: ¿algún día encontraremos la ......
#
# [284/290] Analizando: fecode - El Paro Nacional del Magisterio de 48 horas se ...
#   🤖 Analizando: fecode - El Paro Nacional del Magisterio de 48 horas se ......
#
# [285/290] Analizando: fecode - Paro Nacional del Magisterio los días 19 y 20 de ...
#   🤖 Analizando: fecode - Paro Nacional del Magisterio los días 19 y 20 de .....
#
# [286/290] Analizando: Fecode anuncia nuevo paro nacional
#   🤖 Analizando: Fecode anuncia nuevo paro nacional...
#
# [287/290] Analizando: Así transcurre el paro de maestros en todo el país
#   🤖 Analizando: Así transcurre el paro de maestros en todo el país...
#
# [288/290] Analizando: Fecode | Cientos de dirigentes de los sindicatos filiales de ...
#   🤖 Analizando: Fecode | Cientos de dirigentes de los sindicatos filiales de...
#
# [289/290] Analizando: 60 AÑOS DE FECODE
#   🤖 Analizando: 60 AÑOS DE FECODE...
#
# [290/290] Analizando: Paro docente - La Izquierda Diario
#   🤖 Analizando: Paro docente - La Izquierda Diario...
#
# 💾 FASE 3: Guardando resultados...
# ✅ Archivo guardado: noticias_paros_docentes_2016_ANALIZADO.csv
# 📊 Total de noticias analizadas: 290
#
# 📅 Normalizando formato de fechas y filtrando eventos relevantes...
# ✅ Total de eventos filtrados (Colombia/Bogotá): 41
# 📁 Archivo filtrado guardado: web_noticias_paros_docentes_2019.csv
#
# ============================================================
# 📈 ESTADÍSTICAS DEL ANÁLISIS
# ============================================================
# 🔴 Paros verdaderos (con suspensión de clases): 56
# 📍 Eventos en Bogotá: 62
# ⏱️ Duración promedio: 9.9 días
#
# 🎉 ¡Análisis completado!
