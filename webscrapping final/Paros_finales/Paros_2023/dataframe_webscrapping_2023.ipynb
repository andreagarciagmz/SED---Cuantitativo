# %%
# !pip install pandas
# !pip install openpyxl
# !pip install requests
# !pip install beautifulsoup4
# !pip install newspaper3k
# !pip install selenium
# !pip install openai
# !pip install serpapi
# !pip install GoogleNews
# !pip install googlesearch-python
# !pip install google-search-results
# !pip install concurrent.futures
# !pip install lxml
# !pip install numpy
# !pip install json
# !pip install "httpx[http2]"
# !pip install "lxml[html_clean]"
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.12/dist-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2025.10.5)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (4.13.5)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (4.15.0)
# Collecting newspaper3k
#   Downloading newspaper3k-0.2.8-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.12/dist-packages (from newspaper3k) (4.13.5)
# Requirement already satisfied: Pillow>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from newspaper3k) (11.3.0)
# Requirement already satisfied: PyYAML>=3.11 in /usr/local/lib/python3.12/dist-packages (from newspaper3k) (6.0.3)
# Collecting cssselect>=0.9.2 (from newspaper3k)
#   Downloading cssselect-1.3.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: lxml>=3.6.0 in /usr/local/lib/python3.12/dist-packages (from newspaper3k) (5.4.0)
# Requirement already satisfied: nltk>=3.2.1 in /usr/local/lib/python3.12/dist-packages (from newspaper3k) (3.9.1)
# Requirement already satisfied: requests>=2.10.0 in /usr/local/lib/python3.12/dist-packages (from newspaper3k) (2.32.4)
# Collecting feedparser>=5.2.1 (from newspaper3k)
#   Downloading feedparser-6.0.12-py3-none-any.whl.metadata (2.7 kB)
# Collecting tldextract>=2.0.1 (from newspaper3k)
#   Downloading tldextract-5.3.0-py3-none-any.whl.metadata (11 kB)
# Collecting feedfinder2>=0.0.4 (from newspaper3k)
#   Downloading feedfinder2-0.0.4.tar.gz (3.3 kB)
#   Preparing metadata (setup.py) ... done
# Collecting jieba3k>=0.35.1 (from newspaper3k)
#   Downloading jieba3k-0.35.1.zip (7.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 56.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.12/dist-packages (from newspaper3k) (2.9.0.post0)
# Collecting tinysegmenter==0.3 (from newspaper3k)
#   Downloading tinysegmenter-0.3.tar.gz (16 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.4.1->newspaper3k) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.4.1->newspaper3k) (4.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from feedfinder2>=0.0.4->newspaper3k) (1.17.0)
# Collecting sgmllib3k (from feedparser>=5.2.1->newspaper3k)
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk>=3.2.1->newspaper3k) (8.3.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk>=3.2.1->newspaper3k) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk>=3.2.1->newspaper3k) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk>=3.2.1->newspaper3k) (4.67.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.10.0->newspaper3k) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.10.0->newspaper3k) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.10.0->newspaper3k) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.10.0->newspaper3k) (2025.10.5)
# Collecting requests-file>=1.4 (from tldextract>=2.0.1->newspaper3k)
#   Downloading requests_file-3.0.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: filelock>=3.0.8 in /usr/local/lib/python3.12/dist-packages (from tldextract>=2.0.1->newspaper3k) (3.20.0)
# Downloading newspaper3k-0.2.8-py3-none-any.whl (211 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.1/211.1 kB 1.7 MB/s eta 0:00:00
# Downloading cssselect-1.3.0-py3-none-any.whl (18 kB)
# Downloading feedparser-6.0.12-py3-none-any.whl (81 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.5/81.5 kB 5.8 MB/s eta 0:00:00
# Downloading tldextract-5.3.0-py3-none-any.whl (107 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.4/107.4 kB 7.8 MB/s eta 0:00:00
# Downloading requests_file-3.0.1-py2.py3-none-any.whl (4.5 kB)
# Building wheels for collected packages: tinysegmenter, feedfinder2, jieba3k, sgmllib3k
#   Building wheel for tinysegmenter (setup.py) ... done
#   Created wheel for tinysegmenter: filename=tinysegmenter-0.3-py3-none-any.whl size=13540 sha256=500f561aad0c54dc50b836238f269d736c817258d75b68e39d1e35d1d5961ba6
#   Stored in directory: /root/.cache/pip/wheels/a5/91/9f/00d66475960891a64867914273fcaf78df6cb04d905b104a2a
#   Building wheel for feedfinder2 (setup.py) ... done
#   Created wheel for feedfinder2: filename=feedfinder2-0.0.4-py3-none-any.whl size=3341 sha256=4c0ea0516bce7556669e983f17e00f2fafa9fc3c8166af0b3583fd8558c415d3
#   Stored in directory: /root/.cache/pip/wheels/9f/9f/fb/364871d7426d3cdd4d293dcf7e53d97f160c508b2ccf00cc79
#   Building wheel for jieba3k (setup.py) ... done
#   Created wheel for jieba3k: filename=jieba3k-0.35.1-py3-none-any.whl size=7398380 sha256=257fa8232eb5f1f909af32d3af3cca509a4b4fdf764337a094cedc3ac08854d3
#   Stored in directory: /root/.cache/pip/wheels/26/72/f7/fff392a8d4ea988dea4ccf9788599d09462a7f5e51e04f8a92
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6046 sha256=901b67e6fa3bb390d8237eee2578dc973d270dfb3af2b2ae3b82a1545f9e3cec
#   Stored in directory: /root/.cache/pip/wheels/03/f5/1a/23761066dac1d0e8e683e5fdb27e12de53209d05a4a37e6246
# Successfully built tinysegmenter feedfinder2 jieba3k sgmllib3k
# Installing collected packages: tinysegmenter, sgmllib3k, jieba3k, feedparser, cssselect, requests-file, feedfinder2, tldextract, newspaper3k
# Successfully installed cssselect-1.3.0 feedfinder2-0.0.4 feedparser-6.0.12 jieba3k-0.35.1 newspaper3k-0.2.8 requests-file-3.0.1 sgmllib3k-1.0.0 tinysegmenter-0.3 tldextract-5.3.0
# Collecting selenium
#   Downloading selenium-4.38.0-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: urllib3<3.0,>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from urllib3[socks]<3.0,>=2.5.0->selenium) (2.5.0)
# Collecting trio<1.0,>=0.31.0 (from selenium)
#   Downloading trio-0.31.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting trio-websocket<1.0,>=0.12.2 (from selenium)
#   Downloading trio_websocket-0.12.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: certifi>=2025.10.5 in /usr/local/lib/python3.12/dist-packages (from selenium) (2025.10.5)
# Requirement already satisfied: typing_extensions<5.0,>=4.15.0 in /usr/local/lib/python3.12/dist-packages (from selenium) (4.15.0)
# Requirement already satisfied: websocket-client<2.0,>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from selenium) (1.9.0)
# Requirement already satisfied: attrs>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from trio<1.0,>=0.31.0->selenium) (25.4.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.12/dist-packages (from trio<1.0,>=0.31.0->selenium) (2.4.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from trio<1.0,>=0.31.0->selenium) (3.11)
# Collecting outcome (from trio<1.0,>=0.31.0->selenium)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: sniffio>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from trio<1.0,>=0.31.0->selenium) (1.3.1)
# Collecting wsproto>=0.14 (from trio-websocket<1.0,>=0.12.2->selenium)
#   Downloading wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from urllib3[socks]<3.0,>=2.5.0->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from wsproto>=0.14->trio-websocket<1.0,>=0.12.2->selenium) (0.16.0)
# Downloading selenium-4.38.0-py3-none-any.whl (9.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 54.3 MB/s eta 0:00:00
# Downloading trio-0.31.0-py3-none-any.whl (512 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 512.7/512.7 kB 29.9 MB/s eta 0:00:00
# Downloading trio_websocket-0.12.2-py3-none-any.whl (21 kB)
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Installing collected packages: wsproto, outcome, trio, trio-websocket, selenium
# Successfully installed outcome-1.3.0.post0 selenium-4.38.0 trio-0.31.0 trio-websocket-0.12.2 wsproto-1.2.0
# Requirement already satisfied: openai in /usr/local/lib/python3.12/dist-packages (1.109.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from openai) (0.11.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from openai) (2.11.10)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.12/dist-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Collecting serpapi
#   Downloading serpapi-0.1.5-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from serpapi) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->serpapi) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->serpapi) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->serpapi) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->serpapi) (2025.10.5)
# Downloading serpapi-0.1.5-py2.py3-none-any.whl (10 kB)
# Installing collected packages: serpapi
# Successfully installed serpapi-0.1.5
# Collecting GoogleNews
#   Downloading GoogleNews-1.6.15-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from GoogleNews) (4.13.5)
# Collecting dateparser (from GoogleNews)
#   Downloading dateparser-1.2.2-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (from GoogleNews) (2.9.0.post0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->GoogleNews) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->GoogleNews) (4.15.0)
# Requirement already satisfied: pytz>=2024.2 in /usr/local/lib/python3.12/dist-packages (from dateparser->GoogleNews) (2025.2)
# Requirement already satisfied: regex>=2024.9.11 in /usr/local/lib/python3.12/dist-packages (from dateparser->GoogleNews) (2024.11.6)
# Requirement already satisfied: tzlocal>=0.2 in /usr/local/lib/python3.12/dist-packages (from dateparser->GoogleNews) (5.3.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil->GoogleNews) (1.17.0)
# Downloading GoogleNews-1.6.15-py3-none-any.whl (8.8 kB)
# Downloading dateparser-1.2.2-py3-none-any.whl (315 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 315.5/315.5 kB 5.7 MB/s eta 0:00:00
# Installing collected packages: dateparser, GoogleNews
# Successfully installed GoogleNews-1.6.15 dateparser-1.2.2
# Collecting googlesearch-python
#   Downloading googlesearch_python-1.3.0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: beautifulsoup4>=4.9 in /usr/local/lib/python3.12/dist-packages (from googlesearch-python) (4.13.5)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.12/dist-packages (from googlesearch-python) (2.32.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.9->googlesearch-python) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.9->googlesearch-python) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.20->googlesearch-python) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.20->googlesearch-python) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.20->googlesearch-python) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.20->googlesearch-python) (2025.10.5)
# Downloading googlesearch_python-1.3.0-py3-none-any.whl (5.6 kB)
# Installing collected packages: googlesearch-python
# Successfully installed googlesearch-python-1.3.0
# Collecting google-search-results
#   Downloading google_search_results-2.4.2.tar.gz (18 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from google-search-results) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->google-search-results) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->google-search-results) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->google-search-results) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->google-search-results) (2025.10.5)
# Building wheels for collected packages: google-search-results
#   Building wheel for google-search-results (setup.py) ... done
#   Created wheel for google-search-results: filename=google_search_results-2.4.2-py3-none-any.whl size=32010 sha256=7bc21bb47f89c61661b0d7a69d91c63ead24aa5864cf03871affcf943651870e
#   Stored in directory: /root/.cache/pip/wheels/0c/47/f5/89b7e770ab2996baf8c910e7353d6391e373075a0ac213519e
# Successfully built google-search-results
# Installing collected packages: google-search-results
# Successfully installed google-search-results-2.4.2
# ERROR: Could not find a version that satisfies the requirement concurrent.futures (from versions: none)
# ERROR: No matching distribution found for concurrent.futures
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (5.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# ERROR: Could not find a version that satisfies the requirement json (from versions: none)
# ERROR: No matching distribution found for json
# Requirement already satisfied: httpx[http2] in /usr/local/lib/python3.12/dist-packages (0.28.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx[http2]) (4.11.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx[http2]) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx[http2]) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx[http2]) (3.11)
# Requirement already satisfied: h2<5,>=3 in /usr/local/lib/python3.12/dist-packages (from httpx[http2]) (4.3.0)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx[http2]) (0.16.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in /usr/local/lib/python3.12/dist-packages (from h2<5,>=3->httpx[http2]) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /usr/local/lib/python3.12/dist-packages (from h2<5,>=3->httpx[http2]) (4.1.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx[http2]) (1.3.1)
# Requirement already satisfied: typing_extensions>=4.5 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx[http2]) (4.15.0)
# Requirement already satisfied: lxml[html_clean] in /usr/local/lib/python3.12/dist-packages (5.4.0)
# Collecting lxml_html_clean (from lxml[html_clean])
#   Downloading lxml_html_clean-0.4.3-py3-none-any.whl.metadata (2.3 kB)
# Downloading lxml_html_clean-0.4.3-py3-none-any.whl (14 kB)
# Installing collected packages: lxml_html_clean
# Successfully installed lxml_html_clean-0.4.3

# %%
import re
from dateutil import parser
from tabulate import tabulate
import pandas as pd
import requests
from bs4 import BeautifulSoup
from urllib.parse import quote_plus
import time
import random
from datetime import datetime
from GoogleNews import GoogleNews
from serpapi import GoogleSearch
import pandas as pd
from openai import OpenAI
import json

# %%
# ================================================================
# Keys
# ================================================================

SerpAPI_tkn1= ""
OPENAI_API_KEY = ""
SESSION = requests.Session()
SESSION.headers.update({'User-Agent': 'Mozilla/5.0 (compatible; EduNews/3.1)'})
SESSION_TIMEOUT = 15
client = OpenAI(api_key=OPENAI_API_KEY)

# %%
# ================================================================
# EXTENDIDO
# ================================================================
HEADERS = {'User-Agent': 'Mozilla/5.0'}
TIMEOUT = 10
MAX_RESULTS = 300
YEAR = "2023"

def link_valido(url):
    try:
        r = requests.head(url, timeout=5, allow_redirects=True)
        return r.status_code == 200
    except:
        return False


# ================================================================
#  SCRAPING DE FUENTES ESPECÍFICAS
# ================================================================
def buscar_noticias_generales(nombre_fuente, url_base, termino_busqueda, max_resultados=150):
    """Scrapea noticias desde sitios como El Tiempo, ADE o FECODE."""
    print(f"\n🔍 Buscando en {nombre_fuente}: {termino_busqueda}")
    datos = []
    termino_codificado = quote_plus(termino_busqueda)
    url_busqueda = f"{url_base}{termino_codificado}"

    headers = {'User-Agent': 'Mozilla/5.0'}

    try:
        response = requests.get(url_busqueda, headers=headers, timeout=20)
        response.raise_for_status()
        soup = BeautifulSoup(response.content, 'html.parser')

        articulos = soup.find_all('article', limit=max_resultados)
        print(f"Encontrados {len(articulos)} artículos en {nombre_fuente}")

        for art in articulos:
            titulo = (art.find('h2') or art.find('h3'))
            enlace = art.find('a', href=True)

            if not titulo or not enlace:
                continue

            link = enlace['href']
            if not link.startswith('http'):
                link = f"{url_base.rstrip('/')}/{link.lstrip('/')}"

            if not link_valido(link):
                continue

            descripcion = art.find('p').get_text(strip=True) if art.find('p') else ''
            fecha_elem = art.find('time')
            fecha = fecha_elem.get_text(strip=True) if fecha_elem else 'No especificada'

            datos.append({
                'fuente': nombre_fuente,
                'titulo': titulo.get_text(strip=True),
                'descripcion': descripcion,
                'fecha_publicacion': fecha,
                'url': link,
                'periodo_busqueda': termino_busqueda,
                'fecha_extraccion': datetime.now().strftime('%Y-%m-%d %H:%M:%S')
            })

    except Exception as e:
        print(f"❌ Error en {nombre_fuente}: {e}")

    time.sleep(random.uniform(1.5, 3.5))
    return datos


# ================================================================
#  GOOGLE NEWS
# ================================================================
def buscar_con_googlenews():
    googlenews = GoogleNews(lang='es', encode='utf-8')
    googlenews.set_time_range('12/01/2022', '02/01/2024')
    resultados = []

    queries = [
        'paro docente Colombia 2023', 'paro maestros Bogotá 2023', 'FECODE paro 2023',
        'huelga de profesores Colombia 2023', 'protestas docentes educación 2023',
        'ADE Bogotá paro 2023', 'magisterio colombiano paro 2023',
        'ministerio educación paro maestros 2023', 'paro educativo nacional Colombia 2023',
        'suspensión de clases por paro docente 2023'
    ]

    for q in queries:
        googlenews.search(q)
        time.sleep(random.uniform(2, 4))
        res = googlenews.result()
        for r in res:
            resultados.append({
                'fuente': r.get('media', 'GoogleNews'),
                'titulo': r.get('title'),
                'descripcion': r.get('desc', ''),
                'url': r.get('link', ''),
                'fecha_publicacion': r.get('date', ''),
                'periodo_busqueda': q,
                'fecha_extraccion': datetime.now().strftime("%Y-%m-%d %H:%M:%S")
            })
    print(f"✅ GoogleNews: {len(resultados)} resultados")
    return resultados


# ================================================================
#  SERPAPI
# ================================================================
def buscar_con_serpapi(api_key):
    print("\n🔍 Buscando con SerpAPI...")
    resultados = []
    queries = [
        '(paro docente OR paro maestros OR huelga profesores OR FECODE OR ADE) Colombia 2023',
        '(paro educativo OR suspensión clases) Bogotá 2023',
        '(FECODE protesta OR paro) Colombia 2023',
        '(magisterio colombiano OR sindicato maestros) paro 2023',
    ]

    for query in queries:
        params = {
            "engine": "google",
            "q": f"{query} after:2022-12-01 before:2024-02-01",
            "api_key": api_key,
            "num": 190
        }
        try:
            search = GoogleSearch(params)
            results = search.get_dict()
            items = results.get("organic_results", [])
            for item in items:
                resultados.append({
                    'fuente': 'Google (SerpAPI)',
                    'titulo': item.get('title'),
                    'descripcion': item.get('snippet', ''),
                    'url': item.get('link'),
                    'fecha_publicacion': '',
                    'periodo_busqueda': query,
                    'fecha_extraccion': datetime.now().strftime("%Y-%m-%d %H:%M:%S")
                })
        except Exception as e:
            print(f"❌ Error en SerpAPI: {e}")
            time.sleep(random.uniform(1, 2))
    print(f" SerpAPI: {len(resultados)} resultados")
    return resultados

# ================================================================
#  EJECUCIÓN PRINCIPAL
# ================================================================

if __name__ == "__main__":
    print("="*60)
    print(" INICIANDO SCRAPER + ANÁLISIS IA")
    print("="*60)

    resultados_totales = []

    # 1) Fuentes oficiales primero
    print("\n FASE 1: Recopilando noticias...")

    fuentes = {
        "El Tiempo": "https://www.eltiempo.com/buscar/",
        "El Espectador": "https://www.elespectador.com/buscador/",
        "FECODE": "https://fecode.edu.co/?s=",
        "ADE Bogotá": "https://adebogota.org/index.php/buscar?q=",
        "SED": "https://www.educacionbogota.edu.co/noticias?field_noticia_descripcion_value=",
        "Bogota.gov": "https://bogota.gov.co/tag/ingreso-minimo-garantizado?search_api_fulltext=",
        "Caracol" : "https://www.noticiascaracol.com/busqueda?q=",
        "Valora Analitik" : "https://www.valoraanalitik.com/?s=",
        "Portafolio": "https://www.portafolio.co/buscar?q=",
    }
    terminos = [
        "paro docentes", "paro maestros", "suspensión de clases 2023",
        "cese de actividades escolares 2023", "FECODE 2023", "huelga de profesores",
        "protesta docente 2023"
    ]
    for fuente, url_base in fuentes.items():
        for termino in terminos:
            resultados_totales.extend(
                buscar_noticias_generales(fuente, url_base, termino)
            )
            time.sleep(random.uniform(2, 4))

   # 2) GoogleNews y SerpAPI
    resultados_totales.extend(buscar_con_googlenews())
    resultados_totales.extend(buscar_con_serpapi(SerpAPI_tkn1))

    df = pd.DataFrame(resultados_totales).drop_duplicates(subset="url")
    df.to_csv("noticias_paros_docentes_2023_SUPER.csv", index=False, encoding="utf-8-sig")

    print(f"\n✅ Total de noticias recopiladas: {len(resultados_totales)}")
# Out:
# ============================================================
#  INICIANDO SCRAPER + ANÁLISIS IA
# ============================================================
#
#  FASE 1: Recopilando noticias...
#
# 🔍 Buscando en El Tiempo: paro docentes
# Encontrados 20 artículos en El Tiempo
#
# 🔍 Buscando en El Tiempo: paro maestros
# Encontrados 20 artículos en El Tiempo
#
# 🔍 Buscando en El Tiempo: suspensión de clases 2023
# Encontrados 20 artículos en El Tiempo
#
# 🔍 Buscando en El Tiempo: cese de actividades escolares 2023
# Encontrados 20 artículos en El Tiempo
#
# 🔍 Buscando en El Tiempo: FECODE 2023
# Encontrados 20 artículos en El Tiempo
#
# 🔍 Buscando en El Tiempo: huelga de profesores
# Encontrados 20 artículos en El Tiempo
#
# 🔍 Buscando en El Tiempo: protesta docente 2023
# Encontrados 20 artículos en El Tiempo
#
# 🔍 Buscando en El Espectador: paro docentes
# Encontrados 0 artículos en El Espectador
#
# 🔍 Buscando en El Espectador: paro maestros
# Encontrados 0 artículos en El Espectador
#
# 🔍 Buscando en El Espectador: suspensión de clases 2023
# Encontrados 0 artículos en El Espectador
#
# 🔍 Buscando en El Espectador: cese de actividades escolares 2023
# Encontrados 0 artículos en El Espectador
#
# 🔍 Buscando en El Espectador: FECODE 2023
# Encontrados 0 artículos en El Espectador
#
# 🔍 Buscando en El Espectador: huelga de profesores
# Encontrados 0 artículos en El Espectador
#
# 🔍 Buscando en El Espectador: protesta docente 2023
# Encontrados 0 artículos en El Espectador
#
# 🔍 Buscando en FECODE: paro docentes
# Encontrados 4 artículos en FECODE
#
# 🔍 Buscando en FECODE: paro maestros
# Encontrados 2 artículos en FECODE
#
# 🔍 Buscando en FECODE: suspensión de clases 2023
# Encontrados 0 artículos en FECODE
#
# 🔍 Buscando en FECODE: cese de actividades escolares 2023
# Encontrados 0 artículos en FECODE
#
# 🔍 Buscando en FECODE: FECODE 2023
# Encontrados 5 artículos en FECODE
#
# 🔍 Buscando en FECODE: huelga de profesores
# Encontrados 0 artículos en FECODE
#
# 🔍 Buscando en FECODE: protesta docente 2023
# Encontrados 0 artículos en FECODE
#
# 🔍 Buscando en ADE Bogotá: paro docentes
# Encontrados 0 artículos en ADE Bogotá
#
# 🔍 Buscando en ADE Bogotá: paro maestros
# Encontrados 0 artículos en ADE Bogotá
#
# 🔍 Buscando en ADE Bogotá: suspensión de clases 2023
# Encontrados 0 artículos en ADE Bogotá
#
# 🔍 Buscando en ADE Bogotá: cese de actividades escolares 2023
# Encontrados 0 artículos en ADE Bogotá
#
# 🔍 Buscando en ADE Bogotá: FECODE 2023
# Encontrados 0 artículos en ADE Bogotá
#
# 🔍 Buscando en ADE Bogotá: huelga de profesores
# Encontrados 0 artículos en ADE Bogotá
#
# 🔍 Buscando en ADE Bogotá: protesta docente 2023
# Encontrados 0 artículos en ADE Bogotá
#
# 🔍 Buscando en SED: paro docentes
# ❌ Error en SED: HTTPSConnectionPool(host='www.educacionbogota.edu.co', port=443): Max retries exceeded with url: /noticias?field_noticia_descripcion_value=paro+docentes (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7eab15aae750>, 'Connection to www.educacionbogota.edu.co timed out. (connect timeout=20)'))
#
# 🔍 Buscando en SED: paro maestros
# ❌ Error en SED: HTTPSConnectionPool(host='www.educacionbogota.edu.co', port=443): Max retries exceeded with url: /noticias?field_noticia_descripcion_value=paro+maestros (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7eab159f9340>, 'Connection to www.educacionbogota.edu.co timed out. (connect timeout=20)'))
#
# 🔍 Buscando en SED: suspensión de clases 2023
# ❌ Error en SED: HTTPSConnectionPool(host='www.educacionbogota.edu.co', port=443): Max retries exceeded with url: /noticias?field_noticia_descripcion_value=suspensi%C3%B3n+de+clases+2023 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7eab15aae660>, 'Connection to www.educacionbogota.edu.co timed out. (connect timeout=20)'))
#
# 🔍 Buscando en SED: cese de actividades escolares 2023
# ❌ Error en SED: HTTPSConnectionPool(host='www.educacionbogota.edu.co', port=443): Max retries exceeded with url: /noticias?field_noticia_descripcion_value=cese+de+actividades+escolares+2023 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7eab159f8e90>, 'Connection to www.educacionbogota.edu.co timed out. (connect timeout=20)'))
#
# 🔍 Buscando en SED: FECODE 2023
# ❌ Error en SED: HTTPSConnectionPool(host='www.educacionbogota.edu.co', port=443): Max retries exceeded with url: /noticias?field_noticia_descripcion_value=FECODE+2023 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7eab159f9d00>, 'Connection to www.educacionbogota.edu.co timed out. (connect timeout=20)'))
#
# 🔍 Buscando en SED: huelga de profesores
# ❌ Error en SED: HTTPSConnectionPool(host='www.educacionbogota.edu.co', port=443): Max retries exceeded with url: /noticias?field_noticia_descripcion_value=huelga+de+profesores (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7eab159fa6c0>, 'Connection to www.educacionbogota.edu.co timed out. (connect timeout=20)'))
#
# 🔍 Buscando en SED: protesta docente 2023
# ❌ Error en SED: HTTPSConnectionPool(host='www.educacionbogota.edu.co', port=443): Max retries exceeded with url: /noticias?field_noticia_descripcion_value=protesta+docente+2023 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7eab159fb020>, 'Connection to www.educacionbogota.edu.co timed out. (connect timeout=20)'))
#
# 🔍 Buscando en Bogota.gov: paro docentes
# Encontrados 0 artículos en Bogota.gov
#
# 🔍 Buscando en Bogota.gov: paro maestros
# Encontrados 0 artículos en Bogota.gov
#
# 🔍 Buscando en Bogota.gov: suspensión de clases 2023
# Encontrados 0 artículos en Bogota.gov
#
# 🔍 Buscando en Bogota.gov: cese de actividades escolares 2023
# Encontrados 0 artículos en Bogota.gov
#
# 🔍 Buscando en Bogota.gov: FECODE 2023
# Encontrados 0 artículos en Bogota.gov
#
# 🔍 Buscando en Bogota.gov: huelga de profesores
# Encontrados 0 artículos en Bogota.gov
#
# 🔍 Buscando en Bogota.gov: protesta docente 2023
# Encontrados 0 artículos en Bogota.gov
#
# 🔍 Buscando en Caracol: paro docentes
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Encontrados 0 artículos en Caracol
#
# 🔍 Buscando en Caracol: paro maestros
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Encontrados 0 artículos en Caracol
#
# 🔍 Buscando en Caracol: suspensión de clases 2023
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Encontrados 0 artículos en Caracol
#
# 🔍 Buscando en Caracol: cese de actividades escolares 2023
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Encontrados 0 artículos en Caracol
#
# 🔍 Buscando en Caracol: FECODE 2023
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Encontrados 0 artículos en Caracol
#
# 🔍 Buscando en Caracol: huelga de profesores
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Encontrados 0 artículos en Caracol
#
# 🔍 Buscando en Caracol: protesta docente 2023
# WARNING:bs4.dammit:Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Encontrados 0 artículos en Caracol
#
# 🔍 Buscando en Valora Analitik: paro docentes
# ❌ Error en Valora Analitik: 403 Client Error: Forbidden for url: https://www.valoraanalitik.com/?s=paro+docentes
#
# 🔍 Buscando en Valora Analitik: paro maestros
# ❌ Error en Valora Analitik: 403 Client Error: Forbidden for url: https://www.valoraanalitik.com/?s=paro+maestros
#
# 🔍 Buscando en Valora Analitik: suspensión de clases 2023
# ❌ Error en Valora Analitik: 403 Client Error: Forbidden for url: https://www.valoraanalitik.com/?s=suspensi%C3%B3n+de+clases+2023
#
# 🔍 Buscando en Valora Analitik: cese de actividades escolares 2023
# ❌ Error en Valora Analitik: 403 Client Error: Forbidden for url: https://www.valoraanalitik.com/?s=cese+de+actividades+escolares+2023
#
# 🔍 Buscando en Valora Analitik: FECODE 2023
# ❌ Error en Valora Analitik: 403 Client Error: Forbidden for url: https://www.valoraanalitik.com/?s=FECODE+2023
#
# 🔍 Buscando en Valora Analitik: huelga de profesores
# ❌ Error en Valora Analitik: 403 Client Error: Forbidden for url: https://www.valoraanalitik.com/?s=huelga+de+profesores
#
# 🔍 Buscando en Valora Analitik: protesta docente 2023
# ❌ Error en Valora Analitik: 403 Client Error: Forbidden for url: https://www.valoraanalitik.com/?s=protesta+docente+2023
#
# 🔍 Buscando en Portafolio: paro docentes
# Encontrados 20 artículos en Portafolio
#
# 🔍 Buscando en Portafolio: paro maestros
# Encontrados 20 artículos en Portafolio
#
# 🔍 Buscando en Portafolio: suspensión de clases 2023
# Encontrados 20 artículos en Portafolio
#
# 🔍 Buscando en Portafolio: cese de actividades escolares 2023
# Encontrados 20 artículos en Portafolio
#
# 🔍 Buscando en Portafolio: FECODE 2023
# Encontrados 20 artículos en Portafolio
#
# 🔍 Buscando en Portafolio: huelga de profesores
# Encontrados 20 artículos en Portafolio
#
# 🔍 Buscando en Portafolio: protesta docente 2023
# Encontrados 20 artículos en Portafolio
# ✅ GoogleNews: 550 resultados
#
# 🔍 Buscando con SerpAPI...
#  SerpAPI: 40 resultados
#
# ✅ Total de noticias recopiladas: 741

# %%
# ================================================================
# ANÁLISIS CON IA
# ================================================================

def obtener_texto_completo(url):

    try:
        r = requests.get(url, timeout=15)
        r.raise_for_status()
        soup = BeautifulSoup(r.text, "html.parser")

        # Elimina elementos que no son contenido principal
        for s in soup(["script", "style", "noscript", "header", "footer", "aside", "form"]):
            s.extract()

        texto = " ".join(soup.stripped_strings)
        return texto[:8000]  # Máximo 8000 caracteres
    except Exception as e:
        return f"Error al obtener contenido: {e}"


def analizar_con_ia(titulo, descripcion, url):
    """
    🤖 EXPLICACIÓN (LA MÁS IMPORTANTE):
    Esta función envía la noticia a GPT-4 para que la analice siguiendo criterios estrictos.

    PROCESO:
    1. Intenta descargar el contenido completo de la URL
    2. Si falla, usa solo título + descripción, indicame si pudiste o no acceder al URL
    3. Construye un prompt detallado con instrucciones para la IA
    4. Envía el prompt a OpenAI (modelo gpt-4o-mini)
    5. Recibe respuesta en formato JSON
    6. Parsea el JSON y devuelve un diccionario con las características

    CARACTERÍSTICAS QUE ANALIZA:
    - es_paro_docente: ¿Hubo suspensión de clases?
    - organizaciones_sindicales: ¿Qué sindicatos u organizaciones políticas participaron?
    - duracion_dias: ¿Cuántos días duró?
    - ubicacion_bogota: ¿Ocurrió en Bogotá?
    - ubicacion_Colombia: ¿Abarcó todo el territorio Nacional=
    - costo_mencionado: ¿Se habla de costos económicos?
    - fecha_paro: ¿cuál es la fecha exacta del paro (día, mes, año)?
    """
    print(f"  🤖 Analizando: {titulo[:60]}...")

    contenido_completo = obtener_texto_completo(url) if url else ""

    if "Error" in contenido_completo or not contenido_completo:
        texto_analizar = f"Título: {titulo}\nDescripción: {descripcion}"
    else:
        texto_analizar = contenido_completo

    # ============================================
    #  PROMPT IA
    # ============================================
    prompt = f"""
Analiza la siguiente noticia en español sobre educación, sindicatos o protestas de docentes.

CRITERIOS ESTRICTOS:
- Un **paro docente verdadero** solo existe si hubo suspensión de clases programadas.
- Si fue marcha, manifestación o concentración SIN suspensión de clases, NO es paro.
- Debes explicar tu razonamiento.

Devuelve un JSON con estas claves:

- "es_paro_docente": true/false → true solo si hubo suspensión de clases
- "justificacion_paro": texto breve (2-4 líneas) explicando por qué es o no un paro
- "organizaciones_sindicales": lista de sindicatos mencionados u organizaciones políticas o partidos políticos (ej: ["FECODE", "ADE"]), o []
- "hay_suspension_clases": true/false → si se suspendieron clases
- "duracion_dias": número de días estimados, o null
- "razones_paro": resumen de las demandas principales
- "ubicacion_bogota": true/false → si ocurre en Bogotá/Cundinamarca
- "ubicacion_Colombia": true/false → si el paro abarca el territorio Nacional
- "costo_mencionado": monto económico si se menciona, o null
- "resumen": breve resumen (máx. 3 líneas)
- "fecha_paro": fecha exacta o estimada del paro (en formato ISO: YYYY-MM-DD).
   Si no se menciona explícitamente, intenta inferirla a partir del texto:
   por ejemplo, si dice "este jueves" o "la semana pasada",
   dedúcela usando la fecha de publicación o el contexto temporal.
   Si no se puede deducir con precisión, deja null.
- "tipo_movilizacion": ¿cuál es el tipo de movilización, paro docente con las caracteristicas que ya vimos, paro de otro gremio, demostración, plantón, toma, marcha pacífica, etc?
- "ubicacion": además del país y ciudad, podemos identificar localidades? barrios? calles? edificios? colegios específicos o barrios?
Devuelve SOLO el JSON válido, sin texto extra.
- "fuente_oficial": ¿es una fuente oficial de algún sindicato o es media, si es media cual, si es sindicato, cual?

Texto a analizar:
{texto_analizar}
"""

    try:
        # ============================================
        #  API DE OPENAI
        # ============================================

        response = client.chat.completions.create(
            model="gpt-4o-mini",
            temperature=0.1,
            messages=[{"role": "user", "content": prompt}],
        )

        # Extrae el texto de la respuesta
        respuesta_texto = response.choices[0].message.content.strip()

        # ============================================
        # PARSEO DEL JSON
        # ============================================
        # La IA devuelve un JSON como string, lo convertimos a diccionario
        try:
            # Intenta parsear directamente
            analisis = json.loads(respuesta_texto)
        except json.JSONDecodeError:
            # Si falla, busca el JSON dentro de bloques de código ```json```
            if "```json" in respuesta_texto:
                inicio = respuesta_texto.find("```json") + 7
                fin = respuesta_texto.find("```", inicio)
                json_str = respuesta_texto[inicio:fin].strip()
                analisis = json.loads(json_str)
            else:
                # Si todo falla, devuelve valores por defecto
                print("    ⚠️ No se pudo parsear el JSON")
                analisis = {
                    'es_paro_docente': False,
                    'justificacion_paro': 'Error al analizar',
                    'organizaciones_sindicales': [],
                    'hay_suspension_clases': False,
                    'duracion_dias': None,
                    'razones_paro': '',
                    'ubicacion_bogota': False,
                    'ubicacion_Colombia': False,
                    'costo_mencionado': None,
                    'resumen': '',
                    'fecha_paro': None,
                    'tipo_movilizacion': '',
                    'ubicacion': '',
                    'fuente_oficial': ''
                }

        return analisis

    except Exception as e:
        print(f"    ❌ Error en análisis IA: {e}")
        if "insufficient_quota" in str(e):
            print("    Please check your OpenAI API plan and billing details.")
        return {
            'es_paro_docente': False,
            'justificacion_paro': f'Error: {str(e)}',
            'organizaciones_sindicales': [],
            'hay_suspension_clases': False,
            'duracion_dias': None,
            'razones_paro': '',
            'ubicacion_bogota': False,
            'ubicacion_Colombia': False,
            'costo_mencionado': None,
            'resumen': '',
            'fecha_paro': None,
            'tipo_movilizacion': '',
            'ubicacion': '',
            'fuente_oficial': ''
        }


# ================================================================
# 🧹 FASE 1.5: LIMPIEZA Y ELIMINACIÓN DE DUPLICADOS
# ================================================================
print("\n🧹 Eliminando duplicados...")

df = pd.DataFrame(resultados_totales)

df['url_norm'] = df['url'].astype(str).str.strip().str.lower()
df = df.drop_duplicates(subset=['url_norm'], keep='first')

print(f"✅ Total tras eliminar duplicados: {len(df)} noticias únicas\n")

# ================================================================
# FASE 2: ANÁLISIS CON IA
# ================================================================
print("\n🤖 FASE 2: Analizando con IA...")

resultados_finales = []
for i, noticia in enumerate(df.to_dict('records'), 1):
    print(f"\n[{i}/{len(df)}] Analizando: {noticia['titulo'][:80]}")

    analisis = analizar_con_ia(
        noticia['titulo'],
        noticia.get('descripcion', ''),
        noticia.get('url', '')
    )

    noticia.update(analisis)
    resultados_finales.append(noticia)

    # Espera 2 segundos entre llamadas para no saturar la API
    time.sleep(2)

# ================================================================
# FASE 3: GUARDAR RESULTADOS EN CSV
# ================================================================
print("\n💾 FASE 3: Guardando resultados...")

df_final = pd.DataFrame(resultados_finales)

# Reordena columnas para legibilidad
columnas_importantes = [
    'titulo', 'fuente', 'fecha_publicacion', 'url',
    'es_paro_docente', 'hay_suspension_clases', 'ubicacion_bogota',
    'ubicacion_Colombia', 'duracion_dias', 'organizaciones_sindicales',
    'razones_paro', 'costo_mencionado', 'justificacion_paro', 'resumen',
    'fecha_paro', 'tipo_movilizacion', 'ubicacion',
    'descripcion', 'periodo_busqueda', 'fecha_extraccion', 'fuente_oficial'
]

columnas_finales = [col for col in columnas_importantes if col in df_final.columns]
df_final = df_final[columnas_finales]

# Guarda CSV final
nombre_archivo = "noticias_paros_docentes_2023_ANALIZADO.csv"
df_final.to_csv(nombre_archivo, index=False, encoding="utf-8-sig")

print(f"✅ Archivo guardado: {nombre_archivo}")
print(f"📊 Total de noticias analizadas: {len(df_final)}")

# ================================================================
# 🧹 FASE 2.5: UNIFICAR FORMATO DE FECHAS Y FILTRAR EVENTOS
# ================================================================
print("\n📅 Normalizando formato de fechas y filtrando eventos relevantes...")

def parse_fecha(fecha):
    if pd.isna(fecha) or str(fecha).strip() == "":
        return None
    for fmt in ("%Y-%m-%d", "%d/%m/%Y", "%d-%m-%Y", "%B %d, %Y", "%d %b %Y"):
        try:
            return pd.to_datetime(fecha, format=fmt, errors='coerce')
        except Exception:
            continue
    return pd.to_datetime(fecha, errors='coerce')

df_final['fecha_paro'] = df_final['fecha_paro'].apply(parse_fecha)
df_final['fecha_paro'] = df_final['fecha_paro'].dt.strftime('%Y-%m-%d')

df_filtrado = df_final[
    ((df_final['es_paro_docente'] == True) | (df_final['hay_suspension_clases'] == True))
    & ((df_final['ubicacion_bogota'] == True) | (df_final['ubicacion_Colombia'] == True))
].copy()

print(f"✅ Total de eventos filtrados (Colombia/Bogotá): {len(df_filtrado)}")

nombre_archivo_filtrado = "web_noticias_paros_docentes_2023.csv"
df_filtrado.to_csv(nombre_archivo_filtrado, index=False, encoding="utf-8-sig")
print(f"📁 Archivo filtrado guardado: {nombre_archivo_filtrado}")

# ================================================================
# ESTADÍSTICAS FINALES
# ================================================================
print("\n" + "="*60)
print("📈 ESTADÍSTICAS DEL ANÁLISIS")
print("="*60)

paros_verdaderos = df_final[df_final['es_paro_docente'] == True]
print(f"🔴 Paros verdaderos (con suspensión de clases): {len(paros_verdaderos)}")

en_bogota = df_final[df_final['ubicacion_bogota'] == True]
print(f"📍 Eventos en Bogotá: {len(en_bogota)}")

con_duracion = df_final[df_final['duracion_dias'].notna()]
if len(con_duracion) > 0:
   print(f"⏱️ Duración promedio: {con_duracion['duracion_dias'].mean():.1f} días")

print("\n🎉 ¡Análisis completado!")
# Out:
# 🧹 Eliminando duplicados...
# ✅ Total tras eliminar duplicados: 266 noticias únicas
#
#
# 🤖 FASE 2: Analizando con IA...
#
# [1/266] Analizando: Circulares 2023
#   🤖 Analizando: Circulares 2023...
#
# [2/266] Analizando: Documentos 2025
#   🤖 Analizando: Documentos 2025...
#
# [3/266] Analizando: Circulares 2025
#   🤖 Analizando: Circulares 2025...
#
# [4/266] Analizando: Inicio
#   🤖 Analizando: Inicio...
#
# [5/266] Analizando: Elecciones Fecode 2023
#   🤖 Analizando: Elecciones Fecode 2023...
#
# [6/266] Analizando: Acuerdo FECODE – MEN 2023
#   🤖 Analizando: Acuerdo FECODE – MEN 2023...
#
# [7/266] Analizando: Escuela Sindical Documentos
#   🤖 Analizando: Escuela Sindical Documentos...
#
# [8/266] Analizando: El Monedero: inflación de alimentos vs. su bolsillo, en el caso del arroz o el h
#   🤖 Analizando: El Monedero: inflación de alimentos vs. su bolsillo, en el c...
#
# [9/266] Analizando: Womenize Latam llega al Caribe para impulsar el liderazgo femenino en tecnología
#   🤖 Analizando: Womenize Latam llega al Caribe para impulsar el liderazgo fe...
#
# [10/266] Analizando: Club El Nogal revisará despidos de forma individual, tras mesas con Mintrabajo
#   🤖 Analizando: Club El Nogal revisará despidos de forma individual, tras me...
#
# [11/266] Analizando: Huracán Melissa deja sus primeros estragos, tras su llegada a Jamaica
#   🤖 Analizando: Huracán Melissa deja sus primeros estragos, tras su llegada ...
#
# [12/266] Analizando: Fundación Terpel impacta en la educación de niños en poblaciones en zonas rurale
#   🤖 Analizando: Fundación Terpel impacta en la educación de niños en poblaci...
#
# [13/266] Analizando: ¿Buscando trabajo con estudios básicos? Hay feria de empleo en Bogotá
#   🤖 Analizando: ¿Buscando trabajo con estudios básicos? Hay feria de empleo ...
#
# [14/266] Analizando: Enfriamiento líquido se consolida como la tecnología clave para los centros de d
#   🤖 Analizando: Enfriamiento líquido se consolida como la tecnología clave p...
#
# [15/266] Analizando: Violencia escolar en América Latina y el Caribe: un desafío urgente
#   🤖 Analizando: Violencia escolar en América Latina y el Caribe: un desafío ...
#
# [16/266] Analizando: El costo oculto de la política: cómo la financiación electoral afecta los impues
#   🤖 Analizando: El costo oculto de la política: cómo la financiación elector...
#
# [17/266] Analizando: Dónde hay más informalidad en el mundo y cómo está Colombia
#   🤖 Analizando: Dónde hay más informalidad en el mundo y cómo está Colombia...
#
# [18/266] Analizando: Empresas aseguran que los roles de trabajadores son transformados gracias a la I
#   🤖 Analizando: Empresas aseguran que los roles de trabajadores son transfor...
#
# [19/266] Analizando: A. Latina necesita líderes climáticos
#   🤖 Analizando: A. Latina necesita líderes climáticos...
#
# [20/266] Analizando: ¿Le pasa igual? Esto es lo que más olvidan los colombianos en su maleta de viaje
#   🤖 Analizando: ¿Le pasa igual? Esto es lo que más olvidan los colombianos e...
#
# [21/266] Analizando: Profesor colombiano integra misión espacial en hábitat análogo financiado por la
#   🤖 Analizando: Profesor colombiano integra misión espacial en hábitat análo...
#
# [22/266] Analizando: Las cinco propuestas de Camacol para que el próximo Gobierno reactive vivienda
#   🤖 Analizando: Las cinco propuestas de Camacol para que el próximo Gobierno...
#
# [23/266] Analizando: Fecode confirma convocatoria de paro en octubre: fecha y motivos de la protesta
#   🤖 Analizando: Fecode confirma convocatoria de paro en octubre: fecha y mot...
#
# [24/266] Analizando: Colombia impulsó el talento con la AI Week 2025
#   🤖 Analizando: Colombia impulsó el talento con la AI Week 2025...
#
# [25/266] Analizando: Ordenan demoler una parte de la Casa Blanca, en Estados Unidos: ¿por qué?
#   🤖 Analizando: Ordenan demoler una parte de la Casa Blanca, en Estados Unid...
#
# [26/266] Analizando: El mercado eléctrico sintió presión para venderle energía a Air-e para el 2026
#   🤖 Analizando: El mercado eléctrico sintió presión para venderle energía a ...
#
# [27/266] Analizando: El juicio de la coherencia
#   🤖 Analizando: El juicio de la coherencia...
#
# [28/266] Analizando: Wyndham Hotels & Resorts incrementa 4% su red global y mantiene ganancias en el
#   🤖 Analizando: Wyndham Hotels & Resorts incrementa 4% su red global y manti...
#
# [29/266] Analizando: Gobierno activa incentivo integral para gestión de riesgos en pesca y acuicultur
#   🤖 Analizando: Gobierno activa incentivo integral para gestión de riesgos e...
#
# [30/266] Analizando: ‘Los recursos para la formación nunca serán suficientes’: Universidad Pontificia
#   🤖 Analizando: ‘Los recursos para la formación nunca serán suficientes’: Un...
#
# [31/266] Analizando: GeoPark rechaza la propuesta de Parex Resources para adquirir la compañía
#   🤖 Analizando: GeoPark rechaza la propuesta de Parex Resources para adquiri...
#
# [32/266] Analizando: Universidad de élite: ¿mérito o privilegio?
#   🤖 Analizando: Universidad de élite: ¿mérito o privilegio?...
#
# [33/266] Analizando: PepsiCo fortalece alianzas en Colombia para una producción agrícola más eficient
#   🤖 Analizando: PepsiCo fortalece alianzas en Colombia para una producción a...
#
# [34/266] Analizando: Latam da la pelea: con más de 160 aviones apuesta por fortalecer su flota aérea
#   🤖 Analizando: Latam da la pelea: con más de 160 aviones apuesta por fortal...
#
# [35/266] Analizando: Coviandina concluye reparación del túnel de Quebradablanca y abre paso a Villavi
#   🤖 Analizando: Coviandina concluye reparación del túnel de Quebradablanca y...
#
# [36/266] Analizando: La vivienda, un lujo inalcanzable: OBS alerta sobre una crisis estructural en Co
#   🤖 Analizando: La vivienda, un lujo inalcanzable: OBS alerta sobre una cris...
#
# [37/266] Analizando: Metro de Bogotá prepara su primer proyecto inmobiliario asociado a la Línea 1
#   🤖 Analizando: Metro de Bogotá prepara su primer proyecto inmobiliario asoc...
#
# [38/266] Analizando: Banco de Bogotá lanza Bre-B y transforma la forma de recibir pagos
#   🤖 Analizando: Banco de Bogotá lanza Bre-B y transforma la forma de recibir...
#
# [39/266] Analizando: La estrategia de realme en Colombia está impulsada por la innovación y la IA
#   🤖 Analizando: La estrategia de realme en Colombia está impulsada por la in...
#
# [40/266] Analizando: Ya no son los Call Centers: estos son los sectores que más están alquilando ofic
#   🤖 Analizando: Ya no son los Call Centers: estos son los sectores que más e...
#
# [41/266] Analizando: Clínica Montserrat: riesgos de vivir conectados todo el tiempo
#   🤖 Analizando: Clínica Montserrat: riesgos de vivir conectados todo el tiem...
#
# [42/266] Analizando: Grupo Éxito continúa impulsando estrategias de ahorro para cautivar a sus client
#   🤖 Analizando: Grupo Éxito continúa impulsando estrategias de ahorro para c...
#
# [43/266] Analizando: La arquitectura: el motor del crecimiento ordenado de las ciudades
#   🤖 Analizando: La arquitectura: el motor del crecimiento ordenado de las ci...
#
# [44/266] Analizando: Esta marca promoverá incentivos tributarios para cambiar la nevera
#   🤖 Analizando: Esta marca promoverá incentivos tributarios para cambiar la ...
#
# [45/266] Analizando: La marca checa de calzado que lleva 57 años en Colombia y muchos creen que es na
#   🤖 Analizando: La marca checa de calzado que lleva 57 años en Colombia y mu...
#
# [46/266] Analizando: Contraloría alerta déficit en PAE y advierte riesgo para 1,6 millones de estudia
#   🤖 Analizando: Contraloría alerta déficit en PAE y advierte riesgo para 1,6...
#
# [47/266] Analizando: 'Para comprar una vivienda VIS, una familia necesita ganar entre 3,5 y 4 mínimos
#   🤖 Analizando: 'Para comprar una vivienda VIS, una familia necesita ganar e...
#
# [48/266] Analizando: ‘La vivienda social no puede quedar en el olvido’: Grupo Amarilo
#   🤖 Analizando: ‘La vivienda social no puede quedar en el olvido’: Grupo Ama...
#
# [49/266] Analizando: Facturación electrónica: el dolor de cabeza para las empresas que incumplan
#   🤖 Analizando: Facturación electrónica: el dolor de cabeza para las empresa...
#
# [50/266] Analizando: 'Vendemos la mitad de viviendas y desistimientos se duplicaron en gobierno Petro
#   🤖 Analizando: 'Vendemos la mitad de viviendas y desistimientos se duplicar...
#
# [51/266] Analizando: Cortes de luz en Boyacá, en Tunja, Duitama y Paipa del 21 al 24 de octubre
#   🤖 Analizando: Cortes de luz en Boyacá, en Tunja, Duitama y Paipa del 21 al...
#
# [52/266] Analizando: Inversión pública en el país sigue rezagada: no llega al 50%
#   🤖 Analizando: Inversión pública en el país sigue rezagada: no llega al 50%...
#
# [53/266] Analizando: Polémica por artículo del Presupuesto 2026 que permitiría mover fondos pensional
#   🤖 Analizando: Polémica por artículo del Presupuesto 2026 que permitiría mo...
#
# [54/266] Analizando: Propiedad horizontal y convivencia: así funciona la ley del ruido en el país
#   🤖 Analizando: Propiedad horizontal y convivencia: así funciona la ley del ...
#
# [55/266] Analizando: SIC ordena el cierre inmediato de la empresa de criptos World en Colombia
#   🤖 Analizando: SIC ordena el cierre inmediato de la empresa de criptos Worl...
#
# [56/266] Analizando: Cambios en el gasto del Presupuesto 2026 despiertan dudas en el Congreso
#   🤖 Analizando: Cambios en el gasto del Presupuesto 2026 despiertan dudas en...
#
# [57/266] Analizando: Reforma al Icetex tendría un impacto fiscal de $8,9 billones, advierte el Minhac
#   🤖 Analizando: Reforma al Icetex tendría un impacto fiscal de $8,9 billones...
#
# [58/266] Analizando: Alerta en Colombia y América Latina: el virus que se están propagando por WhatsA
#   🤖 Analizando: Alerta en Colombia y América Latina: el virus que se están p...
#
# [59/266] Analizando: México aprueba Ley Aduanera para combatir la evasión fiscal: ¿de qué trata?
#   🤖 Analizando: México aprueba Ley Aduanera para combatir la evasión fiscal:...
#
# [60/266] Analizando: Controles al gasto, veedurías institucionales y transparencia electoral en el pa
#   🤖 Analizando: Controles al gasto, veedurías institucionales y transparenci...
#
# [61/266] Analizando: Inflación le quitaría ritmo a la economía en el cuarto trimestre
#   🤖 Analizando: Inflación le quitaría ritmo a la economía en el cuarto trime...
#
# [62/266] Analizando: Aranceles de Trump golpean la industria de Halloween: precios altos y menor ofer
#   🤖 Analizando: Aranceles de Trump golpean la industria de Halloween: precio...
#
# [63/266] Analizando: Aeropuerto de Cartagena podría no modernizarse por disputa entre la ANI y la Alc
#   🤖 Analizando: Aeropuerto de Cartagena podría no modernizarse por disputa e...
#
# [64/266] Analizando: '¿Sería casualidad que la imputación fuera paralela a la reforma de la salud?'
#   🤖 Analizando: '¿Sería casualidad que la imputación fuera paralela a la ref...
#
# [65/266] Analizando: Fitch advierte que romper la regla fiscal pasará factura a las calificaciones
#   🤖 Analizando: Fitch advierte que romper la regla fiscal pasará factura a l...
#
# [66/266] Analizando: Trampas del crecimiento de la productividad en Colombia: reto para las regiones
#   🤖 Analizando: Trampas del crecimiento de la productividad en Colombia: ret...
#
# [67/266] Analizando: Muertos, hambre y destrucción: las cifras de la guerra en Gaza
#   🤖 Analizando: Muertos, hambre y destrucción: las cifras de la guerra en Ga...
#
# [68/266] Analizando: 100.000 viajeros recorrerán la vía Bogotá – Girardot durante el plan retorno
#   🤖 Analizando: 100.000 viajeros recorrerán la vía Bogotá – Girardot durante...
#
# [69/266] Analizando: Colombia estaría en camino a su quinto año por fuera del rango meta en inflación
#   🤖 Analizando: Colombia estaría en camino a su quinto año por fuera del ran...
#
# [70/266] Analizando: 66.000 muertos y millones de desplazados: cifras tras dos años de conflicto en G
#   🤖 Analizando: 66.000 muertos y millones de desplazados: cifras tras dos añ...
#
# [71/266] Analizando: ¿Cuándo salen a vacaciones los colegios e inicia la semana de receso de octubre?
#   🤖 Analizando: ¿Cuándo salen a vacaciones los colegios e inicia la semana d...
#
# [72/266] Analizando: Termotasajero prevé fracaso en subasta de energía: ¿por qué?
#   🤖 Analizando: Termotasajero prevé fracaso en subasta de energía: ¿por qué?...
#
# [73/266] Analizando: La distorsión de precios y la baja demanda ahogan a las siderúrgicas
#   🤖 Analizando: La distorsión de precios y la baja demanda ahogan a las side...
#
# [74/266] Analizando: Freno a la inversión en el país se mantendrá como una constante durante el 2025
#   🤖 Analizando: Freno a la inversión en el país se mantendrá como una consta...
#
# [75/266] Analizando: La informalidad, un obstáculo para lograr crecimiento incluyente
#   🤖 Analizando: La informalidad, un obstáculo para lograr crecimiento incluy...
#
# [76/266] Analizando: Análisis: Colombia avanza lento en la misión de reducir de la pobreza monetaria
#   🤖 Analizando: Análisis: Colombia avanza lento en la misión de reducir de l...
#
# [77/266] Analizando: Niñas y niños conectados: los nuevos retos digitales que enfrentan las familias
#   🤖 Analizando: Niñas y niños conectados: los nuevos retos digitales que enf...
#
# [78/266] Analizando: Ganadería y caña, sectores que más sufren falta de seguridad
#   🤖 Analizando: Ganadería y caña, sectores que más sufren falta de seguridad...
#
# [79/266] Analizando: Viajar sin pagar de más: así puede planear sus vacaciones con programas de lealt
#   🤖 Analizando: Viajar sin pagar de más: así puede planear sus vacaciones co...
#
# [80/266] Analizando: Esta es la viabilidad de la energía nuclear en Colombia
#   🤖 Analizando: Esta es la viabilidad de la energía nuclear en Colombia...
#
# [81/266] Analizando: Radiografía de la educación privada en Colombia: cómo van las finanzas de los co
#   🤖 Analizando: Radiografía de la educación privada en Colombia: cómo van la...
#
# [82/266] Analizando: Más de $400.000 millones invirtieron las generadoras en sostenibilidad en 2024
#   🤖 Analizando: Más de $400.000 millones invirtieron las generadoras en sost...
#
# [83/266] Analizando: Efemérides del 13 de junio de 2025: Qué pasó un día como hoy
#   🤖 Analizando: Efemérides del 13 de junio de 2025: Qué pasó un día como hoy...
#
# [84/266] Analizando: El PIB creció 2,7% en el primer trimestre, con el consumo como motor
#   🤖 Analizando: El PIB creció 2,7% en el primer trimestre, con el consumo co...
#
# [85/266] Analizando: Análisis: ¿el apagón en Europa debe ser una señal de alerta para Colombia?
#   🤖 Analizando: Análisis: ¿el apagón en Europa debe ser una señal de alerta ...
#
# [86/266] Analizando: Mociclistas se unen a jornada de protestas en Bogotá por restricción de parrille
#   🤖 Analizando: Mociclistas se unen a jornada de protestas en Bogotá por res...
#
# [87/266] Analizando: Inspeccionan la sede de Colombia Humana por indagación a la campaña de Petro
#   🤖 Analizando: Inspeccionan la sede de Colombia Humana por indagación a la ...
#
# [88/266] Analizando: Pacientes con enfermedades raras alertan por demoras en diagnóstico y acceso
#   🤖 Analizando: Pacientes con enfermedades raras alertan por demoras en diag...
#
# [89/266] Analizando: Gastos del sistema de salud alcanzaron los $121 billones en 2024
#   🤖 Analizando: Gastos del sistema de salud alcanzaron los $121 billones en ...
#
# [90/266] Analizando: Deterioro financiero del sistema de salud alcanza $4,2 billones en cartera farma
#   🤖 Analizando: Deterioro financiero del sistema de salud alcanza $4,2 billo...
#
# [91/266] Analizando: Inflación y déficit le seguirán pasando factura a la política monetaria
#   🤖 Analizando: Inflación y déficit le seguirán pasando factura a la polític...
#
# [92/266] Analizando: Clínica de Marly pone en marcha el primer PET-CT digital de Siemens Healthineers
#   🤖 Analizando: Clínica de Marly pone en marcha el primer PET-CT digital de ...
#
# [93/266] Analizando: España supera los 10 millones de mayores de 65 años con el reto de vivir mejor
#   🤖 Analizando: España supera los 10 millones de mayores de 65 años con el r...
#
# [94/266] Analizando: El futuro de la inteligencia artificial: datos, talento y oportunidades para Col
#   🤖 Analizando: El futuro de la inteligencia artificial: datos, talento y op...
#
# [95/266] Analizando: Insonorizar las casas, un negocio que crece por los conciertos
#   🤖 Analizando: Insonorizar las casas, un negocio que crece por los conciert...
#
# [96/266] Analizando: Nacionalizar inversiones del ahorro pensional, una cura peor que la enfermedad
#   🤖 Analizando: Nacionalizar inversiones del ahorro pensional, una cura peor...
#
# [97/266] Analizando: Tasa de interés real: las decisiones que ha tomado el Banco de la República con
#   🤖 Analizando: Tasa de interés real: las decisiones que ha tomado el Banco ...
#
# [98/266] Analizando: Reacciones a propuesta de declarar inexequible la reforma pensional
#   🤖 Analizando: Reacciones a propuesta de declarar inexequible la reforma pe...
#
# [99/266] Analizando: Choque por cifras de mortalidad de las enfermedades huérfanas
#   🤖 Analizando: Choque por cifras de mortalidad de las enfermedades huérfana...
#
# [100/266] Analizando: El pueblo en Colombia que es tranquilo, pero guarda un laberinto de túneles bajo
#   🤖 Analizando: El pueblo en Colombia que es tranquilo, pero guarda un laber...
#
# [101/266] Analizando: Los sobrevivientes del empleo serán quienes dominen la inteligencia artificial
#   🤖 Analizando: Los sobrevivientes del empleo serán quienes dominen la intel...
#
# [102/266] Analizando: Gerente del Banrep advierte sobre riesgos que están enfrentando las finanzas del
#   🤖 Analizando: Gerente del Banrep advierte sobre riesgos que están enfrenta...
#
# [103/266] Analizando: Liberación de rehenes en Gaza: quién es el colombiano que fue liberado por Hamás
#   🤖 Analizando: Liberación de rehenes en Gaza: quién es el colombiano que fu...
#
# [104/266] Analizando: Famosa psiquiatra y autora Marián Rojas estará en Colombia: cuándo es la cita y
#   🤖 Analizando: Famosa psiquiatra y autora Marián Rojas estará en Colombia: ...
#
# [105/266] Analizando: Inteligencia artificial amenaza el multimillonario negocio de agentes de futboli
#   🤖 Analizando: Inteligencia artificial amenaza el multimillonario negocio d...
#
# [106/266] Analizando: Bloqueo comercial de EE. UU. no sería la razón de la crisis en Cuba, dicen exper
#   🤖 Analizando: Bloqueo comercial de EE. UU. no sería la razón de la crisis ...
#
# [107/266] Analizando: Así es como puede jugar al Mega Millions desde Colombia y ganar premios millonar
#   🤖 Analizando: Así es como puede jugar al Mega Millions desde Colombia y ga...
#
# [108/266] Analizando: Ni Estados Unidos ni Europa: Colombia se parece más a China en esto inesperado
#   🤖 Analizando: Ni Estados Unidos ni Europa: Colombia se parece más a China ...
#
# [109/266] Analizando: En qué ciudad de Colombia es más probable que se vuelva rico en 2026, según la I
#   🤖 Analizando: En qué ciudad de Colombia es más probable que se vuelva rico...
#
# [110/266] Analizando: Cafés de Colombia Expo 2025: una nueva edición llega a Bogotá
#   🤖 Analizando: Cafés de Colombia Expo 2025: una nueva edición llega a Bogot...
#
# [111/266] Analizando: De no creer: el pueblo colombiano donde las casas están pintadas con símbolos se
#   🤖 Analizando: De no creer: el pueblo colombiano donde las casas están pint...
#
# [112/266] Analizando: La profesión que podría hacerle famoso y casi nadie estudia en Colombia, según l
#   🤖 Analizando: La profesión que podría hacerle famoso y casi nadie estudia ...
#
# [113/266] Analizando: Impuesto al consumo: ABC para que entienda cómo funciona este cobro
#   🤖 Analizando: Impuesto al consumo: ABC para que entienda cómo funciona est...
#
# [114/266] Analizando: Javier Cuéllar regresa al FNG como presidente encargado
#   🤖 Analizando: Javier Cuéllar regresa al FNG como presidente encargado...
#
# [115/266] Analizando: Se les hizo el 'milagro': los Brayans en Colombia podrán tener deliciosa oferta
#   🤖 Analizando: Se les hizo el 'milagro': los Brayans en Colombia podrán ten...
#
# [116/266] Analizando: Mercado laboral: el nuevo empleo que dispara los sueldos en la era digital
#   🤖 Analizando: Mercado laboral: el nuevo empleo que dispara los sueldos en ...
#
# [117/266] Analizando: Los recursos de la naturaleza: oportunidades rentables y ambientalmente responsa
#   🤖 Analizando: Los recursos de la naturaleza: oportunidades rentables y amb...
#
# [118/266] Analizando: Educación y empleo juvenil en Colombia: cifras revelan brechas frente a la Ocde
#   🤖 Analizando: Educación y empleo juvenil en Colombia: cifras revelan brech...
#
# [119/266] Analizando: Psicólogo explicó cuáles son las profesiones con mayor presencia de rasgos psico
#   🤖 Analizando: Psicólogo explicó cuáles son las profesiones con mayor prese...
#
# [120/266] Analizando: La historia de Carlos Slim, el magnate que construyó un imperio empresarial
#   🤖 Analizando: La historia de Carlos Slim, el magnate que construyó un impe...
#
# [121/266] Analizando: Evitar la politización y reducir el déficit, prioridades del próximo Minhacienda
#   🤖 Analizando: Evitar la politización y reducir el déficit, prioridades del...
#
# [122/266] Analizando: 'La educación tradicional está desconectada del mercado': Ignia
#   🤖 Analizando: 'La educación tradicional está desconectada del mercado': Ig...
#
# [123/266] Analizando: ‘Las energías renovables apenas alcanzan para cubrir la crisis’: Siemens
#   🤖 Analizando: ‘Las energías renovables apenas alcanzan para cubrir la cris...
#
# [124/266] Analizando: Se agita el debate pensional tras recusación a magistrado que propone tumbar la
#   🤖 Analizando: Se agita el debate pensional tras recusación a magistrado qu...
#
# [125/266] Analizando: Proyecto de decreto sobre portabilidad financiera: esto es lo que usted podría h
#   🤖 Analizando: Proyecto de decreto sobre portabilidad financiera: esto es l...
#
# [126/266] Analizando: Senado aprueba gratuidad del Icfes para estudiantes de bajos recursos
#   🤖 Analizando: Senado aprueba gratuidad del Icfes para estudiantes de bajos...
#
# [127/266] Analizando: Gobierno colombiano garantizará la seguridad de la Embajada de Estados Unidos
#   🤖 Analizando: Gobierno colombiano garantizará la seguridad de la Embajada ...
#
# [128/266] Analizando: Qué es lo que está pasando con la Andi y por qué hay manifestaciones contra el g
#   🤖 Analizando: Qué es lo que está pasando con la Andi y por qué hay manifes...
#
# [129/266] Analizando: Cuáles son las carreras que muy pocos eligen estudiar en Colombia, según la IA
#   🤖 Analizando: Cuáles son las carreras que muy pocos eligen estudiar en Col...
#
# [130/266] Analizando: Fecode convoca paro nacional de 24 horas para exigir soluciones en salud
#   🤖 Analizando: Fecode convoca paro nacional de 24 horas para exigir solucio...
#
# [131/266] Analizando: Estado Unidos, en la mira de la empresa de reclutamiento Time to Hire
#   🤖 Analizando: Estado Unidos, en la mira de la empresa de reclutamiento Tim...
#
# [132/266] Analizando: Proyecto busca flexibilizar reglas para importación y comercialización de gas na
#   🤖 Analizando: Proyecto busca flexibilizar reglas para importación y comerc...
#
# [133/266] Analizando: Licencia de paternidad en Colombia podría ser de hasta tres meses
#   🤖 Analizando: Licencia de paternidad en Colombia podría ser de hasta tres ...
#
# [134/266] Analizando: Crece controversia entre Fomag y Así Vamos en Salud por informe sobre régimen es
#   🤖 Analizando: Crece controversia entre Fomag y Así Vamos en Salud por info...
#
# [135/266] Analizando: Déficit del Fomag en 2025 prende alertas sobre sostenibilidad en salud del magis
#   🤖 Analizando: Déficit del Fomag en 2025 prende alertas sobre sostenibilida...
#
# [136/266] Analizando: Nueva modalidad de aportes: cómo cotizar seguridad social con ingresos bajos
#   🤖 Analizando: Nueva modalidad de aportes: cómo cotizar seguridad social co...
#
# [137/266] Analizando: Seguros Bolívar alcanzó $2,87 billones en primas emitidas en el primer semestre
#   🤖 Analizando: Seguros Bolívar alcanzó $2,87 billones en primas emitidas en...
#
# [138/266] Analizando: Pese a amenazas de Trump, UE impuso millonaria multa a Google: ¿por qué?
#   🤖 Analizando: Pese a amenazas de Trump, UE impuso millonaria multa a Googl...
#
# [139/266] Analizando: Precandidatos presidenciales presentan propuestas en materia económica y de segu
#   🤖 Analizando: Precandidatos presidenciales presentan propuestas en materia...
#
# [140/266] Analizando: Maestros de Fecode estarán en paro de 24 horas este jueves 30 de octubre: Salud
#   🤖 Analizando: Maestros de Fecode estarán en paro de 24 horas este jueves 3...
#
# [141/266] Analizando: Agenda de protestas en Bogotá: Fecode convocó paro nacional para el 30 de octubr
#   🤖 Analizando: Agenda de protestas en Bogotá: Fecode convocó paro nacional ...
#
# [142/266] Analizando: Atención: Este será el nuevo paro nacional que vivirá Colombia el próximo 30 de
#   🤖 Analizando: Atención: Este será el nuevo paro nacional que vivirá Colomb...
#
# [143/266] Analizando: Fecode anunció paro nacional de maestros: habrá concentraciones en plazas públic
#   🤖 Analizando: Fecode anunció paro nacional de maestros: habrá concentracio...
#
# [144/266] Analizando: Escuelas cerradas: ¿hoy, martes 14 de octubre, hay paro docente en todo el país?
#   🤖 Analizando: Escuelas cerradas: ¿hoy, martes 14 de octubre, hay paro doce...
#
# [145/266] Analizando: Amsafe adhiere al paro nacional docente de la Ctera del 14 de octubre
#   🤖 Analizando: Amsafe adhiere al paro nacional docente de la Ctera del 14 d...
#
# [146/266] Analizando: Anuncian nuevo paro nacional en Colombia: la movilidad se vería impactada por co
#   🤖 Analizando: Anuncian nuevo paro nacional en Colombia: la movilidad se ve...
#
# [147/266] Analizando: El secretario de Educación afirmó que el salario docente “ha ido avanzando” desd
#   🤖 Analizando: El secretario de Educación afirmó que el salario docente “ha...
#
# [148/266] Analizando: Paro de docentes de Eje Cafetero durará 72 horas: marchas en Pereira, Armenia y
#   🤖 Analizando: Paro de docentes de Eje Cafetero durará 72 horas: marchas en...
#
# [149/266] Analizando: Docentes de Norte de Santander anuncian paro por crisis en el sistema de salud d
#   🤖 Analizando: Docentes de Norte de Santander anuncian paro por crisis en e...
#
# [150/266] Analizando: EN VIVO | Paro nacional de Fecode en Colombia: puntos y horarios de las moviliza
#   🤖 Analizando: EN VIVO | Paro nacional de Fecode en Colombia: puntos y hora...
#
# [151/266] Analizando: Maestros de Fecode estarán en paro de 24 horas este jueves 30 de octubre: Salud
#   🤖 Analizando: Maestros de Fecode estarán en paro de 24 horas este jueves 3...
#
# [152/266] Analizando: ¡Pilas! Habrá manifestaciones y marchas programadas del 28 al 31 de octubre en B
#   🤖 Analizando: ¡Pilas! Habrá manifestaciones y marchas programadas del 28 a...
#
# [153/266] Analizando: Fecode anunció paro nacional de maestros: habrá concentraciones en plazas públic
#   🤖 Analizando: Fecode anunció paro nacional de maestros: habrá concentracio...
#
# [154/266] Analizando: Sindicatos de maestros y trabajadores convocan a marchas el 14 de octubre en Bog
#   🤖 Analizando: Sindicatos de maestros y trabajadores convocan a marchas el ...
#
# [155/266] Analizando: Anuncian nuevo paro nacional en Colombia: la movilidad se vería impactada por co
#   🤖 Analizando: Anuncian nuevo paro nacional en Colombia: la movilidad se ve...
#
# [156/266] Analizando: Trabajadores anuncian toma y cierre del Ministerio de Educación, posible paro af
#   🤖 Analizando: Trabajadores anuncian toma y cierre del Ministerio de Educac...
#
# [157/266] Analizando: Paro de docentes de Eje Cafetero durará 72 horas: marchas en Pereira, Armenia y
#   🤖 Analizando: Paro de docentes de Eje Cafetero durará 72 horas: marchas en...
#
# [158/266] Analizando: Por paro de maestros en Bogotá, secretaria de Educación anunció que se le descon
#   🤖 Analizando: Por paro de maestros en Bogotá, secretaria de Educación anun...
#
# [159/266] Analizando: Secretaría de Educación reveló qué pasará con los colegios en Bogotá durante el
#   🤖 Analizando: Secretaría de Educación reveló qué pasará con los colegios e...
#
# [160/266] Analizando: Maestros de Fecode estarán en paro de 24 horas este jueves 30 de octubre: Salud
#   🤖 Analizando: Maestros de Fecode estarán en paro de 24 horas este jueves 3...
#
# [161/266] Analizando: Fecode anunció nueva jornada de paro: estudiantes no tendrían clase
#   🤖 Analizando: Fecode anunció nueva jornada de paro: estudiantes no tendría...
#
# [162/266] Analizando: Atención: Este será el nuevo paro nacional que vivirá Colombia el próximo 30 de
#   🤖 Analizando: Atención: Este será el nuevo paro nacional que vivirá Colomb...
#
# [163/266] Analizando: Fecode confirma paro nacional de 24 horas este 30 de octubre: principales causas
#   🤖 Analizando: Fecode confirma paro nacional de 24 horas este 30 de octubre...
#
# [164/266] Analizando: Fecode anunció paro nacional de maestros: habrá concentraciones en plazas públic
#   🤖 Analizando: Fecode anunció paro nacional de maestros: habrá concentracio...
#
# [165/266] Analizando: Fecode convoca paro nacional de maestros para el 30 de octubre por crisis en el
#   🤖 Analizando: Fecode convoca paro nacional de maestros para el 30 de octub...
#
# [166/266] Analizando: Gobierno nacional y sindicatos del sector educación lograron acuerdo tras advert
#   🤖 Analizando: Gobierno nacional y sindicatos del sector educación lograron...
#
# [167/266] Analizando: Fecode anuncia paro por crisis en el nuevo modelo de salud del magisterio
#   🤖 Analizando: Fecode anuncia paro por crisis en el nuevo modelo de salud d...
#
# [168/266] Analizando: Fecode se une a marchas del 18 de marzo en Colombia: exigen reforma laboral y me
#   🤖 Analizando: Fecode se une a marchas del 18 de marzo en Colombia: exigen ...
#
# [169/266] Analizando: Fecode anuncia movilizaciones para este 23 de octubre en varias regiones del paí
#   🤖 Analizando: Fecode anuncia movilizaciones para este 23 de octubre en var...
#
# [170/266] Analizando: Los conflictos sociales paralizan a Panamá
#   🤖 Analizando: Los conflictos sociales paralizan a Panamá...
#
# [171/266] Analizando: Paro nacional 28 y 29 mayo: quiénes, dónde y por qué marchan en Colombia
#   🤖 Analizando: Paro nacional 28 y 29 mayo: quiénes, dónde y por qué marchan...
#
# [172/266] Analizando: Paros de maestros: la tensión entre la protesta y la educación en Bogotá
#   🤖 Analizando: Paros de maestros: la tensión entre la protesta y la educaci...
#
# [173/266] Analizando: Fecode anuncia paro por crisis en el nuevo modelo de salud del magisterio
#   🤖 Analizando: Fecode anuncia paro por crisis en el nuevo modelo de salud d...
#
# [174/266] Analizando: SUTEP INICIARÁ HUELGA ESCALONADA EL 16 DE OCTUBRE ANTE LA DESATENCIÓN DEL GOBIER
#   🤖 Analizando: SUTEP INICIARÁ HUELGA ESCALONADA EL 16 DE OCTUBRE ANTE LA DE...
#
# [175/266] Analizando: Paro camionero 2024: análisis desde lo económico y lo político
#   🤖 Analizando: Paro camionero 2024: análisis desde lo económico y lo políti...
#
# [176/266] Analizando: Sutep cumple quinto día de huelga de hambre por el salario digno: tres maestros
#   🤖 Analizando: Sutep cumple quinto día de huelga de hambre por el salario d...
#
# [177/266] Analizando: María Fernanda Cabal propuso, otra vez, ley que busca proteger el derecho a la e
#   🤖 Analizando: María Fernanda Cabal propuso, otra vez, ley que busca proteg...
#
# [178/266] Analizando: Se levanta el paro de maestros tras el hundimiento de la reforma a la educación
#   🤖 Analizando: Se levanta el paro de maestros tras el hundimiento de la ref...
#
# [179/266] Analizando: Los maestros oficiales anuncian un paro en su puja por priorizar la educación pú
#   🤖 Analizando: Los maestros oficiales anuncian un paro en su puja por prior...
#
# [180/266] Analizando: Maestros pensionados protestan por reincorporación a seguro de sobrevivencia
#   🤖 Analizando: Maestros pensionados protestan por reincorporación a seguro ...
#
# [181/266] Analizando: Educación cesanteó a más de cien docentes que protestaban en la plaza
#   🤖 Analizando: Educación cesanteó a más de cien docentes que protestaban en...
#
# [182/266] Analizando: Lucha, ingenio y crisis: hitos del sector educativo venezolano en los últimos ci
#   🤖 Analizando: Lucha, ingenio y crisis: hitos del sector educativo venezola...
#
# [183/266] Analizando: Moviliza a padres la falta de maestros
#   🤖 Analizando: Moviliza a padres la falta de maestros...
#
# [184/266] Analizando: Comando Intersindical de Maestros espera por reunión con la gobernación
#   🤖 Analizando: Comando Intersindical de Maestros espera por reunión con la ...
#
# [185/266] Analizando: ADP inicia protesta frente al Ministerio de Educación en demanda de aumento sala
#   🤖 Analizando: ADP inicia protesta frente al Ministerio de Educación en dem...
#
# [186/266] Analizando: Sigue la toma de la Secretaría de Educación de Bogotá: protestas de profesores i
#   🤖 Analizando: Sigue la toma de la Secretaría de Educación de Bogotá: prote...
#
# [187/266] Analizando: Docentes invisibles: Gobierno venezolano eclipsa protestas docentes con propagan
#   🤖 Analizando: Docentes invisibles: Gobierno venezolano eclipsa protestas d...
#
# [188/266] Analizando: Docentes ignorados: la protesta se mantiene en pleno año electoral
#   🤖 Analizando: Docentes ignorados: la protesta se mantiene en pleno año ele...
#
# [189/266] Analizando: Con protestas, deserción docente y niños con virus empezó la primera semana de c
#   🤖 Analizando: Con protestas, deserción docente y niños con virus empezó la...
#
# [190/266] Analizando: Bicitaxistas de Bogotá dicen que regulación pone en riesgo su sustento
#   🤖 Analizando: Bicitaxistas de Bogotá dicen que regulación pone en riesgo s...
#
# [191/266] Analizando: Bloqueos TransMilenio este jueves afectaron a 1.800.000 personas: Alcalde Galán
#   🤖 Analizando: Bloqueos TransMilenio este jueves afectaron a 1.800.000 pers...
#
# [192/266] Analizando: Paro Nacional: todo lo que debe saber sobre las movilizaciones del 28 y 29 de ma
#   🤖 Analizando: Paro Nacional: todo lo que debe saber sobre las movilizacion...
#
# [193/266] Analizando: Así está la movilidad en Bogotá por manifestaciones hoy sábado 23 de noviembre
#   🤖 Analizando: Así está la movilidad en Bogotá por manifestaciones hoy sába...
#
# [194/266] Analizando: Bogotá registra la tasa de desempleo más baja en los últimos ocho años
#   🤖 Analizando: Bogotá registra la tasa de desempleo más baja en los últimos...
#
# [195/266] Analizando: Taxistas convocaron a paro en 13 ciudades del país, estos son los puntos de conc
#   🤖 Analizando: Taxistas convocaron a paro en 13 ciudades del país, estos so...
#
# [196/266] Analizando: El paro de camioneros por el alza del diésel enfrenta a Petro con su pasado
#   🤖 Analizando: El paro de camioneros por el alza del diésel enfrenta a Petr...
#
# [197/266] Analizando: Paro de camioneros este 30 de agosto en Bogotá: anuncian punto de concentración
#   🤖 Analizando: Paro de camioneros este 30 de agosto en Bogotá: anuncian pun...
#
# [198/266] Analizando: Fecode: ¿Por qué la evaluación docente divide a Gobierno y profesores, al punto
#   🤖 Analizando: Fecode: ¿Por qué la evaluación docente divide a Gobierno y p...
#
# [199/266] Analizando: Las agresiones del Esmad después de 2021: las amenazas llevan al exilio a la fam
#   🤖 Analizando: Las agresiones del Esmad después de 2021: las amenazas lleva...
#
# [200/266] Analizando: Agenda de protestas en Bogotá: Fecode convocó paro nacional para el 30 de octubr
#   🤖 Analizando: Agenda de protestas en Bogotá: Fecode convocó paro nacional ...
#
# [201/266] Analizando: Fecode anunció nueva jornada de paro: estudiantes no tendrían clase
#   🤖 Analizando: Fecode anunció nueva jornada de paro: estudiantes no tendría...
#
# [202/266] Analizando: Atención: Este será el nuevo paro nacional que vivirá Colombia el próximo 30 de
#   🤖 Analizando: Atención: Este será el nuevo paro nacional que vivirá Colomb...
#
# [203/266] Analizando: Fecode anunció paro nacional de maestros: habrá concentraciones en plazas públic
#   🤖 Analizando: Fecode anunció paro nacional de maestros: habrá concentracio...
#
# [204/266] Analizando: Anuncian nuevo paro nacional en Colombia: la movilidad se vería impactada por co
#   🤖 Analizando: Anuncian nuevo paro nacional en Colombia: la movilidad se ve...
#
# [205/266] Analizando: ¿Petro anunció veladamente el fin del Fomag y del régimen exceptuado del magiste
#   🤖 Analizando: ¿Petro anunció veladamente el fin del Fomag y del régimen ex...
#
# [206/266] Analizando: Maestros de nuevo se van a paro, impactará en tres regiones, vea las razones y f
#   🤖 Analizando: Maestros de nuevo se van a paro, impactará en tres regiones,...
#
# [207/266] Analizando: Gobierno y sindicatos acuerdan aumento salarial para maestros: este será el porc
#   🤖 Analizando: Gobierno y sindicatos acuerdan aumento salarial para maestro...
#
# [208/266] Analizando: Gobierno nacional y sindicatos del sector educación lograron acuerdo tras advert
#   🤖 Analizando: Gobierno nacional y sindicatos del sector educación lograron...
#
# [209/266] Analizando: Maestros anuncian paro indefinido en julio y el cierre de 7.000 instituciones ed
#   🤖 Analizando: Maestros anuncian paro indefinido en julio y el cierre de 7....
#
# [210/266] Analizando: Trabajadores anuncian toma y cierre del Ministerio de Educación, posible paro af
#   🤖 Analizando: Trabajadores anuncian toma y cierre del Ministerio de Educac...
#
# [211/266] Analizando: El Gobierno anunció un aumento salarial a docentes y no docentes universitarios
#   🤖 Analizando: El Gobierno anunció un aumento salarial a docentes y no doce...
#
# [212/266] Analizando: María Fernanda Cabal le pidió al ministro de Educación garantizar el servicio ed
#   🤖 Analizando: María Fernanda Cabal le pidió al ministro de Educación garan...
#
# [213/266] Analizando: Gobierno y sindicatos acuerdan aumento salarial para maestros: este será el porc
#   🤖 Analizando: Gobierno y sindicatos acuerdan aumento salarial para maestro...
#
# [214/266] Analizando: Gobierno nacional y sindicatos del sector educación lograron acuerdo tras advert
#   🤖 Analizando: Gobierno nacional y sindicatos del sector educación lograron...
#
# [215/266] Analizando: La Universidad de Buenos Aires adhiere al paro docente: cómo será la protesta y
#   🤖 Analizando: La Universidad de Buenos Aires adhiere al paro docente: cómo...
#
# [216/266] Analizando: Echaron a 117 docentes que faltaron más de 130 días en 2023 tras un paro
#   🤖 Analizando: Echaron a 117 docentes que faltaron más de 130 días en 2023 ...
#
# [217/266] Analizando: Paro nacional: ¿Habrá clases escolares este miércoles 23 de octubre? Minedu anun
#   🤖 Analizando: Paro nacional: ¿Habrá clases escolares este miércoles 23 de ...
#
# [218/266] Analizando: Huelga del Sutep: ministro de Educación anunció bono y aumento salarial ante el
#   🤖 Analizando: Huelga del Sutep: ministro de Educación anunció bono y aumen...
#
# [219/266] Analizando: Paro nacional del Sutep: docentes protestan en Lima, Arequipa, Ica y Loreto por
#   🤖 Analizando: Paro nacional del Sutep: docentes protestan en Lima, Arequip...
#
# [220/266] Analizando: Atención: Este será el nuevo paro nacional que vivirá Colombia el próximo 30 de
#   🤖 Analizando: Atención: Este será el nuevo paro nacional que vivirá Colomb...
#
# [221/266] Analizando: Fecode confirma paro nacional de 24 horas este 30 de octubre: principales causas
#   🤖 Analizando: Fecode confirma paro nacional de 24 horas este 30 de octubre...
#
# [222/266] Analizando: Fecode anunció paro nacional de maestros: habrá concentraciones en plazas públic
#   🤖 Analizando: Fecode anunció paro nacional de maestros: habrá concentracio...
#
# [223/266] Analizando: Escuelas cerradas: ¿hoy, martes 14 de octubre, hay paro docente en todo el país?
#   🤖 Analizando: Escuelas cerradas: ¿hoy, martes 14 de octubre, hay paro doce...
#
# [224/266] Analizando: Amsafe adhiere al paro nacional docente de la Ctera del 14 de octubre
#   🤖 Analizando: Amsafe adhiere al paro nacional docente de la Ctera del 14 d...
#
# [225/266] Analizando: Paro docente nacional convocado por CTERA: suspenden clases en todo el país
#   🤖 Analizando: Paro docente nacional convocado por CTERA: suspenden clases ...
#
# [226/266] Analizando: El secretario de Educación afirmó que el salario docente “ha ido avanzando” desd
#   🤖 Analizando: El secretario de Educación afirmó que el salario docente “ha...
#
# [227/266] Analizando: Luego del paro de maestros y de trabajadores de la educación, convocan a otro qu
#   🤖 Analizando: Luego del paro de maestros y de trabajadores de la educación...
#
# [228/266] Analizando: Paro nacional indefinido en educación en Colombia se definiría el 12 de septiemb
#   🤖 Analizando: Paro nacional indefinido en educación en Colombia se definir...
#
# [229/266] Analizando: Paro de empleados administrativos pone en vilo a colegios públicos: posible cier
#   🤖 Analizando: Paro de empleados administrativos pone en vilo a colegios pú...
#
# [230/266] Analizando: Por el paro de ATE, escuelas tandilenses suspenden las clases del jueves
#   🤖 Analizando: Por el paro de ATE, escuelas tandilenses suspenden las clase...
#
# [231/266] Analizando: La UNLP arranca la primera de dos jornadas de paro para reclamar por la Ley de F
#   🤖 Analizando: La UNLP arranca la primera de dos jornadas de paro para recl...
#
# [232/266] Analizando: Docentes y no docentes de la UNLP paran en medio del conflicto por la Ley de Fin
#   🤖 Analizando: Docentes y no docentes de la UNLP paran en medio del conflic...
#
# [233/266] Analizando: Suspenden clases en Atacama para evaluar daños tras fuerte sismo
#   🤖 Analizando: Suspenden clases en Atacama para evaluar daños tras fuerte s...
#
# [234/266] Analizando: SEP exhibe a la CNTE por paro de maestros: ¿Cuántas escuelas no tienen clases y
#   🤖 Analizando: SEP exhibe a la CNTE por paro de maestros: ¿Cuántas escuelas...
#
# [235/266] Analizando: ¿Adiós a las clases?: esto pasará si el sindicato de docentes se une al paro nac
#   🤖 Analizando: ¿Adiós a las clases?: esto pasará si el sindicato de docente...
#
# [236/266] Analizando: Paro de 48 horas en Santander: anuncian marchas y suspensión de clases
#   🤖 Analizando: Paro de 48 horas en Santander: anuncian marchas y suspensión...
#
# [237/266] Analizando: Día del Maestro 2025: Sin clases y con paro nacional en diez estados
#   🤖 Analizando: Día del Maestro 2025: Sin clases y con paro nacional en diez...
#
# [238/266] Analizando: Colegios sin clases presenciales por paro de transporte: Minedu dispone virtuali
#   🤖 Analizando: Colegios sin clases presenciales por paro de transporte: Min...
#
# [239/266] Analizando: Padres de familia en Cozumel preocupados por suspensión de clases por paro de ma
#   🤖 Analizando: Padres de familia en Cozumel preocupados por suspensión de c...
#
# [240/266] Analizando: Fecode anuncia paro nacional de maestros por 24 horas ...
#   🤖 Analizando: Fecode anuncia paro nacional de maestros por 24 horas ......
#
# [241/266] Analizando: Convocan a paro nacional de profesores para este 30 ...
#   🤖 Analizando: Convocan a paro nacional de profesores para este 30 ......
#
# [242/266] Analizando: Los viejos y nuevos motivos de las marchas ...
#   🤖 Analizando: Los viejos y nuevos motivos de las marchas ......
#
# [243/266] Analizando: Secretaría de Prensa y Comunicaciones
#   🤖 Analizando: Secretaría de Prensa y Comunicaciones...
#
# [244/266] Analizando: ¿Cuándo hay paro de FECODE 2023? Día de marchas y ...
#   🤖 Analizando: ¿Cuándo hay paro de FECODE 2023? Día de marchas y ......
#
# [245/266] Analizando: Estudiantes pierden hasta un 35% del tiempo de clase al ...
#   🤖 Analizando: Estudiantes pierden hasta un 35% del tiempo de clase al ......
#
# [246/266] Analizando: ¿Qué día es el paro de FECODE? Razones y ciudades
#   🤖 Analizando: ¿Qué día es el paro de FECODE? Razones y ciudades...
#
# [247/266] Analizando: Fecode sale a paro este 30 de agosto: ¿por qué marchan ...
#   🤖 Analizando: Fecode sale a paro este 30 de agosto: ¿por qué marchan ......
#
# [248/266] Analizando: Paro de Fecode de este miércoles: puntos de encuentro ...
#   🤖 Analizando: Paro de Fecode de este miércoles: puntos de encuentro ......
#
# [249/266] Analizando: Fecode anunció un paro nacional para el próximo 30 de ...
#   🤖 Analizando: Fecode anunció un paro nacional para el próximo 30 de ......
#
# [250/266] Analizando: Paro nacional de profesores, 30 de agosto de 2023: fecha ...
#   🤖 Analizando: Paro nacional de profesores, 30 de agosto de 2023: fecha ......
#
# [251/266] Analizando: Paro de actividades de los estudiantes y empleados en la ...
#   🤖 Analizando: Paro de actividades de los estudiantes y empleados en la ......
#
# [252/266] Analizando: Paro Nacional 30 de Agosto: Las razones de Fecode ...
#   🤖 Analizando: Paro Nacional 30 de Agosto: Las razones de Fecode ......
#
# [253/266] Analizando: Mala administración y falta de garantías alegan ...
#   🤖 Analizando: Mala administración y falta de garantías alegan ......
#
# [254/266] Analizando: ‍♀️ Paro martes 14/03 y ⚠ASAMBLEA en 📌Escuela Julio ...
#   🤖 Analizando: ‍♀️ Paro martes 14/03 y ⚠ASAMBLEA en 📌Escuela Julio ......
#
# [255/266] Analizando: Universidad Colegio Mayor de Cundinamarca: Estudiantes ...
#   🤖 Analizando: Universidad Colegio Mayor de Cundinamarca: Estudiantes ......
#
# [256/266] Analizando: Los maestros en Colombia no podrían volver a paro
#   🤖 Analizando: Los maestros en Colombia no podrían volver a paro...
#
# [257/266] Analizando: Manifestaciones 28 de febrero en Colombia: Puntos de ...
#   🤖 Analizando: Manifestaciones 28 de febrero en Colombia: Puntos de ......
#
# [258/266] Analizando: Barranquilla: anuncian paro de maestros
#   🤖 Analizando: Barranquilla: anuncian paro de maestros...
#
# [259/266] Analizando: Fecode anuncia paro nacional de 24 horas ...
#   🤖 Analizando: Fecode anuncia paro nacional de 24 horas ......
#
# [260/266] Analizando: Fecode anuncia movilizaciones en Colombia el 27 de ...
#   🤖 Analizando: Fecode anuncia movilizaciones en Colombia el 27 de ......
#
# [261/266] Analizando: Sindicato de maestros convocó a paro el 29 y 30 de ...
#   🤖 Analizando: Sindicato de maestros convocó a paro el 29 y 30 de ......
#
# [262/266] Analizando: fecode
#   🤖 Analizando: fecode...
#
# [263/266] Analizando: Marchas de Fecode HOY 30 de agosto: Protestas EN VIVO ...
#   🤖 Analizando: Marchas de Fecode HOY 30 de agosto: Protestas EN VIVO ......
#
# [264/266] Analizando: Paro de profesores de Fecode: ¿por qué marchan este 30 ...
#   🤖 Analizando: Paro de profesores de Fecode: ¿por qué marchan este 30 ......
#
# [265/266] Analizando: Paro de maestros: Qué dice Fecode, horarios y puntos de ...
#   🤖 Analizando: Paro de maestros: Qué dice Fecode, horarios y puntos de ......
#
# [266/266] Analizando: 2K views | Reel by ADEMACOR-Asociación de Maestros y ...
#   🤖 Analizando: 2K views | Reel by ADEMACOR-Asociación de Maestros y ......
#
# 💾 FASE 3: Guardando resultados...
# ✅ Archivo guardado: noticias_paros_docentes_2023_ANALIZADO.csv
# 📊 Total de noticias analizadas: 266
#
# 📅 Normalizando formato de fechas y filtrando eventos relevantes...
# ✅ Total de eventos filtrados (Colombia/Bogotá): 55
# 📁 Archivo filtrado guardado: web_noticias_paros_docentes_2023.csv
#
# ============================================================
# 📈 ESTADÍSTICAS DEL ANÁLISIS
# ============================================================
# 🔴 Paros verdaderos (con suspensión de clases): 68
# 📍 Eventos en Bogotá: 58
# ⏱️ Duración promedio: 1.8 días
#
# 🎉 ¡Análisis completado!
