# %%
# !pip install pandas
# !pip install openpyxl
# !pip install requests
# !pip install beautifulsoup4
# !pip install newspaper3k
# !pip install selenium
# !pip install openai
# !pip install serpapi
# !pip install GoogleNews
# !pip install googlesearch-python
# !pip install google-search-results
# !pip install concurrent.futures
# !pip install lxml
# !pip install numpy
# !pip install json
# !pip install "httpx[http2]"
# !pip install "lxml[html_clean]"
# Out:
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.11/site-packages (2.1.4)
# Requirement already satisfied: numpy<2,>=1.23.2 in /opt/anaconda3/lib/python3.11/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: openpyxl in /opt/anaconda3/lib/python3.11/site-packages (3.0.10)
# Requirement already satisfied: et_xmlfile in /opt/anaconda3/lib/python3.11/site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.11/site-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.11/site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.11/site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.11/site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.11/site-packages (from requests) (2025.8.3)
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/lib/python3.11/site-packages (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/lib/python3.11/site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: newspaper3k in /opt/anaconda3/lib/python3.11/site-packages (0.2.8)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /opt/anaconda3/lib/python3.11/site-packages (from newspaper3k) (4.12.2)
# Requirement already satisfied: Pillow>=3.3.0 in /opt/anaconda3/lib/python3.11/site-packages (from newspaper3k) (10.2.0)
# Requirement already satisfied: PyYAML>=3.11 in /opt/anaconda3/lib/python3.11/site-packages (from newspaper3k) (6.0.1)
# Requirement already satisfied: cssselect>=0.9.2 in /opt/anaconda3/lib/python3.11/site-packages (from newspaper3k) (1.2.0)
# Requirement already satisfied: lxml>=3.6.0 in /opt/anaconda3/lib/python3.11/site-packages (from newspaper3k) (4.9.3)
# Requirement already satisfied: nltk>=3.2.1 in /opt/anaconda3/lib/python3.11/site-packages (from newspaper3k) (3.8.1)
# Requirement already satisfied: requests>=2.10.0 in /opt/anaconda3/lib/python3.11/site-packages (from newspaper3k) (2.31.0)
# Requirement already satisfied: feedparser>=5.2.1 in /opt/anaconda3/lib/python3.11/site-packages (from newspaper3k) (6.0.12)
# Requirement already satisfied: tldextract>=2.0.1 in /opt/anaconda3/lib/python3.11/site-packages (from newspaper3k) (3.2.0)
# Requirement already satisfied: feedfinder2>=0.0.4 in /opt/anaconda3/lib/python3.11/site-packages (from newspaper3k) (0.0.4)
# Requirement already satisfied: jieba3k>=0.35.1 in /opt/anaconda3/lib/python3.11/site-packages (from newspaper3k) (0.35.1)
# Requirement already satisfied: python-dateutil>=2.5.3 in /opt/anaconda3/lib/python3.11/site-packages (from newspaper3k) (2.8.2)
# Requirement already satisfied: tinysegmenter==0.3 in /opt/anaconda3/lib/python3.11/site-packages (from newspaper3k) (0.3)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/lib/python3.11/site-packages (from beautifulsoup4>=4.4.1->newspaper3k) (2.5)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.11/site-packages (from feedfinder2>=0.0.4->newspaper3k) (1.16.0)
# Requirement already satisfied: sgmllib3k in /opt/anaconda3/lib/python3.11/site-packages (from feedparser>=5.2.1->newspaper3k) (1.0.0)
# Requirement already satisfied: click in /opt/anaconda3/lib/python3.11/site-packages (from nltk>=3.2.1->newspaper3k) (8.1.7)
# Requirement already satisfied: joblib in /opt/anaconda3/lib/python3.11/site-packages (from nltk>=3.2.1->newspaper3k) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /opt/anaconda3/lib/python3.11/site-packages (from nltk>=3.2.1->newspaper3k) (2025.9.18)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.11/site-packages (from nltk>=3.2.1->newspaper3k) (4.65.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.10.0->newspaper3k) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.10.0->newspaper3k) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.10.0->newspaper3k) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.10.0->newspaper3k) (2025.8.3)
# Requirement already satisfied: requests-file>=1.4 in /opt/anaconda3/lib/python3.11/site-packages (from tldextract>=2.0.1->newspaper3k) (1.5.1)
# Requirement already satisfied: filelock>=3.0.8 in /opt/anaconda3/lib/python3.11/site-packages (from tldextract>=2.0.1->newspaper3k) (3.13.1)
# Requirement already satisfied: selenium in /opt/anaconda3/lib/python3.11/site-packages (4.35.0)
# Requirement already satisfied: urllib3<3.0,>=2.5.0 in /opt/anaconda3/lib/python3.11/site-packages (from urllib3[socks]<3.0,>=2.5.0->selenium) (2.5.0)
# Requirement already satisfied: trio~=0.30.0 in /opt/anaconda3/lib/python3.11/site-packages (from selenium) (0.30.0)
# Requirement already satisfied: trio-websocket~=0.12.2 in /opt/anaconda3/lib/python3.11/site-packages (from selenium) (0.12.2)
# Requirement already satisfied: certifi>=2025.6.15 in /opt/anaconda3/lib/python3.11/site-packages (from selenium) (2025.8.3)
# Requirement already satisfied: typing_extensions~=4.14.0 in /opt/anaconda3/lib/python3.11/site-packages (from selenium) (4.14.1)
# Requirement already satisfied: websocket-client~=1.8.0 in /opt/anaconda3/lib/python3.11/site-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from trio~=0.30.0->selenium) (25.3.0)
# Requirement already satisfied: sortedcontainers in /opt/anaconda3/lib/python3.11/site-packages (from trio~=0.30.0->selenium) (2.4.0)
# Requirement already satisfied: idna in /opt/anaconda3/lib/python3.11/site-packages (from trio~=0.30.0->selenium) (3.4)
# Requirement already satisfied: outcome in /opt/anaconda3/lib/python3.11/site-packages (from trio~=0.30.0->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in /opt/anaconda3/lib/python3.11/site-packages (from trio~=0.30.0->selenium) (1.3.0)
# Requirement already satisfied: wsproto>=0.14 in /opt/anaconda3/lib/python3.11/site-packages (from trio-websocket~=0.12.2->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /opt/anaconda3/lib/python3.11/site-packages (from urllib3[socks]<3.0,>=2.5.0->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /opt/anaconda3/lib/python3.11/site-packages (from wsproto>=0.14->trio-websocket~=0.12.2->selenium) (0.16.0)
# Requirement already satisfied: openai in /opt/anaconda3/lib/python3.11/site-packages (2.0.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/anaconda3/lib/python3.11/site-packages (from openai) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/anaconda3/lib/python3.11/site-packages (from openai) (1.8.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/anaconda3/lib/python3.11/site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /opt/anaconda3/lib/python3.11/site-packages (from openai) (0.11.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /opt/anaconda3/lib/python3.11/site-packages (from openai) (1.10.12)
# Requirement already satisfied: sniffio in /opt/anaconda3/lib/python3.11/site-packages (from openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in /opt/anaconda3/lib/python3.11/site-packages (from openai) (4.65.0)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /opt/anaconda3/lib/python3.11/site-packages (from openai) (4.14.1)
# Requirement already satisfied: idna>=2.8 in /opt/anaconda3/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai) (3.4)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /opt/anaconda3/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: serpapi in /opt/anaconda3/lib/python3.11/site-packages (0.1.5)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.11/site-packages (from serpapi) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.11/site-packages (from requests->serpapi) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.11/site-packages (from requests->serpapi) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.11/site-packages (from requests->serpapi) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.11/site-packages (from requests->serpapi) (2025.8.3)
# Requirement already satisfied: GoogleNews in /opt/anaconda3/lib/python3.11/site-packages (1.6.15)
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/lib/python3.11/site-packages (from GoogleNews) (4.12.2)
# Requirement already satisfied: dateparser in /opt/anaconda3/lib/python3.11/site-packages (from GoogleNews) (1.2.2)
# Requirement already satisfied: python-dateutil in /opt/anaconda3/lib/python3.11/site-packages (from GoogleNews) (2.8.2)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/lib/python3.11/site-packages (from beautifulsoup4->GoogleNews) (2.5)
# Requirement already satisfied: pytz>=2024.2 in /opt/anaconda3/lib/python3.11/site-packages (from dateparser->GoogleNews) (2025.2)
# Requirement already satisfied: regex>=2024.9.11 in /opt/anaconda3/lib/python3.11/site-packages (from dateparser->GoogleNews) (2025.9.18)
# Requirement already satisfied: tzlocal>=0.2 in /opt/anaconda3/lib/python3.11/site-packages (from dateparser->GoogleNews) (2.1)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.11/site-packages (from python-dateutil->GoogleNews) (1.16.0)
# Requirement already satisfied: googlesearch-python in /opt/anaconda3/lib/python3.11/site-packages (1.3.0)
# Requirement already satisfied: beautifulsoup4>=4.9 in /opt/anaconda3/lib/python3.11/site-packages (from googlesearch-python) (4.12.2)
# Requirement already satisfied: requests>=2.20 in /opt/anaconda3/lib/python3.11/site-packages (from googlesearch-python) (2.31.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/lib/python3.11/site-packages (from beautifulsoup4>=4.9->googlesearch-python) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.20->googlesearch-python) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.20->googlesearch-python) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.20->googlesearch-python) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.20->googlesearch-python) (2025.8.3)
# Requirement already satisfied: google-search-results in /opt/anaconda3/lib/python3.11/site-packages (2.4.2)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.11/site-packages (from google-search-results) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.11/site-packages (from requests->google-search-results) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.11/site-packages (from requests->google-search-results) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.11/site-packages (from requests->google-search-results) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.11/site-packages (from requests->google-search-results) (2025.8.3)
# ERROR: Could not find a version that satisfies the requirement concurrent.futures (from versions: none)
# ERROR: No matching distribution found for concurrent.futures
# Requirement already satisfied: lxml in /opt/anaconda3/lib/python3.11/site-packages (4.9.3)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.11/site-packages (1.26.4)
# ERROR: Could not find a version that satisfies the requirement json (from versions: none)
# ERROR: No matching distribution found for json
# Requirement already satisfied: httpx[http2] in /opt/anaconda3/lib/python3.11/site-packages (0.28.1)
# Requirement already satisfied: anyio in /opt/anaconda3/lib/python3.11/site-packages (from httpx[http2]) (4.2.0)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.11/site-packages (from httpx[http2]) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.11/site-packages (from httpx[http2]) (1.0.9)
# Requirement already satisfied: idna in /opt/anaconda3/lib/python3.11/site-packages (from httpx[http2]) (3.4)
# Requirement already satisfied: h2<5,>=3 in /opt/anaconda3/lib/python3.11/site-packages (from httpx[http2]) (4.3.0)
# Requirement already satisfied: h11>=0.16 in /opt/anaconda3/lib/python3.11/site-packages (from httpcore==1.*->httpx[http2]) (0.16.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in /opt/anaconda3/lib/python3.11/site-packages (from h2<5,>=3->httpx[http2]) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /opt/anaconda3/lib/python3.11/site-packages (from h2<5,>=3->httpx[http2]) (4.1.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/anaconda3/lib/python3.11/site-packages (from anyio->httpx[http2]) (1.3.0)
# Requirement already satisfied: lxml[html_clean] in /opt/anaconda3/lib/python3.11/site-packages (4.9.3)
# WARNING: lxml 4.9.3 does not provide the extra 'html-clean'

# %%
import re
from dateutil import parser
from tabulate import tabulate
import pandas as pd
import requests
from bs4 import BeautifulSoup
from urllib.parse import quote_plus
import time
import random
from datetime import datetime
from GoogleNews import GoogleNews
from serpapi import GoogleSearch
import pandas as pd
from openai import OpenAI
import json
from urllib.parse import urljoin, urlparse

# %%
# ================================================================
# Keys
# ================================================================


SESSION = requests.Session()
SESSION.headers.update({'User-Agent': 'Mozilla/5.0 (compatible; EduNews/3.1)'})
SESSION_TIMEOUT = 15
client = OpenAI(api_key=OPENAI_API_KEY)

# %%
# ================================================================
# EXTENDIDO
# ================================================================
HEADERS = {'User-Agent': 'Mozilla/5.0'}
TIMEOUT = 10
MAX_RESULTS = 300
YEAR = "2023"

def link_valido(url):
    try:
        r = requests.head(url, timeout=5, allow_redirects=True)
        return r.status_code == 200
    except:
        return False


# ================================================================
#  SCRAPING DE FUENTES ESPECÍFICAS
# ================================================================
def buscar_noticias_generales(nombre_fuente, url_base, termino_busqueda, max_resultados=150):
    """Scrapea noticias desde sitios como El Tiempo, ADE o FECODE."""
    print(f"\n🔍 Buscando en {nombre_fuente}: {termino_busqueda}")
    datos = []
    termino_codificado = quote_plus(termino_busqueda)
    url_busqueda = f"{url_base}{termino_codificado}"

    headers = {'User-Agent': 'Mozilla/5.0'}

    try:
        response = requests.get(url_busqueda, headers=headers, timeout=20)
        response.raise_for_status()
        soup = BeautifulSoup(response.content, 'html.parser')

        articulos = soup.find_all('article', limit=max_resultados)
        print(f"Encontrados {len(articulos)} artículos en {nombre_fuente}")

        for art in articulos:
            titulo = (art.find('h2') or art.find('h3'))
            enlace = art.find('a', href=True)

            if not titulo or not enlace:
                continue

            link = enlace['href']
            if not link.startswith('http'):
            # Tu método preferido
                provisional = f"{url_base.rstrip('/')}/{link.lstrip('/')}"
                parsed = urlparse(provisional)

            # Si el link se ve bien, lo usamos; si no, fallback a urljoin
                if parsed.scheme and parsed.netloc:
                    link = provisional
                else:
                    link = urljoin(url_base, link)

            #if not link_valido(link):
            #    continue

            descripcion = art.find('p').get_text(strip=True) if art.find('p') else ''
            fecha_elem = art.find('time')
            fecha = fecha_elem.get_text(strip=True) if fecha_elem else 'No especificada'

            datos.append({
                'fuente': nombre_fuente,
                'titulo': titulo.get_text(strip=True),
                'descripcion': descripcion,
                'fecha_publicacion': fecha,
                'url': link,
                'periodo_busqueda': termino_busqueda,
                'fecha_extraccion': datetime.now().strftime('%Y-%m-%d %H:%M:%S')
            })

    except Exception as e:
        print(f"❌ Error en {nombre_fuente}: {e}")

    time.sleep(random.uniform(1.5, 3.5))
    return datos


# ================================================================
#  GOOGLE NEWS
# ================================================================
def buscar_con_googlenews():
    googlenews = GoogleNews(lang='es', encode='utf-8')
    googlenews.set_time_range('12/01/2022', '02/01/2024')
    resultados = []

    queries = [
    f'paro docente Colombia {YEAR}',
    f'paro maestros Bogotá {YEAR}',
    f'FECODE paro {YEAR}',
    f'huelga de profesores Colombia {YEAR}',
    f'protestas docentes educación {YEAR}',
    f'ADE Bogotá paro {YEAR}',
    f'magisterio colombiano paro {YEAR}',
    f'ministerio educación paro maestros {YEAR}',
    f'paro educativo nacional Colombia {YEAR}',
    f'suspensión de clases por paro docente {YEAR}'
]


    for q in queries:
        googlenews.search(q)
        time.sleep(random.uniform(2, 4))
        res = googlenews.result()
        for r in res:
            resultados.append({
                'fuente': r.get('media', 'GoogleNews'),
                'titulo': r.get('title'),
                'descripcion': r.get('desc', ''),
                'url': r.get('link', ''),
                'fecha_publicacion': r.get('date', ''),
                'periodo_busqueda': q,
                'fecha_extraccion': datetime.now().strftime("%Y-%m-%d %H:%M:%S")
            })
    print(f"✅ GoogleNews: {len(resultados)} resultados")
    return resultados


# ================================================================
#  SERPAPI
# ================================================================
def buscar_con_serpapi(api_key):
    print("\n🔍 Buscando con SerpAPI...")
    resultados = []
    queries = [
    f'(paro docente OR paro maestros OR huelga profesores OR FECODE OR ADE) Colombia {YEAR}',
    f'(paro educativo OR suspensión clases) Bogotá {YEAR}',
    f'(FECODE protesta OR paro) Colombia {YEAR}',
    f'(magisterio colombiano OR sindicato maestros) paro {YEAR}',
    f'site:fecode.edu.co ("paro docente" OR "suspensión de clases" OR "cese de actividades" OR "movilización" OR "protesta magisterial" OR "huelga de maestros") {YEAR}',
    ]


    for query in queries:
        params = {
            "engine": "google",
            "q": f"{query} after:2022-12-01 before:2024-02-01",
            "api_key": api_key,
            "num": 190
        }
        try:
            search = GoogleSearch(params)
            results = search.get_dict()
            items = results.get("organic_results", [])
            for item in items:
                resultados.append({
                    'fuente': 'Google (SerpAPI)',
                    'titulo': item.get('title'),
                    'descripcion': item.get('snippet', ''),
                    'url': item.get('link'),
                    'fecha_publicacion': '',
                    'periodo_busqueda': query,
                    'fecha_extraccion': datetime.now().strftime("%Y-%m-%d %H:%M:%S")
                })
        except Exception as e:
            print(f"❌ Error en SerpAPI: {e}")
            time.sleep(random.uniform(1, 2))
    print(f" SerpAPI: {len(resultados)} resultados")
    return resultados

# ================================================================
#  EJECUCIÓN PRINCIPAL
# ================================================================

if __name__ == "__main__":
    print("="*60)
    print(" INICIANDO SCRAPER + ANÁLISIS IA")
    print("="*60)

    resultados_totales = []

    # 1) Fuentes* oficiales primero
    print("\n FASE 1: Recopilando noticias...")

    fuentes = {
        "FECODE": "https://fecode.edu.co/?s=",
        "ADE Bogotá": "https://adebogota.org/index.php/buscar?q=",
        "SED Bogotá": "https://www.educacionbogota.edu.co/noticias?field_noticia_descripcion_value=",
        "Red Académica": "https://www.redacademica.edu.co/resultados-busqueda?search_api_fulltext=",

        # Gobierno Distrital
        "Bogotá.gov": "https://bogota.gov.co/busqueda?search_api_fulltext=",

        # Medios de comunicación nacionales – educación
        "El Tiempo": "https://www.eltiempo.com/buscar/",
        "El Espectador": "https://www.elespectador.com/buscador/",
        "Noticias Caracol": "https://www.noticiascaracol.com/busqueda?q=",
        "Portafolio": "https://www.portafolio.co/buscar?q=",
        "Valora Analitik": "https://www.valoraanalitik.com/?s=",
        "La FM (Educación)": "https://www.lafm.com.co/educacion",
        "Radionacional (Educación)": "https://www.radionacional.co/actualidad/educacion",
        "Red + Noticias": "https://redmas.com.co/colombia/"
    }
    terminos = [
    "paro docentes",
    "paro maestros",
    f"suspensión de clases {YEAR}",
    f"cese de actividades escolares {YEAR}",
    f"FECODE {YEAR}",
    "huelga de profesores",
    f"protesta docente {YEAR}"
    ]  
    for fuente, url_base in fuentes.items():
        for termino in terminos:
            resultados_totales.extend(
                buscar_noticias_generales(fuente, url_base, termino)
            )
            time.sleep(random.uniform(2, 4))

   # 2) GoogleNews y SerpAPI
    resultados_totales.extend(buscar_con_googlenews())
    resultados_totales.extend(buscar_con_serpapi(SerpAPI_tkn1))

    df = pd.DataFrame(resultados_totales).drop_duplicates(subset="url")
    df.to_csv("noticias_paros_docentes_2023_SUPER.csv", index=False, encoding="utf-8-sig")

    print(f"\n✅ Total de noticias recopiladas: {len(resultados_totales)}")
# Out:
# ============================================================
#  INICIANDO SCRAPER + ANÁLISIS IA
# ============================================================
#
#  FASE 1: Recopilando noticias...
#
# 🔍 Buscando en FECODE: paro docentes
# Encontrados 4 artículos en FECODE
#
# 🔍 Buscando en FECODE: paro maestros
# Encontrados 2 artículos en FECODE
#
# 🔍 Buscando en FECODE: suspensión de clases 2023
# Encontrados 0 artículos en FECODE
#
# 🔍 Buscando en FECODE: cese de actividades escolares 2023
# Encontrados 0 artículos en FECODE
#
# 🔍 Buscando en FECODE: FECODE 2023
# Encontrados 5 artículos en FECODE
#
# 🔍 Buscando en FECODE: huelga de profesores
# Encontrados 0 artículos en FECODE
#
# 🔍 Buscando en FECODE: protesta docente 2023
# Encontrados 1 artículos en FECODE
#
# 🔍 Buscando en ADE Bogotá: paro docentes
# Encontrados 0 artículos en ADE Bogotá
#
# 🔍 Buscando en ADE Bogotá: paro maestros
# Encontrados 0 artículos en ADE Bogotá
#
# 🔍 Buscando en ADE Bogotá: suspensión de clases 2023
# Encontrados 0 artículos en ADE Bogotá
#
# 🔍 Buscando en ADE Bogotá: cese de actividades escolares 2023
# Encontrados 0 artículos en ADE Bogotá
#
# 🔍 Buscando en ADE Bogotá: FECODE 2023
# Encontrados 0 artículos en ADE Bogotá
#
# 🔍 Buscando en ADE Bogotá: huelga de profesores
# Encontrados 0 artículos en ADE Bogotá
#
# 🔍 Buscando en ADE Bogotá: protesta docente 2023
# Encontrados 0 artículos en ADE Bogotá
#
# 🔍 Buscando en SED Bogotá: paro docentes
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Encontrados 0 artículos en SED Bogotá
#
# 🔍 Buscando en SED Bogotá: paro maestros
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Encontrados 0 artículos en SED Bogotá
#
# 🔍 Buscando en SED Bogotá: suspensión de clases 2023
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Encontrados 0 artículos en SED Bogotá
#
# 🔍 Buscando en SED Bogotá: cese de actividades escolares 2023
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Encontrados 0 artículos en SED Bogotá
#
# 🔍 Buscando en SED Bogotá: FECODE 2023
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Encontrados 0 artículos en SED Bogotá
#
# 🔍 Buscando en SED Bogotá: huelga de profesores
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Encontrados 0 artículos en SED Bogotá
#
# 🔍 Buscando en SED Bogotá: protesta docente 2023
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# Encontrados 0 artículos en SED Bogotá
#
# 🔍 Buscando en Red Académica: paro docentes
# Encontrados 14 artículos en Red Académica
#
# 🔍 Buscando en Red Académica: paro maestros
# Encontrados 12 artículos en Red Académica
#
# 🔍 Buscando en Red Académica: suspensión de clases 2023
# Encontrados 12 artículos en Red Académica
#
# 🔍 Buscando en Red Académica: cese de actividades escolares 2023
# Encontrados 13 artículos en Red Académica
#
# 🔍 Buscando en Red Académica: FECODE 2023
# Encontrados 12 artículos en Red Académica
#
# 🔍 Buscando en Red Académica: huelga de profesores
# Encontrados 12 artículos en Red Académica
#
# 🔍 Buscando en Red Académica: protesta docente 2023
# Encontrados 12 artículos en Red Académica
#
# 🔍 Buscando en Bogotá.gov: paro docentes
# Encontrados 0 artículos en Bogotá.gov
#
# 🔍 Buscando en Bogotá.gov: paro maestros
# Encontrados 0 artículos en Bogotá.gov
#
# 🔍 Buscando en Bogotá.gov: suspensión de clases 2023
# Encontrados 0 artículos en Bogotá.gov
#
# 🔍 Buscando en Bogotá.gov: cese de actividades escolares 2023
# Encontrados 0 artículos en Bogotá.gov
#
# 🔍 Buscando en Bogotá.gov: FECODE 2023
# Encontrados 0 artículos en Bogotá.gov
#
# 🔍 Buscando en Bogotá.gov: huelga de profesores
# Encontrados 0 artículos en Bogotá.gov
#
# 🔍 Buscando en Bogotá.gov: protesta docente 2023
# Encontrados 0 artículos en Bogotá.gov
#
# 🔍 Buscando en El Tiempo: paro docentes
# Encontrados 20 artículos en El Tiempo
#
# 🔍 Buscando en El Tiempo: paro maestros
# Encontrados 20 artículos en El Tiempo
#
# 🔍 Buscando en El Tiempo: suspensión de clases 2023
# Encontrados 20 artículos en El Tiempo
#
# 🔍 Buscando en El Tiempo: cese de actividades escolares 2023
# Encontrados 20 artículos en El Tiempo
#
# 🔍 Buscando en El Tiempo: FECODE 2023
# Encontrados 20 artículos en El Tiempo
#
# 🔍 Buscando en El Tiempo: huelga de profesores
# Encontrados 20 artículos en El Tiempo
#
# 🔍 Buscando en El Tiempo: protesta docente 2023
# Encontrados 20 artículos en El Tiempo
#
# 🔍 Buscando en El Espectador: paro docentes
# Encontrados 0 artículos en El Espectador
#
# 🔍 Buscando en El Espectador: paro maestros
# Encontrados 0 artículos en El Espectador
#
# 🔍 Buscando en El Espectador: suspensión de clases 2023
# Encontrados 0 artículos en El Espectador
#
# 🔍 Buscando en El Espectador: cese de actividades escolares 2023
# Encontrados 0 artículos en El Espectador
#
# 🔍 Buscando en El Espectador: FECODE 2023
# Encontrados 0 artículos en El Espectador
#
# 🔍 Buscando en El Espectador: huelga de profesores
# Encontrados 0 artículos en El Espectador
#
# 🔍 Buscando en El Espectador: protesta docente 2023
# Encontrados 0 artículos en El Espectador
#
# 🔍 Buscando en Noticias Caracol: paro docentes
# Encontrados 0 artículos en Noticias Caracol
#
# 🔍 Buscando en Noticias Caracol: paro maestros
# Encontrados 0 artículos en Noticias Caracol
#
# 🔍 Buscando en Noticias Caracol: suspensión de clases 2023
# Encontrados 0 artículos en Noticias Caracol
#
# 🔍 Buscando en Noticias Caracol: cese de actividades escolares 2023
# Encontrados 0 artículos en Noticias Caracol
#
# 🔍 Buscando en Noticias Caracol: FECODE 2023
# Encontrados 0 artículos en Noticias Caracol
#
# 🔍 Buscando en Noticias Caracol: huelga de profesores
# Encontrados 0 artículos en Noticias Caracol
#
# 🔍 Buscando en Noticias Caracol: protesta docente 2023
# Encontrados 0 artículos en Noticias Caracol
#
# 🔍 Buscando en Portafolio: paro docentes
# Encontrados 20 artículos en Portafolio
#
# 🔍 Buscando en Portafolio: paro maestros
# Encontrados 20 artículos en Portafolio
#
# 🔍 Buscando en Portafolio: suspensión de clases 2023
# Encontrados 20 artículos en Portafolio
#
# 🔍 Buscando en Portafolio: cese de actividades escolares 2023
# Encontrados 20 artículos en Portafolio
#
# 🔍 Buscando en Portafolio: FECODE 2023
# Encontrados 20 artículos en Portafolio
#
# 🔍 Buscando en Portafolio: huelga de profesores
# Encontrados 20 artículos en Portafolio
#
# 🔍 Buscando en Portafolio: protesta docente 2023
# Encontrados 20 artículos en Portafolio
#
# 🔍 Buscando en Valora Analitik: paro docentes
# Encontrados 8 artículos en Valora Analitik
#
# 🔍 Buscando en Valora Analitik: paro maestros
# Encontrados 8 artículos en Valora Analitik
#
# 🔍 Buscando en Valora Analitik: suspensión de clases 2023
# Encontrados 1 artículos en Valora Analitik
#
# 🔍 Buscando en Valora Analitik: cese de actividades escolares 2023
# Encontrados 0 artículos en Valora Analitik
#
# 🔍 Buscando en Valora Analitik: FECODE 2023
# Encontrados 8 artículos en Valora Analitik
#
# 🔍 Buscando en Valora Analitik: huelga de profesores
# Encontrados 5 artículos en Valora Analitik
#
# 🔍 Buscando en Valora Analitik: protesta docente 2023
# Encontrados 5 artículos en Valora Analitik
#
# 🔍 Buscando en La FM (Educación): paro docentes
# ❌ Error en La FM (Educación): 404 Client Error: Not Found for url: https://www.lafm.com.co/educacionparo+docentes
#
# 🔍 Buscando en La FM (Educación): paro maestros
# ❌ Error en La FM (Educación): 404 Client Error: Not Found for url: https://www.lafm.com.co/educacionparo+maestros
#
# 🔍 Buscando en La FM (Educación): suspensión de clases 2023
# ❌ Error en La FM (Educación): 404 Client Error: Not Found for url: https://www.lafm.com.co/educacionsuspensi%C3%B3n+de+clases+2023
#
# 🔍 Buscando en La FM (Educación): cese de actividades escolares 2023
# ❌ Error en La FM (Educación): 404 Client Error: Not Found for url: https://www.lafm.com.co/educacioncese+de+actividades+escolares+2023
#
# 🔍 Buscando en La FM (Educación): FECODE 2023
# ❌ Error en La FM (Educación): 404 Client Error: Not Found for url: https://www.lafm.com.co/educacionFECODE+2023
#
# 🔍 Buscando en La FM (Educación): huelga de profesores
# ❌ Error en La FM (Educación): 404 Client Error: Not Found for url: https://www.lafm.com.co/educacionhuelga+de+profesores
#
# 🔍 Buscando en La FM (Educación): protesta docente 2023
# ❌ Error en La FM (Educación): 404 Client Error: Not Found for url: https://www.lafm.com.co/educacionprotesta+docente+2023
#
# 🔍 Buscando en Radionacional (Educación): paro docentes
# ❌ Error en Radionacional (Educación): 400 Client Error: Bad Request for url: https://www.radionacional.co/actualidad/educacionparo+docentes
#
# 🔍 Buscando en Radionacional (Educación): paro maestros
# ❌ Error en Radionacional (Educación): 400 Client Error: Bad Request for url: https://www.radionacional.co/actualidad/educacionparo+maestros
#
# 🔍 Buscando en Radionacional (Educación): suspensión de clases 2023
# ❌ Error en Radionacional (Educación): 400 Client Error: Bad Request for url: https://www.radionacional.co/actualidad/educacionsuspensi%C3%B3n+de+clases+2023
#
# 🔍 Buscando en Radionacional (Educación): cese de actividades escolares 2023
# ❌ Error en Radionacional (Educación): 400 Client Error: Bad Request for url: https://www.radionacional.co/actualidad/educacioncese+de+actividades+escolares+2023
#
# 🔍 Buscando en Radionacional (Educación): FECODE 2023
# ❌ Error en Radionacional (Educación): 400 Client Error: Bad Request for url: https://www.radionacional.co/actualidad/educacionFECODE+2023
#
# 🔍 Buscando en Radionacional (Educación): huelga de profesores
# ❌ Error en Radionacional (Educación): 400 Client Error: Bad Request for url: https://www.radionacional.co/actualidad/educacionhuelga+de+profesores
#
# 🔍 Buscando en Radionacional (Educación): protesta docente 2023
# ❌ Error en Radionacional (Educación): 400 Client Error: Bad Request for url: https://www.radionacional.co/actualidad/educacionprotesta+docente+2023
#
# 🔍 Buscando en Red + Noticias: paro docentes
# ❌ Error en Red + Noticias: 403 Client Error: Forbidden for url: https://redmas.com.co/colombia/paro+docentes
#
# 🔍 Buscando en Red + Noticias: paro maestros
# ❌ Error en Red + Noticias: 403 Client Error: Forbidden for url: https://redmas.com.co/colombia/paro+maestros
#
# 🔍 Buscando en Red + Noticias: suspensión de clases 2023
# ❌ Error en Red + Noticias: 403 Client Error: Forbidden for url: https://redmas.com.co/colombia/suspensi%C3%B3n+de+clases+2023
#
# 🔍 Buscando en Red + Noticias: cese de actividades escolares 2023
# ❌ Error en Red + Noticias: 403 Client Error: Forbidden for url: https://redmas.com.co/colombia/cese+de+actividades+escolares+2023
#
# 🔍 Buscando en Red + Noticias: FECODE 2023
# ❌ Error en Red + Noticias: 403 Client Error: Forbidden for url: https://redmas.com.co/colombia/FECODE+2023
#
# 🔍 Buscando en Red + Noticias: huelga de profesores
# ❌ Error en Red + Noticias: 403 Client Error: Forbidden for url: https://redmas.com.co/colombia/huelga+de+profesores
#
# 🔍 Buscando en Red + Noticias: protesta docente 2023
# ❌ Error en Red + Noticias: 403 Client Error: Forbidden for url: https://redmas.com.co/colombia/protesta+docente+2023
# ✅ GoogleNews: 550 resultados
#
# 🔍 Buscando con SerpAPI...
#  SerpAPI: 50 resultados
#
# ✅ Total de noticias recopiladas: 1011

# %%
# ================================================================
# ANÁLISIS CON IA
# ================================================================

from urllib.parse import quote_plus

def obtener_texto_completo(url, titulo=""):
    """
    Intenta obtener el contenido completo desde una URL.
    Si falla, sugiere una búsqueda en Google con base en el título.
    """

    try:
        r = requests.get(url, timeout=15)
        r.raise_for_status()
        soup = BeautifulSoup(r.text, "html.parser")

        # Elimina contenido irrelevante
        for s in soup(["script", "style", "noscript", "header", "footer", "aside", "form"]):
            s.extract()

        texto = " ".join(soup.stripped_strings)
        return texto[:8000]

    except Exception as e:
        print(f"❌ Error al acceder a la URL: {url}\n   Motivo: {e}")

        # Genera un enlace de búsqueda en Google
        if titulo:
            query = quote_plus(titulo)
        else:
            # Extrae la última parte del URL como fallback
            query = quote_plus(url.split("/")[-1])

        google_link = f"https://www.google.com/search?q={query}"
        print(f"🔎 Sugerencia de búsqueda en Google: {google_link}")

        return f"[Error al obtener contenido de la URL]\nSugerencia: busca manualmente en Google: {google_link}"



def analizar_con_ia(titulo, descripcion, url):
    """
    🤖 EXPLICACIÓN (LA MÁS IMPORTANTE):
    Esta función envía la noticia a GPT-4 para que la analice siguiendo criterios estrictos.

    PROCESO:
    1. Intenta descargar el contenido completo de la URL
    2. Si falla, usa solo título + descripción, indicame si pudiste o no acceder al URL
    3. Construye un prompt detallado con instrucciones para la IA
    4. Envía el prompt a OpenAI (modelo gpt-4o-mini)
    5. Recibe respuesta en formato JSON
    6. Parsea el JSON y devuelve un diccionario con las características

    CARACTERÍSTICAS QUE ANALIZA:
    - es_paro_docente: ¿Hubo suspensión de clases?
    - organizaciones_sindicales: ¿Qué sindicatos u organizaciones políticas participaron?
    - duracion_dias: ¿Cuántos días duró?
    - ubicacion_bogota: ¿Ocurrió en Bogotá?
    - ubicacion_Colombia: ¿Abarcó todo el territorio Nacional=
    - costo_mencionado: ¿Se habla de costos económicos?
    - fecha_paro: ¿cuál es la fecha exacta del paro (día, mes, año)?
    """
    print(f"  🤖 Analizando: {titulo[:60]}...")

    contenido_completo = obtener_texto_completo(url) if url else ""

    if "Error" in contenido_completo or not contenido_completo:
        texto_analizar = f"Título: {titulo}\nDescripción: {descripcion}"
    else:
        texto_analizar = contenido_completo

    # ============================================
    #  PROMPT IA
    # ============================================
    prompt = f"""
Analiza la siguiente noticia en español sobre educación, sindicatos o protestas de docentes.

CRITERIOS ESTRICTOS:
- Un **paro docente verdadero** solo existe si hubo suspensión de clases programadas.
- Si fue marcha, manifestación o concentración SIN suspensión de clases, NO es paro.
- Debes explicar tu razonamiento.

Devuelve un JSON con estas claves:

- "es_paro_docente": true/false → true solo si hubo suspensión de clases
- "justificacion_paro": texto breve (2-4 líneas) explicando por qué es o no un paro
- "organizaciones_sindicales": lista de sindicatos mencionados u organizaciones políticas o partidos políticos (ej: ["FECODE", "ADE"]), o []
- "hay_suspension_clases": true/false → si se suspendieron clases
- "duracion_dias": número de días estimados, o null
- "razones_paro": resumen de las demandas principales
- "ubicacion_bogota": true/false → si ocurre en Bogotá/Cundinamarca
- "ubicacion_Colombia": true/false → si el paro abarca el territorio Nacional
- "costo_mencionado": monto económico si se menciona, o null
- "resumen": breve resumen (máx. 3 líneas)
- "fecha_paro": fecha exacta o estimada del paro (en formato ISO: YYYY-MM-DD).
   Si no se menciona explícitamente, intenta inferirla a partir del texto:
   por ejemplo, si dice "este jueves" o "la semana pasada",
   dedúcela usando la fecha de publicación o el contexto temporal.
   Si no se puede deducir con precisión, deja null.
- "tipo_movilizacion": ¿cuál es el tipo de movilización, paro docente con las caracteristicas que ya vimos, paro de otro gremio, demostración, plantón, toma, marcha pacífica, etc?
- "ubicacion": además del país y ciudad, podemos identificar localidades? barrios? calles? edificios? colegios específicos o barrios?
Devuelve SOLO el JSON válido, sin texto extra.
- "fuente_oficial": ¿es una fuente oficial de algún sindicato o es media, si es media cual, si es sindicato, cual?

Texto a analizar:
{texto_analizar}
"""

    try:
        # ============================================
        #  API DE OPENAI
        # ============================================

        response = client.chat.completions.create(
            model="gpt-4o-mini",
            temperature=0.1,
            messages=[{"role": "user", "content": prompt}],
        )

        # Extrae el texto de la respuesta
        respuesta_texto = response.choices[0].message.content.strip()

        # ============================================
        # PARSEO DEL JSON
        # ============================================
        # La IA devuelve un JSON como string, lo convertimos a diccionario
        try:
            # Intenta parsear directamente
            analisis = json.loads(respuesta_texto)
        except json.JSONDecodeError:
            # Si falla, busca el JSON dentro de bloques de código ```json```
            if "```json" in respuesta_texto:
                inicio = respuesta_texto.find("```json") + 7
                fin = respuesta_texto.find("```", inicio)
                json_str = respuesta_texto[inicio:fin].strip()
                analisis = json.loads(json_str)
            else:
                # Si todo falla, devuelve valores por defecto
                print("    ⚠️ No se pudo parsear el JSON")
                analisis = {
                    'es_paro_docente': False,
                    'justificacion_paro': 'Error al analizar',
                    'organizaciones_sindicales': [],
                    'hay_suspension_clases': False,
                    'duracion_dias': None,
                    'razones_paro': '',
                    'ubicacion_bogota': False,
                    'ubicacion_Colombia': False,
                    'costo_mencionado': None,
                    'resumen': '',
                    'fecha_paro': None,
                    'tipo_movilizacion': '',
                    'ubicacion': '',
                    'fuente_oficial': ''
                }

        return analisis

    except Exception as e:
        print(f"    ❌ Error en análisis IA: {e}")
        if "insufficient_quota" in str(e):
            print("    Please check your OpenAI API plan and billing details.")
        return {
            'es_paro_docente': False,
            'justificacion_paro': f'Error: {str(e)}',
            'organizaciones_sindicales': [],
            'hay_suspension_clases': False,
            'duracion_dias': None,
            'razones_paro': '',
            'ubicacion_bogota': False,
            'ubicacion_Colombia': False,
            'costo_mencionado': None,
            'resumen': '',
            'fecha_paro': None,
            'tipo_movilizacion': '',
            'ubicacion': '',
            'fuente_oficial': ''
        }


# ================================================================
# 🧹 FASE 1.5: LIMPIEZA Y ELIMINACIÓN DE DUPLICADOS
# ================================================================
print("\n🧹 Eliminando duplicados...")

df = pd.DataFrame(resultados_totales)

df['url_norm'] = df['url'].astype(str).str.strip().str.lower()
df = df.drop_duplicates(subset=['url_norm'], keep='first')

print(f"✅ Total tras eliminar duplicados: {len(df)} noticias únicas\n")

# ================================================================
# FASE 2: ANÁLISIS CON IA
# ================================================================
print("\n🤖 FASE 2: Analizando con IA...")

resultados_finales = []
for i, noticia in enumerate(df.to_dict('records'), 1):
    print(f"\n[{i}/{len(df)}] Analizando: {noticia['titulo'][:80]}")

    analisis = analizar_con_ia(
        noticia['titulo'],
        noticia.get('descripcion', ''),
        noticia.get('url', '')
    )

    noticia.update(analisis)
    resultados_finales.append(noticia)

    # Espera 2 segundos entre llamadas para no saturar la API
    time.sleep(2)

# ================================================================
# FASE 3: GUARDAR RESULTADOS EN CSV
# ================================================================
print("\n💾 FASE 3: Guardando resultados...")

df_final = pd.DataFrame(resultados_finales)

# Reordena columnas para legibilidad
columnas_importantes = [
    'titulo', 'fuente', 'fecha_publicacion', 'url',
    'es_paro_docente', 'hay_suspension_clases', 'ubicacion_bogota',
    'ubicacion_Colombia', 'duracion_dias', 'organizaciones_sindicales',
    'razones_paro', 'costo_mencionado', 'justificacion_paro', 'resumen',
    'fecha_paro', 'tipo_movilizacion', 'ubicacion',
    'descripcion', 'periodo_busqueda', 'fecha_extraccion', 'fuente_oficial'
]

columnas_finales = [col for col in columnas_importantes if col in df_final.columns]
df_final = df_final[columnas_finales]

# Guarda CSV final
nombre_archivo = "noticias_paros_docentes_2023_ANALIZADO.csv"
df_final.to_csv(nombre_archivo, index=False, encoding="utf-8-sig")

print(f"✅ Archivo guardado: {nombre_archivo}")
print(f"📊 Total de noticias analizadas: {len(df_final)}")

# ================================================================
# 🧹 FASE 2.5: UNIFICAR FORMATO DE FECHAS Y FILTRAR EVENTOS
# ================================================================
print("\n📅 Normalizando formato de fechas y filtrando eventos relevantes...")

def parse_fecha(fecha):
    if pd.isna(fecha) or str(fecha).strip() == "":
        return None
    for fmt in ("%Y-%m-%d", "%d/%m/%Y", "%d-%m-%Y", "%B %d, %Y", "%d %b %Y"):
        try:
            return pd.to_datetime(fecha, format=fmt, errors='coerce')
        except Exception:
            continue
    return pd.to_datetime(fecha, errors='coerce')

df_final['fecha_paro'] = df_final['fecha_paro'].apply(parse_fecha)
df_final['fecha_paro'] = df_final['fecha_paro'].dt.strftime('%Y-%m-%d')

df_filtrado = df_final[
    ((df_final['es_paro_docente'] == True) | (df_final['hay_suspension_clases'] == True))
    & ((df_final['ubicacion_bogota'] == True) | (df_final['ubicacion_Colombia'] == True))
].copy()

print(f"✅ Total de eventos filtrados (Colombia/Bogotá): {len(df_filtrado)}")

nombre_archivo_filtrado = "web_noticias_paros_docentes_2023.csv"
df_filtrado.to_csv(nombre_archivo_filtrado, index=False, encoding="utf-8-sig")
print(f"📁 Archivo filtrado guardado: {nombre_archivo_filtrado}")

# ================================================================
# ESTADÍSTICAS FINALES
# ================================================================
print("\n" + "="*60)
print("📈 ESTADÍSTICAS DEL ANÁLISIS")
print("="*60)

paros_verdaderos = df_final[df_final['es_paro_docente'] == True]
print(f"🔴 Paros verdaderos (con suspensión de clases): {len(paros_verdaderos)}")

en_bogota = df_final[df_final['ubicacion_bogota'] == True]
print(f"📍 Eventos en Bogotá: {len(en_bogota)}")

con_duracion = df_final[df_final['duracion_dias'].notna()]
if len(con_duracion) > 0:
   print(f"⏱️ Duración promedio: {con_duracion['duracion_dias'].mean():.1f} días")

print("\n🎉 ¡Análisis completado!")
# Out:
# 🧹 Eliminando duplicados...
# ✅ Total tras eliminar duplicados: 387 noticias únicas
#
#
# 🤖 FASE 2: Analizando con IA...
#
# [1/387] Analizando: Circulares 2023
#   🤖 Analizando: Circulares 2023...
#
# [2/387] Analizando: Documentos 2025
#   🤖 Analizando: Documentos 2025...
#
# [3/387] Analizando: Circulares 2025
#   🤖 Analizando: Circulares 2025...
#
# [4/387] Analizando: Inicio
#   🤖 Analizando: Inicio...
#
# [5/387] Analizando: Elecciones Fecode 2023
#   🤖 Analizando: Elecciones Fecode 2023...
#
# [6/387] Analizando: Acuerdo FECODE – MEN 2023
#   🤖 Analizando: Acuerdo FECODE – MEN 2023...
#
# [7/387] Analizando: Escuela Sindical Documentos
#   🤖 Analizando: Escuela Sindical Documentos...
#
# [8/387] Analizando: Premio 2019
#   🤖 Analizando: Premio 2019...
#
# [9/387] Analizando: Paro de Docentes
#   🤖 Analizando: Paro de Docentes...
#
# [10/387] Analizando: INFORME DE GESTIÓN ACADÉMICA Y PEDAGÓGICA AÑO 2022
#   🤖 Analizando: INFORME DE GESTIÓN ACADÉMICA Y PEDAGÓGICA AÑO 2022...
#
# [11/387] Analizando: Inmersión pedagógica e intercultural en Francia
#   🤖 Analizando: Inmersión pedagógica e intercultural en Francia...
#
# [12/387] Analizando: Respuesta
#   🤖 Analizando: Respuesta...
#
# [13/387] Analizando: Formación permanente
#   🤖 Analizando: Formación permanente...
#
# [14/387] Analizando: Orientaciones sobre cómo estudiar y evaluar cuando se Aprende en casa
#   🤖 Analizando: Orientaciones sobre cómo estudiar y evaluar cuando se Aprend...
#
# [15/387] Analizando: Comunicado Primera Asamblea de Padres de Familia
#   🤖 Analizando: Comunicado Primera Asamblea de Padres de Familia...
#
# [16/387] Analizando: BOLETÍN SEMANAL N° 21 DEL 9 AL 14 DE JUNIO DE 2025
#   🤖 Analizando: BOLETÍN SEMANAL N° 21 DEL 9 AL 14 DE JUNIO DE 2025...
#
# [17/387] Analizando: BOLETÍN SEMANAL N° 21 DEL 22 AL 27 DE JULIO DE 2024
#   🤖 Analizando: BOLETÍN SEMANAL N° 21 DEL 22 AL 27 DE JULIO DE 2024...
#
# [18/387] Analizando: COMUNICADO RECTORAL 19 DE MAYO 2022 PARA LOS PADRES DE FAMILIA Y ESTUDIANTES RUF
#   🤖 Analizando: COMUNICADO RECTORAL 19 DE MAYO 2022 PARA LOS PADRES DE FAMIL...
#
# [19/387] Analizando: CRONOGRAMA 2023
#   🤖 Analizando: CRONOGRAMA 2023...
#
# [20/387] Analizando: Caja de Herramientas SIMONU
#   🤖 Analizando: Caja de Herramientas SIMONU...
#
# [21/387] Analizando: Cátedras Itinerantes un espacio para el diálogo y la reflexión con enfoque STEM.
#   🤖 Analizando: Cátedras Itinerantes un espacio para el diálogo y la reflexi...
#
# [22/387] Analizando: Historia del Premio
#   🤖 Analizando: Historia del Premio...
#
# [23/387] Analizando: NOVEDADES PARO JUNIO 13 Y 14
#   🤖 Analizando: NOVEDADES PARO JUNIO 13 Y 14...
#
# [24/387] Analizando: Red de Maestros presente en eventos internacionales de STEM
#   🤖 Analizando: Red de Maestros presente en eventos internacionales de STEM...
#
# [25/387] Analizando: Red de Maestros STEM+ Transforma - Cierre 2022
#   🤖 Analizando: Red de Maestros STEM+ Transforma - Cierre 2022...
#
# [26/387] Analizando: Maestros STEM consolidan sus apuestas pedagógicas en Bogotá
#   🤖 Analizando: Maestros STEM consolidan sus apuestas pedagógicas en Bogotá...
#
# [27/387] Analizando: Cierre del período de acompañamiento de los maestros en formación de la Universi
#   🤖 Analizando: Cierre del período de acompañamiento de los maestros en form...
#
# [28/387] Analizando: Celebración día del profesor
#   🤖 Analizando: Celebración día del profesor...
#
# [29/387] Analizando: Tercera cátedra  Red de Maestros STEM + Transforma
#   🤖 Analizando: Tercera cátedra  Red de Maestros STEM + Transforma...
#
# [30/387] Analizando: Mapa de Experiencias e Ideas Transformadoras
#   🤖 Analizando: Mapa de Experiencias e Ideas Transformadoras...
#
# [31/387] Analizando: Ganadores 2023
#   🤖 Analizando: Ganadores 2023...
#
# [32/387] Analizando: CONVOCATORIAS 2023
#   🤖 Analizando: CONVOCATORIAS 2023...
#
# [33/387] Analizando: REPORTES FINANCIEROS AÑO 2023
#   🤖 Analizando: REPORTES FINANCIEROS AÑO 2023...
#
# [34/387] Analizando: Finalización y Matrícula
#   🤖 Analizando: Finalización y Matrícula...
#
# [35/387] Analizando: Comunicado a la Comunidad Educativa - Reapertura
#   🤖 Analizando: Comunicado a la Comunidad Educativa - Reapertura...
#
# [36/387] Analizando: INGRESO AL COLEGIO
#   🤖 Analizando: INGRESO AL COLEGIO...
#
# [37/387] Analizando: LISTAS DE UTILES ESCOLARES 2023
#   🤖 Analizando: LISTAS DE UTILES ESCOLARES 2023...
#
# [38/387] Analizando: Ganadores 2022
#   🤖 Analizando: Ganadores 2022...
#
# [39/387] Analizando: CIRCULAR INFORMATIVA CIERRE AÑO ESCOLAR 2023 JORNADA MAÑANA
#   🤖 Analizando: CIRCULAR INFORMATIVA CIERRE AÑO ESCOLAR 2023 JORNADA MAÑANA...
#
# [40/387] Analizando: BOLETÍN SEMANAL N° 01
#   🤖 Analizando: BOLETÍN SEMANAL N° 01...
#
# [41/387] Analizando: Donatón 2023 “Compartiendo con alegría”  MMC
#   🤖 Analizando: Donatón 2023 “Compartiendo con alegría”  MMC...
#
# [42/387] Analizando: LA ESCUELA: UN RECURSO VITAL EN NUESTRA EXISTENCIA
#   🤖 Analizando: LA ESCUELA: UN RECURSO VITAL EN NUESTRA EXISTENCIA...
#
# [43/387] Analizando: 🎨✨ ¡Bogotá Brilló en el IED Rafael Delgado Salguero! La Fiesta "Vida en Escena"
#   🤖 Analizando: 🎨✨ ¡Bogotá Brilló en el IED Rafael Delgado Salguero! La Fies...
#
#   🤖 Analizando: Proyecto de nuevo régimen aduanero aumentaría la incertidumb...
#
# [92/387] Analizando: La empresa Nvidia sube en Wall Street pese al veto de Trump a sus ventas en Chin
#   🤖 Analizando: La empresa Nvidia sube en Wall Street pese al veto de Trump ...
#
# [93/387] Analizando: Anótelo: cómo evitar el fraude al transferir por medio de un código QR
#   🤖 Analizando: Anótelo: cómo evitar el fraude al transferir por medio de un...
#
# [94/387] Analizando: Con reforma laboral, puede pedir gratis atención psicológica a su ARL: cómo hace
#   🤖 Analizando: Con reforma laboral, puede pedir gratis atención psicológica...
#
# [95/387] Analizando: La inversión extranjera directa en minas y canteras cayó 31%, el primer semestre
#   🤖 Analizando: La inversión extranjera directa en minas y canteras cayó 31%...
#
# [96/387] Analizando: CCS hizo un llamado a las empresas a incluir a toda su cadena de valor en la ges
#   🤖 Analizando: CCS hizo un llamado a las empresas a incluir a toda su caden...
#
# [97/387] Analizando: El Monedero: inflación de alimentos vs. su bolsillo, en el caso del arroz o el h
#   🤖 Analizando: El Monedero: inflación de alimentos vs. su bolsillo, en el c...
#
# [98/387] Analizando: Womenize Latam llega al Caribe para impulsar el liderazgo femenino en tecnología
#   🤖 Analizando: Womenize Latam llega al Caribe para impulsar el liderazgo fe...
#
# [99/387] Analizando: Club El Nogal revisará despidos de forma individual, tras mesas con Mintrabajo
#   🤖 Analizando: Club El Nogal revisará despidos de forma individual, tras me...
#
# [100/387] Analizando: Huracán Melissa deja sus primeros estragos, tras su llegada a Jamaica
#   🤖 Analizando: Huracán Melissa deja sus primeros estragos, tras su llegada ...
#
# [101/387] Analizando: Fundación Terpel impacta en la educación de niños en poblaciones en zonas rurale
#   🤖 Analizando: Fundación Terpel impacta en la educación de niños en poblaci...
#
# [102/387] Analizando: ¿Buscando trabajo con estudios básicos? Hay feria de empleo en Bogotá
#   🤖 Analizando: ¿Buscando trabajo con estudios básicos? Hay feria de empleo ...
#
# [103/387] Analizando: Enfriamiento líquido se consolida como la tecnología clave para los centros de d
#   🤖 Analizando: Enfriamiento líquido se consolida como la tecnología clave p...
#
# [104/387] Analizando: Violencia escolar en América Latina y el Caribe: un desafío urgente
#   🤖 Analizando: Violencia escolar en América Latina y el Caribe: un desafío ...
#
# [105/387] Analizando: El costo oculto de la política: cómo la financiación electoral afecta los impues
#   🤖 Analizando: El costo oculto de la política: cómo la financiación elector...
#
# [106/387] Analizando: Dónde hay más informalidad en el mundo y cómo está Colombia
#   🤖 Analizando: Dónde hay más informalidad en el mundo y cómo está Colombia...
#
# [107/387] Analizando: Empresas aseguran que los roles de trabajadores son transformados gracias a la I
#   🤖 Analizando: Empresas aseguran que los roles de trabajadores son transfor...
#
# [108/387] Analizando: La izquierda triunfa con Mamdani en Nueva York: celebraron con gritos por Palest
#   🤖 Analizando: La izquierda triunfa con Mamdani en Nueva York: celebraron c...
#
# [109/387] Analizando: Treinta años
#   🤖 Analizando: Treinta años...
#
# [110/387] Analizando: Estados Unidos mata a dos presuntos narcos en un ataque a un barco en el Pacífic
#   🤖 Analizando: Estados Unidos mata a dos presuntos narcos en un ataque a un...
#
# [111/387] Analizando: Shakira hace historia... otra vez: 'Billboard' reconoce a la artista por su gira
#   🤖 Analizando: Shakira hace historia... otra vez: 'Billboard' reconoce a la...
#
# [112/387] Analizando: Costos de la energía, entre los principales desafíos para la operación de Nestlé
#   🤖 Analizando: Costos de la energía, entre los principales desafíos para la...
#
# [113/387] Analizando: Las oficinas vuelven a llenarse en Bogotá: cae la vacancia y se disparan nuevame
#   🤖 Analizando: Las oficinas vuelven a llenarse en Bogotá: cae la vacancia y...
#
# [114/387] Analizando: ‘El sector vivienda necesita una alianza real entre gobierno, cajas y banca para
#   🤖 Analizando: ‘El sector vivienda necesita una alianza real entre gobierno...
#
# [115/387] Analizando: De superar varias crisis a abrir su tercer restaurante en EE. UU.: el éxito de J
#   🤖 Analizando: De superar varias crisis a abrir su tercer restaurante en EE...
#
# [116/387] Analizando: ‘Uno de cada diez vehículos que han ingresado al parque automotor en Bogotá es 1
#   🤖 Analizando: ‘Uno de cada diez vehículos que han ingresado al parque auto...
#
# [117/387] Analizando: Fabricato: pioneros en circularidad textil en Colombia
#   🤖 Analizando: Fabricato: pioneros en circularidad textil en Colombia...
#
# [118/387] Analizando: Abelardo de la Espriella lanza su candidatura a las elecciones presidenciales de
#   🤖 Analizando: Abelardo de la Espriella lanza su candidatura a las eleccion...
#
# [119/387] Analizando: Cinco claves para entender el debate sobre por qué ya no está de moda tener novi
#   🤖 Analizando: Cinco claves para entender el debate sobre por qué ya no est...
#
# [120/387] Analizando: El robot araña que imprime casas con tierra y busca llevar su tecnología hasta l
#   🤖 Analizando: El robot araña que imprime casas con tierra y busca llevar s...
#
# [121/387] Analizando: ‘El país está prácticamente quebrado y las finanzas públicas están muy mal admin
#   🤖 Analizando: ‘El país está prácticamente quebrado y las finanzas públicas...
#
# [122/387] Analizando: Las inconsistencias técnicas en los planes de comercialidad del campo Sirius, de
#   🤖 Analizando: Las inconsistencias técnicas en los planes de comercialidad ...
#
# [123/387] Analizando: 'Muchas empresas aún están debatiendo entre el potencial de la tecnología y los
#   🤖 Analizando: 'Muchas empresas aún están debatiendo entre el potencial de ...
#
# [124/387] Analizando: 'Un paciente en Colombia se puede demorar más de dos o tres años en acceder a pr
#   🤖 Analizando: 'Un paciente en Colombia se puede demorar más de dos o tres ...
#
# [125/387] Analizando: Arte faraónico: Egipto muestra su tesoro ancestral con la apertura de su Gran Mu
#   🤖 Analizando: Arte faraónico: Egipto muestra su tesoro ancestral con la ap...
#
# [126/387] Analizando: ¿La campaña de Estados Unidos en el Caribe está 'arruinando' su relación con Col
#   🤖 Analizando: ¿La campaña de Estados Unidos en el Caribe está 'arruinando'...
#
# [127/387] Analizando: Nueva fase de desescalamiento de la guerra comercial entre China y Estados Unido
#   🤖 Analizando: Nueva fase de desescalamiento de la guerra comercial entre C...
#
# [128/387] Analizando: Contraloría alerta déficit en PAE y advierte riesgo para 1,6 millones de estudia
#   🤖 Analizando: Contraloría alerta déficit en PAE y advierte riesgo para 1,6...
#
# [129/387] Analizando: 'Para comprar una vivienda VIS, una familia necesita ganar entre 3,5 y 4 mínimos
#   🤖 Analizando: 'Para comprar una vivienda VIS, una familia necesita ganar e...
#
# [130/387] Analizando: ‘La vivienda social no puede quedar en el olvido’: Grupo Amarilo
#   🤖 Analizando: ‘La vivienda social no puede quedar en el olvido’: Grupo Ama...
#
# [131/387] Analizando: Facturación electrónica: el dolor de cabeza para las empresas que incumplan
#   🤖 Analizando: Facturación electrónica: el dolor de cabeza para las empresa...
#
# [132/387] Analizando: 'Vendemos la mitad de viviendas y desistimientos se duplicaron en gobierno Petro
#   🤖 Analizando: 'Vendemos la mitad de viviendas y desistimientos se duplicar...
#
# [133/387] Analizando: Cortes de luz en Boyacá, en Tunja, Duitama y Paipa del 21 al 24 de octubre
#   🤖 Analizando: Cortes de luz en Boyacá, en Tunja, Duitama y Paipa del 21 al...
#
# [134/387] Analizando: Inversión pública en el país sigue rezagada: no llega al 50%
#   🤖 Analizando: Inversión pública en el país sigue rezagada: no llega al 50%...
#
# [135/387] Analizando: Polémica por artículo del Presupuesto 2026 que permitiría mover fondos pensional
#   🤖 Analizando: Polémica por artículo del Presupuesto 2026 que permitiría mo...
#
# [136/387] Analizando: Propiedad horizontal y convivencia: así funciona la ley del ruido en el país
#   🤖 Analizando: Propiedad horizontal y convivencia: así funciona la ley del ...
#
# [137/387] Analizando: SIC ordena el cierre inmediato de la empresa de criptos World en Colombia
#   🤖 Analizando: SIC ordena el cierre inmediato de la empresa de criptos Worl...
#
# [138/387] Analizando: Cambios en el gasto del Presupuesto 2026 despiertan dudas en el Congreso
#   🤖 Analizando: Cambios en el gasto del Presupuesto 2026 despiertan dudas en...
#
# [139/387] Analizando: Reforma al Icetex tendría un impacto fiscal de $8,9 billones, advierte el Minhac
#   🤖 Analizando: Reforma al Icetex tendría un impacto fiscal de $8,9 billones...
#
# [140/387] Analizando: Alerta en Colombia y América Latina: el virus que se están propagando por WhatsA
#   🤖 Analizando: Alerta en Colombia y América Latina: el virus que se están p...
#
# [141/387] Analizando: México aprueba Ley Aduanera para combatir la evasión fiscal: ¿de qué trata?
#   🤖 Analizando: México aprueba Ley Aduanera para combatir la evasión fiscal:...
#
# [142/387] Analizando: Controles al gasto, veedurías institucionales y transparencia electoral en el pa
#   🤖 Analizando: Controles al gasto, veedurías institucionales y transparenci...
#
# [143/387] Analizando: Inflación le quitaría ritmo a la economía en el cuarto trimestre
#   🤖 Analizando: Inflación le quitaría ritmo a la economía en el cuarto trime...
#
# [144/387] Analizando: Aranceles de Trump golpean la industria de Halloween: precios altos y menor ofer
#   🤖 Analizando: Aranceles de Trump golpean la industria de Halloween: precio...
#
# [145/387] Analizando: Aeropuerto de Cartagena podría no modernizarse por disputa entre la ANI y la Alc
#   🤖 Analizando: Aeropuerto de Cartagena podría no modernizarse por disputa e...
#
# [146/387] Analizando: Colombia se acerca a un apagón: ¿cómo dar el ‘timonazo’ energético?
#   🤖 Analizando: Colombia se acerca a un apagón: ¿cómo dar el ‘timonazo’ ener...
#
# [147/387] Analizando: Análisis: ¿el mundo debe ser más pragmático para la lucha contra el cambio climá
#   🤖 Analizando: Análisis: ¿el mundo debe ser más pragmático para la lucha co...
#
# [148/387] Analizando: Trampas del crecimiento de la productividad en Colombia: reto para las regiones
#   🤖 Analizando: Trampas del crecimiento de la productividad en Colombia: ret...
#
# [149/387] Analizando: Muertos, hambre y destrucción: las cifras de la guerra en Gaza
#   🤖 Analizando: Muertos, hambre y destrucción: las cifras de la guerra en Ga...
#
# [150/387] Analizando: 100.000 viajeros recorrerán la vía Bogotá – Girardot durante el plan retorno
#   🤖 Analizando: 100.000 viajeros recorrerán la vía Bogotá – Girardot durante...
#
# [151/387] Analizando: Colombia estaría en camino a su quinto año por fuera del rango meta en inflación
#   🤖 Analizando: Colombia estaría en camino a su quinto año por fuera del ran...
#
# [152/387] Analizando: 66.000 muertos y millones de desplazados: cifras tras dos años de conflicto en G
#   🤖 Analizando: 66.000 muertos y millones de desplazados: cifras tras dos añ...
#
# [153/387] Analizando: ¿Cuándo salen a vacaciones los colegios e inicia la semana de receso de octubre?
#   🤖 Analizando: ¿Cuándo salen a vacaciones los colegios e inicia la semana d...
#
# [154/387] Analizando: Termotasajero prevé fracaso en subasta de energía: ¿por qué?
#   🤖 Analizando: Termotasajero prevé fracaso en subasta de energía: ¿por qué?...
#
# [155/387] Analizando: La distorsión de precios y la baja demanda ahogan a las siderúrgicas
#   🤖 Analizando: La distorsión de precios y la baja demanda ahogan a las side...
#
# [156/387] Analizando: Freno a la inversión en el país se mantendrá como una constante durante el 2025
#   🤖 Analizando: Freno a la inversión en el país se mantendrá como una consta...
#
# [157/387] Analizando: La informalidad, un obstáculo para lograr crecimiento incluyente
#   🤖 Analizando: La informalidad, un obstáculo para lograr crecimiento incluy...
#
# [158/387] Analizando: Análisis: Colombia avanza lento en la misión de reducir de la pobreza monetaria
#   🤖 Analizando: Análisis: Colombia avanza lento en la misión de reducir de l...
#
# [159/387] Analizando: Niñas y niños conectados: los nuevos retos digitales que enfrentan las familias
#   🤖 Analizando: Niñas y niños conectados: los nuevos retos digitales que enf...
#
# [160/387] Analizando: Ganadería y caña, sectores que más sufren falta de seguridad
#   🤖 Analizando: Ganadería y caña, sectores que más sufren falta de seguridad...
#
# [161/387] Analizando: Viajar sin pagar de más: así puede planear sus vacaciones con programas de lealt
#   🤖 Analizando: Viajar sin pagar de más: así puede planear sus vacaciones co...
#
# [162/387] Analizando: Esta es la viabilidad de la energía nuclear en Colombia
#   🤖 Analizando: Esta es la viabilidad de la energía nuclear en Colombia...
#
# [163/387] Analizando: Radiografía de la educación privada en Colombia: cómo van las finanzas de los co
#   🤖 Analizando: Radiografía de la educación privada en Colombia: cómo van la...
#
# [164/387] Analizando: Más de $400.000 millones invirtieron las generadoras en sostenibilidad en 2024
#   🤖 Analizando: Más de $400.000 millones invirtieron las generadoras en sost...
#
# [165/387] Analizando: Efemérides del 13 de junio de 2025: Qué pasó un día como hoy
#   🤖 Analizando: Efemérides del 13 de junio de 2025: Qué pasó un día como hoy...
#
# [166/387] Analizando: En el diseño de los envases y empaques influye más la psicología del consumidor
#   🤖 Analizando: En el diseño de los envases y empaques influye más la psicol...
#
# [167/387] Analizando: Secretos del coleccionista: lo que debería hacer para 'cazar' tesoros sin gastar
#   🤖 Analizando: Secretos del coleccionista: lo que debería hacer para 'cazar...
#
# [168/387] Analizando: Recomendados Portafolio: La crueldad de la toma del Palacio
#   🤖 Analizando: Recomendados Portafolio: La crueldad de la toma del Palacio...
#
# [169/387] Analizando: Pacientes con enfermedades huérfanas alertan riesgos en acceso a medicamentos y
#   🤖 Analizando: Pacientes con enfermedades huérfanas alertan riesgos en acce...
#
# [170/387] Analizando: Colombia presenta primer balance nacional sobre niñez migrante
#   🤖 Analizando: Colombia presenta primer balance nacional sobre niñez migran...
#
# [171/387] Analizando: Cómo sería el mundo en el año 2029, según la inteligencia artificial: esto revel
#   🤖 Analizando: Cómo sería el mundo en el año 2029, según la inteligencia ar...
#
# [172/387] Analizando: Mociclistas se unen a jornada de protestas en Bogotá por restricción de parrille
#   🤖 Analizando: Mociclistas se unen a jornada de protestas en Bogotá por res...
#
# [173/387] Analizando: Inspeccionan la sede de Colombia Humana por indagación a la campaña de Petro
#   🤖 Analizando: Inspeccionan la sede de Colombia Humana por indagación a la ...
#
# [174/387] Analizando: Pacientes con enfermedades raras alertan por demoras en diagnóstico y acceso
#   🤖 Analizando: Pacientes con enfermedades raras alertan por demoras en diag...
#
# [175/387] Analizando: Gastos del sistema de salud alcanzaron los $121 billones en 2024
#   🤖 Analizando: Gastos del sistema de salud alcanzaron los $121 billones en ...
#
# [176/387] Analizando: Deterioro financiero del sistema de salud alcanza $4,2 billones en cartera farma
#   🤖 Analizando: Deterioro financiero del sistema de salud alcanza $4,2 billo...
#
# [177/387] Analizando: Inflación y déficit le seguirán pasando factura a la política monetaria
#   🤖 Analizando: Inflación y déficit le seguirán pasando factura a la polític...
#
# [178/387] Analizando: Clínica de Marly pone en marcha el primer PET-CT digital de Siemens Healthineers
#   🤖 Analizando: Clínica de Marly pone en marcha el primer PET-CT digital de ...
#
# [179/387] Analizando: España supera los 10 millones de mayores de 65 años con el reto de vivir mejor
#   🤖 Analizando: España supera los 10 millones de mayores de 65 años con el r...
#
# ...
#    Motivo: 403 Client Error: Forbidden for url: https://www.cronista.com/economia-politica/sorpresivo-paro-nacional-docente-todos-los-estudiantes-no-tendran-clases-por-24-horas-cuando-y-a-quienes-afecta/?outputType=amp-type%26ved=2ahUKEwignMf2l9qQAxVgupUCHbytFhYQxfQBegQICRAC%26usg=AOvVaw2w8vlO-HSfEwU0HVDuR1F_/
# 🔎 Sugerencia de búsqueda en Google: https://www.google.com/search?q
# 🔎 Sugerencia de búsqueda en Google: https://www.google.com/search?q=padres-de-familia-en-cozumel-preocupados-por-suspension-de-clases-por-paro-de-maestros.html%26ved%3D2ahUKEwj136z4l9qQAxVnrZUCHWrEPOQQxfQBegQIBRAC%26usg%3DAOvVaw30moIMsLfprmDoIECYtc-7
#
# [353/387] Analizando: Paro de maestros: Fecode anunció movilizaciones ...
#   🤖 Analizando: Paro de maestros: Fecode anunció movilizaciones ......
#
# [354/387] Analizando: Paro nacional de profesores, 30 de agosto de 2023 - El País
#   🤖 Analizando: Paro nacional de profesores, 30 de agosto de 2023 - El País...
#
# [355/387] Analizando: Secretaría de Prensa y Comunicaciones
#   🤖 Analizando: Secretaría de Prensa y Comunicaciones...
#
# [356/387] Analizando: Fecode sale a paro este 30 de agosto: ¿por qué marchan ...
#   🤖 Analizando: Fecode sale a paro este 30 de agosto: ¿por qué marchan ......
#
# [357/387] Analizando: ¿Qué día es el paro de FECODE? Razones y ciudades
#   🤖 Analizando: ¿Qué día es el paro de FECODE? Razones y ciudades...
#
# [358/387] Analizando: Fecode anuncia paro nacional de 24 horas ...
#   🤖 Analizando: Fecode anuncia paro nacional de 24 horas ......
#
# [359/387] Analizando: Paro de Fecode de este miércoles: puntos de encuentro ...
#   🤖 Analizando: Paro de Fecode de este miércoles: puntos de encuentro ......
#
# [360/387] Analizando: Sindicato de maestros convocó a paro el 29 y 30 de ...
#   🤖 Analizando: Sindicato de maestros convocó a paro el 29 y 30 de ......
#
# [361/387] Analizando: Fecode anuncia paro nacional de maestros por 24 horas ...
#   🤖 Analizando: Fecode anuncia paro nacional de maestros por 24 horas ......
#
# [362/387] Analizando: Fecode anuncia Paro Nacional este 30 de Agosto: Estas son ...
#   🤖 Analizando: Fecode anuncia Paro Nacional este 30 de Agosto: Estas son .....
#
# [363/387] Analizando: Educación-Magisterio. 19 luchas docentes que sacudieron ...
#   🤖 Analizando: Educación-Magisterio. 19 luchas docentes que sacudieron ......
# ❌ Error al acceder a la URL: https://www.laizquierdadiario.com/19-luchas-docentes-que-sacudieron-al-mundo-por-aumento-salarial-en-2023
#    Motivo: 403 Client Error: Forbidden for url: https://www.laizquierdadiario.com/19-luchas-docentes-que-sacudieron-al-mundo-por-aumento-salarial-en-2023
# 🔎 Sugerencia de búsqueda en Google: https://www.google.com/search?q=19-luchas-docentes-que-sacudieron-al-mundo-por-aumento-salarial-en-2023
#
# [364/387] Analizando: Los maestros en Colombia no podrían volver a paro
#   🤖 Analizando: Los maestros en Colombia no podrían volver a paro...
#
# [365/387] Analizando: Mala administración y falta de garantías alegan ...
#   🤖 Analizando: Mala administración y falta de garantías alegan ......
#
# [366/387] Analizando: ‍♀️ Paro martes 14/03 y ⚠ASAMBLEA en 📌Escuela Julio ...
#   🤖 Analizando: ‍♀️ Paro martes 14/03 y ⚠ASAMBLEA en 📌Escuela Julio ......
#
# [367/387] Analizando: Universidad Colegio Mayor de Cundinamarca: Estudiantes ...
#   🤖 Analizando: Universidad Colegio Mayor de Cundinamarca: Estudiantes ......
#
# [368/387] Analizando: Manifestaciones 28 de febrero en Colombia: Puntos de ...
#   🤖 Analizando: Manifestaciones 28 de febrero en Colombia: Puntos de ......
#
# [369/387] Analizando: de la republica de colombia.
#   🤖 Analizando: de la republica de colombia....
#
# [370/387] Analizando: Indígenas presionan al Gobierno por el mal estado de las ...
#   🤖 Analizando: Indígenas presionan al Gobierno por el mal estado de las ......
#
# [371/387] Analizando: 23 mil alumnos porteños empiezan hoy las clases y se ...
#   🤖 Analizando: 23 mil alumnos porteños empiezan hoy las clases y se ......
#
# [372/387] Analizando: 1. Situación fáctica descrita en la acción de tutela[ ...
#   🤖 Analizando: 1. Situación fáctica descrita en la acción de tutela[ ......
#
# [373/387] Analizando: ¿Cuándo hay paro de FECODE 2023? Día de marchas y ...
#   🤖 Analizando: ¿Cuándo hay paro de FECODE 2023? Día de marchas y ......
#
# [374/387] Analizando: Fecode anuncia movilizaciones en Colombia el 27 de ...
#   🤖 Analizando: Fecode anuncia movilizaciones en Colombia el 27 de ......
#
# [375/387] Analizando: fecode
#   🤖 Analizando: fecode...
#
# [376/387] Analizando: Paro de maestros: Qué dice Fecode, horarios y puntos de ...
#   🤖 Analizando: Paro de maestros: Qué dice Fecode, horarios y puntos de ......
#
# [377/387] Analizando: Marchas de Fecode HOY 30 de agosto: Protestas EN VIVO ...
#   🤖 Analizando: Marchas de Fecode HOY 30 de agosto: Protestas EN VIVO ......
#
# [378/387] Analizando: fecode - ¡Viva el Paro Nacional del Magistero! Invitamos a ...
#   🤖 Analizando: fecode - ¡Viva el Paro Nacional del Magistero! Invitamos a ....
#
# [379/387] Analizando: RESOLUCIÓN No. 2023-31247 DEL 24 DE MARZO DE 2023
#   🤖 Analizando: RESOLUCIÓN No. 2023-31247 DEL 24 DE MARZO DE 2023...
#
# [380/387] Analizando: CIRCULAR No. 04
#   🤖 Analizando: CIRCULAR No. 04...
#
# [381/387] Analizando: Pliego de Peticiones de Fecode 2023
#   🤖 Analizando: Pliego de Peticiones de Fecode 2023...
#
# [382/387] Analizando: CIRCULAR INFORMATIVA No. 08
#   🤖 Analizando: CIRCULAR INFORMATIVA No. 08...
#
# [383/387] Analizando: Historia
#   🤖 Analizando: Historia...
#
# [384/387] Analizando: i SECRETANA JURIDICA
#   🤖 Analizando: i SECRETANA JURIDICA...
#
# [385/387] Analizando: FEDERACIÓN COLOMBIANA DE ...
#   🤖 Analizando: FEDERACIÓN COLOMBIANA DE ......
#
# [386/387] Analizando: P ILU_CUBIERTA_EXTERIOR_148
#   🤖 Analizando: P ILU_CUBIERTA_EXTERIOR_148...
#
# [387/387] Analizando: verdades inaplazables
#   🤖 Analizando: verdades inaplazables...
#
# 💾 FASE 3: Guardando resultados...
# ✅ Archivo guardado: noticias_paros_docentes_2023_ANALIZADO.csv
# 📊 Total de noticias analizadas: 387
#
# 📅 Normalizando formato de fechas y filtrando eventos relevantes...
# ✅ Total de eventos filtrados (Colombia/Bogotá): 60
# 📁 Archivo filtrado guardado: web_noticias_paros_docentes_2023.csv
#
# ============================================================
# 📈 ESTADÍSTICAS DEL ANÁLISIS
# ============================================================
# 🔴 Paros verdaderos (con suspensión de clases): 72
# 📍 Eventos en Bogotá: 77
# ⏱️ Duración promedio: 1.7 días
#
# 🎉 ¡Análisis completado!
